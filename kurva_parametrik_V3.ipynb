# %%
import numpy as np
import matplotlib.pyplot as plt

# Mengatur tema gelap bawaan matplotlib
plt.style.use('dark_background')


# =====================================================
# VISUALISASI UTAMA (GAYA DASHBOARD CLEAN & BINGKAI LUAR)
# =====================================================

def tampilkan_gaya_pro(param_array, x1, y1, xc, yc, a, b, title, n_pts, step, teks_panel, tipe_kurva="ELIPS", x2=None, y2=None):
    """
    Membuat grafik tunggal dengan sumbu koordinat berada di pinggir (bingkai/box).
    Menampilkan teks_panel yang dinamis sesuai tipe kurva di sebelah kanan.
    """
    warna_kurva = '#00FFCC'   # Cyan-Neon
    warna_kurva2 = '#FF007F'  # Magenta-Neon (Khusus Hiperbola)
    warna_titik = '#FFFFFF'   # Putih
    warna_teks  = '#E0E0E0'
    
    fig, ax = plt.subplots(figsize=(11, 6.5))
    fig.subplots_adjust(left=0.08, right=0.70, top=0.88, bottom=0.10)

    # Judul Utama Gambar
    fig.suptitle(
        f"✦ VISUALISASI {tipe_kurva} PARAMETRIK ✦\nResolusi: {title} | Delta = {step:.4f}",
        fontsize=13, fontweight='bold', color=warna_kurva, y=0.96
    )

    # Plot Jalur Kurva dan Titik Sampel
    if x2 is not None and y2 is not None:
        ax.plot(x1, y1, color=warna_kurva, linewidth=2.5, zorder=2, label='Cabang Kanan')
        ax.plot(x2, y2, color=warna_kurva2, linewidth=2.5, zorder=2, label='Cabang Kiri')
        ax.scatter(x1, y1, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5)
        ax.scatter(x2, y2, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5)
    else:
        ax.plot(x1, y1, color=warna_kurva, linewidth=2.5, zorder=2, label=f'Kurva {tipe_kurva.title()}')
        ax.scatter(x1, y1, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5, label=f'Koordinat ({n_pts} titik)')

    # Titik Pusat / Vertex
    ax.scatter(xc, yc, color='#FFFF00', s=100, marker='P', zorder=5)
    ax.annotate(f"PUSAT ({xc:.1f}, {yc:.1f})", xy=(xc, yc), xytext=(5, 5),
                textcoords="offset points", color='#FFFF00', fontsize=8.5, fontweight='bold')

    # --- PENANDA TITIK AWAL & AKHIR ---
    ax.scatter(x1[0], y1[0], color='#00FF00', marker='s', s=80, zorder=6, label='Titik Awal')
    ax.annotate(f"► START ({x1[0]:.1f}, {y1[0]:.1f})", xy=(x1[0], y1[0]), 
                xytext=(x1[0] + max(a, 1) * 0.15, y1[0] + max(b, 1) * 0.15),
                color='#00FF00', fontsize=8.5, fontweight='bold',
                arrowprops=dict(arrowstyle='->', color='#00FF00', lw=1.2))

    ax.scatter(x1[-1], y1[-1], color='#FF9900', marker='x', s=90, zorder=7, label='Titik Akhir')
    ax.annotate(f"■ END ({x1[-1]:.1f}, {y1[-1]:.1f})", xy=(x1[-1], y1[-1]), 
                xytext=(x1[-1] + max(a, 1) * 0.15, y1[-1] - max(b, 1) * 0.15),
                color='#FF9900', fontsize=8.5, fontweight='bold',
                arrowprops=dict(arrowstyle='->', color='#FF9900', lw=1.2))

    # Teks Koordinat Tipis
    step_lbl = max(1, len(x1) // 6)
    for i in range(1, len(x1) - 1, step_lbl):
        ax.annotate(f"({x1[i]:.1f}, {y1[i]:.1f})", (x1[i], y1[i]),
                    textcoords="offset points", xytext=(5, 5), fontsize=7, color='#888888')
        if x2 is not None and y2 is not None:
            ax.annotate(f"({x2[i]:.1f}, {y2[i]:.1f})", (x2[i], y2[i]),
                        textcoords="offset points", xytext=(5, 5), fontsize=7, color='#888888')

    # --- KOTAK INFO PANEL TUNGGAL ---
    bbox_style = dict(boxstyle="square,pad=0.7", fc="#0B1320", ec=warna_kurva, lw=1.2, alpha=0.95)
    
    # Mencetak panel informasi yang dikirim dari fungsi masing-masing geometri
    fig.text(0.73, 0.5, teks_panel, fontsize=9.5, color=warna_teks, family='monospace', bbox=bbox_style, va='center')

    # Konfigurasi Batas Grafik
    if tipe_kurva in ("ELIPS", "LINGKARAN"):
        ax.set_aspect('equal', adjustable='box')
        ax.set_xlim(xc - a * 1.6, xc + a * 1.6)
        ax.set_ylim(yc - b * 1.6, yc + b * 1.6)
    else:
        all_x = x1 if x2 is None else np.concatenate([x1, x2])
        all_y = y1 if y2 is None else np.concatenate([y1, y2])
        ax.set_xlim(np.min(all_x) - 2, np.max(all_x) + 2)
        ax.set_ylim(np.min(all_y) - 2, np.max(all_y) + 2)

    # Style Background Grid
    ax.grid(True, linestyle='--', alpha=0.3, color='gray')
    ax.tick_params(colors=warna_teks, labelsize=9)
    for spine in ax.spines.values():
        spine.set_color('white')
        spine.set_linewidth(1)

    ax.axvline(xc, color='gray', linestyle=':', linewidth=0.8, alpha=0.4, zorder=1)
    ax.axhline(yc, color='gray', linestyle=':', linewidth=0.8, alpha=0.4, zorder=1)
    ax.legend(loc='lower left', facecolor='#0B1320', edgecolor='none', labelcolor='white', fontsize=8)
    plt.show()


# =====================================================
# INPUT HELPER UTALITAS
# =====================================================

def input_float(prompt):
    while True:
        try:
            return float(input(prompt))
        except ValueError:
            print("  ⚠  Masukkan angka koordinat yang valid!")


def input_step(prompt):
    while True:
        val = input_float(prompt)
        if val > 0:
            return val
        print("  ⚠  Nilai step pembagi harus lebih besar dari 0!")


# =====================================================
# BANGUN 1: LINGKARAN
# =====================================================

def lingkaran():
    print("================================================================================")
    print(" COMPILER KURVA LINGKARAN PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat X (xc) [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Y (yc) [contoh: 0.0] : ")
    r  = input_float("Ukuran Radius  (r) [contoh: 5.0] : ")
    if r <= 0:
        print("  ⚠  Radius wajib bernilai positif!")
        return

    step_besar = input_step("Jarak Interval Step Besar θ (rad) [contoh: 0.5]  : ")
    step_kecil = input_step("Jarak Interval Step Kecil θ (rad) [contoh: 0.05] : ")

    configs = [
        ("Resolusi Rendah", step_besar),
        ("Resolusi Tinggi", step_kecil),
    ]

    keliling = 2 * np.pi * r
    luas = np.pi * r**2

    for title, step_val in configs:
        theta = np.append(np.arange(0, 2 * np.pi, step_val), 2 * np.pi)
        n_pts = len(theta)
        actual_step = 2 * np.pi / (n_pts - 1) if n_pts > 1 else 0

        x = xc + r * np.cos(theta)
        y = yc + r * np.sin(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA LINGKARAN - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {r} * cos(θ)  |  y(θ) = {yc} + {r} * sin(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {r}*cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {r}*sin({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI LINGKARAN\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Radius (r)   : {r}\n"
            f" Luas Area    : {luas:.4f}\n"
            f" Keliling     : {keliling:.4f}\n"
            f" Total Titik  : {n_pts}\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})² + (y-{yc})² = {r}²"
        )
        tampilkan_gaya_pro(theta, x, y, xc, yc, r, r, title, n_pts, actual_step, teks_panel, "LINGKARAN")


# =====================================================
# BANGUN 2: ELIPS
# =====================================================

def elips():
    print("================================================================================")
    print(" COMPILER KURVA ELIPS PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat X (xc)         [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Y (yc)         [contoh: 0.0] : ")
    a  = input_float("Panjang Sumbu Horizontal a [contoh: 8.0] : ")
    b  = input_float("Panjang Sumbu Vertikal b   [contoh: 5.0] : ")
    if a <= 0 or b <= 0:
        print("  ⚠  Nilai sumbu komponen harus di atas 0!")
        return

    step_besar = input_step("Jarak Interval Step Besar θ (rad) [contoh: 0.5]  : ")
    step_kecil = input_step("Jarak Interval Step Kecil θ (rad) [contoh: 0.05] : ")

    c = np.sqrt(abs(a**2 - b**2))
    e = c / max(a, b)
    luas = np.pi * a * b
    keliling = np.pi * (3*(a+b) - np.sqrt((3*a+b)*(a+3*b))) # Ramanujan approx

    configs = [
        ("Resolusi Rendah", step_besar),
        ("Resolusi Tinggi", step_kecil),
    ]

    for title, step_val in configs:
        theta = np.append(np.arange(0, 2 * np.pi, step_val), 2 * np.pi)
        n_pts = len(theta)
        actual_step = 2 * np.pi / (n_pts - 1) if n_pts > 1 else 0

        x = xc + a * np.cos(theta)
        y = yc + b * np.sin(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA ELIPS - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {a} * cos(θ)  |  y(θ) = {yc} + {b} * sin(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {a}*cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {b}*sin({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        # Informasi panel dinamis spesifik untuk elips (termasuk properti lanjutan)
        teks_panel = (
            f" ⚙ DATA SPESIFIKASI ELIPS\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Sumbu hor (a): {a}\n"
            f" Sumbu ver (b): {b}\n"
            f" Jarak Fokus c: {c:.4f}\n"
            f" Eksentrisitas: {e:.4f}\n"
            f" Luas Area    : {luas:.4f}\n"
            f" Keliling     : {keliling:.4f}\n"
            f" Total Titik  : {n_pts}\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})²/{a}² + (y-{yc})²/{b}² = 1"
        )
        tampilkan_gaya_pro(theta, x, y, xc, yc, a, b, title, n_pts, actual_step, teks_panel, "ELIPS")


# =====================================================
# BANGUN 3: PARABOLA
# =====================================================

def parabola():
    print("================================================================================")
    print(" COMPILER KURVA PARABOLA PARAMETRIK")
    print("================================================================================\n")
    orientasi = input(" Tentukan Orientasi [H/V, contoh: H]: ").strip().upper()
    if orientasi not in ('H', 'V'):
        print("  ⚠  Pilihan orientasi tidak valid!")
        return

    xp = input_float("Titik Vertex X (xp)  [contoh: 0.0] : ")
    yp = input_float("Titik Vertex Y (yp)  [contoh: 0.0] : ")
    a  = input_float("Faktor Ketajaman a   [contoh: 1.0] : ")

    step_besar = input_step("Interval Step Batas Besar parameter t [contoh: 1.0] : ")
    step_kecil = input_step("Interval Step Batas Kecil parameter t [contoh: 0.1] : ")

    configs = [("Resolusi Rendah", step_besar), ("Resolusi Tinggi", step_kecil)]

    for title, step_val in configs:
        t = np.arange(-5, 5 + step_val, step_val)
        n_pts = len(t)
        
        if orientasi == 'H':
            x = xp + a * t**2
            y = yp + t
            rumus_std = f"(y-{yp})² = {1/a:.4f} * (x-{xp})"
        else:
            x = xp + t
            y = yp + a * t**2
            rumus_std = f"(x-{xp})² = {1/a:.4f} * (y-{yp})"

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA PARABOLA - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        if orientasi == 'H':
            print(f"   x(t) = xp + a * t²  |  y(t) = yp + t\n")
        else:
            print(f"   x(t) = xp + t     |  y(t) = yp + a * t²\n")
            
        print(f" Persamaan Parametrik (Substitusi):")
        if orientasi == 'H':
            print(f"   x(t) = {xp} + {a} * t²  |  y(t) = {yp} + t\n")
        else:
            print(f"   x(t) = {xp} + t     |  y(t) = {yp} + {a} * t²\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'NILAI t':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(t)):
            calc_x = f"X = {xp} + {a}*({t[i]:.2f})²" if orientasi == 'H' else f"X = {xp} + {t[i]:.2f}"
            calc_y = f"Y = {yp} + {t[i]:.2f}" if orientasi == 'H' else f"Y = {yp} + {a}*({t[i]:.2f})²"
            print(f" {i+1:<4} | {t[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        fokus_dist = 1 / (4 * a) if a != 0 else 0
        arah = "Horizontal" if orientasi == 'H' else "Vertikal"

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI PARABOLA\n"
            f" ════════════════════════════\n"
            f" Vertex (xp,yp): ({xp:.2f}, {yp:.2f})\n"
            f" Orientasi     : {arah}\n"
            f" Parameter a   : {a}\n"
            f" Dist. Fokus   : {fokus_dist:.4f}\n"
            f" Total Titik   : {n_pts}\n"
            f" Skema         : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" {rumus_std}"
        )
        tampilkan_gaya_pro(t, x, y, xp, yp, a, a, title, n_pts, step_val, teks_panel, "PARABOLA")


# =====================================================
# BANGUN 4: HIPERBOLA
# =====================================================

def hiperbola():
    print("================================================================================")
    print(" COMPILER KURVA HIPERBOLA PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat Domain X (xc)      [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Domain Y (yc)      [contoh: 0.0] : ")
    a  = input_float("Semi-Sumbu Transversal Nilai a [contoh: 4.0] : ")
    b  = input_float("Semi-Sumbu Konjugasi Nilai b   [contoh: 3.0] : ")
    if a <= 0 or b <= 0: return

    step_besar = input_step("Interval Pembagi Step Besar θ (rad) [contoh: 0.2]  : ")
    step_kecil = input_step("Interval Pembagi Step Kecil θ (rad) [contoh: 0.02] : ")

    batas = 1.25  
    configs = [("Resolusi Rendah", step_besar), ("Resolusi Tinggi", step_kecil)]

    c = np.sqrt(a**2 + b**2)
    e = c / a

    for title, step_val in configs:
        theta = np.arange(-batas, batas + step_val, step_val)
        n_pts = len(theta)

        x1 = xc + a / np.cos(theta); y1 = yc + b * np.tan(theta)
        x2 = xc - a / np.cos(theta); y2 = yc + b * np.tan(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA HIPERBOLA (CABANG KANAN) - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + a / cos(θ)  |  y(θ) = yc + b * tan(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {a} / cos(θ)  |  y(θ) = {yc} + {b} * tan(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA CABANG KANAN X':<30} | {'HASIL X':<12} | {'FORMULA CABANG KANAN Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {a}/cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {b}*tan({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x1[i]:<12.4f} | {calc_y:<32} | {y1[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI HIPERBOLA\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Transversal a: {a}\n"
            f" Konjugasi b  : {b}\n"
            f" Jarak Fokus c: {c:.4f}\n"
            f" Eksentrisitas: {e:.4f}\n"
            f" Total Titik  : {n_pts} per cb\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})²/{a}² - (y-{yc})²/{b}² = 1"
        )
        tampilkan_gaya_pro(theta, x1, y1, xc, yc, a, b, title, n_pts, step_val, teks_panel, "HIPERBOLA", x2, y2)


# =====================================================
# HUB KONTROL MENU UTAMA
# =====================================================

def menu():
    while True:
        print("\n" + "═" * 42)
        print("   SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF   ")
        print("═" * 42)
        print("  [1]  Kurva Lingkaran Parametrik")
        print("  [2]  Kurva Elips Parametrik")
        print("  [3]  Kurva Parabola Parametrik")
        print("  [4]  Kurva Hiperbola Parametrik")
        print("  [0]  Hentikan & Keluar Program")
        print("─" * 42)

        pilih = input(" Tentukan Opsi Operasi Menu : ").strip()

        if pilih == "1": lingkaran()
        elif pilih == "2": elips()
        elif pilih == "3": parabola()
        elif pilih == "4": hiperbola()
        elif pilih == "0":
            print("\n Eksekusi dihentikan. Program selesai dengan sukses!\n")
            break
        else: print("  ⚠  Pilihan tidak tersedia!")


if __name__ == "__main__":
    menu()
# Out:
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA LINGKARAN PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA LINGKARAN - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 5.0 * cos(θ)  |  y(θ) = 0.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 5.0*cos(0.00)        | 5.0000       | Y = 0.0 + 5.0*sin(0.00)          | 0.0000
#  2    | 0.80         | X = 0.0 + 5.0*cos(0.80)        | 3.4835       | Y = 0.0 + 5.0*sin(0.80)          | 3.5868
#  3    | 1.60         | X = 0.0 + 5.0*cos(1.60)        | -0.1460      | Y = 0.0 + 5.0*sin(1.60)          | 4.9979
#  4    | 2.40         | X = 0.0 + 5.0*cos(2.40)        | -3.6870      | Y = 0.0 + 5.0*sin(2.40)          | 3.3773
#  5    | 3.20         | X = 0.0 + 5.0*cos(3.20)        | -4.9915      | Y = 0.0 + 5.0*sin(3.20)          | -0.2919
#  6    | 4.00         | X = 0.0 + 5.0*cos(4.00)        | -3.2682      | Y = 0.0 + 5.0*sin(4.00)          | -3.7840
#  7    | 4.80         | X = 0.0 + 5.0*cos(4.80)        | 0.4375       | Y = 0.0 + 5.0*sin(4.80)          | -4.9808
#  8    | 5.60         | X = 0.0 + 5.0*cos(5.60)        | 3.8778       | Y = 0.0 + 5.0*sin(5.60)          | -3.1563
#  9    | 6.28         | X = 0.0 + 5.0*cos(6.28)        | 5.0000       | Y = 0.0 + 5.0*sin(6.28)          | -0.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA LINGKARAN - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 5.0 * cos(θ)  |  y(θ) = 0.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 5.0*cos(0.00)        | 5.0000       | Y = 0.0 + 5.0*sin(0.00)          | 0.0000
#  2    | 0.10         | X = 0.0 + 5.0*cos(0.10)        | 4.9750       | Y = 0.0 + 5.0*sin(0.10)          | 0.4992
#  3    | 0.20         | X = 0.0 + 5.0*cos(0.20)        | 4.9003       | Y = 0.0 + 5.0*sin(0.20)          | 0.9933
#  4    | 0.30         | X = 0.0 + 5.0*cos(0.30)        | 4.7767       | Y = 0.0 + 5.0*sin(0.30)          | 1.4776
#  5    | 0.40         | X = 0.0 + 5.0*cos(0.40)        | 4.6053       | Y = 0.0 + 5.0*sin(0.40)          | 1.9471
#  6    | 0.50         | X = 0.0 + 5.0*cos(0.50)        | 4.3879       | Y = 0.0 + 5.0*sin(0.50)          | 2.3971
#  7    | 0.60         | X = 0.0 + 5.0*cos(0.60)        | 4.1267       | Y = 0.0 + 5.0*sin(0.60)          | 2.8232
#  8    | 0.70         | X = 0.0 + 5.0*cos(0.70)        | 3.8242       | Y = 0.0 + 5.0*sin(0.70)          | 3.2211
#  9    | 0.80         | X = 0.0 + 5.0*cos(0.80)        | 3.4835       | Y = 0.0 + 5.0*sin(0.80)          | 3.5868
#  10   | 0.90         | X = 0.0 + 5.0*cos(0.90)        | 3.1080       | Y = 0.0 + 5.0*sin(0.90)          | 3.9166
#  11   | 1.00         | X = 0.0 + 5.0*cos(1.00)        | 2.7015       | Y = 0.0 + 5.0*sin(1.00)          | 4.2074
#  12   | 1.10         | X = 0.0 + 5.0*cos(1.10)        | 2.2680       | Y = 0.0 + 5.0*sin(1.10)          | 4.4560
#  13   | 1.20         | X = 0.0 + 5.0*cos(1.20)        | 1.8118       | Y = 0.0 + 5.0*sin(1.20)          | 4.6602
#  14   | 1.30         | X = 0.0 + 5.0*cos(1.30)        | 1.3375       | Y = 0.0 + 5.0*sin(1.30)          | 4.8178
#  15   | 1.40         | X = 0.0 + 5.0*cos(1.40)        | 0.8498       | Y = 0.0 + 5.0*sin(1.40)          | 4.9272
#  16   | 1.50         | X = 0.0 + 5.0*cos(1.50)        | 0.3537       | Y = 0.0 + 5.0*sin(1.50)          | 4.9875
#  17   | 1.60         | X = 0.0 + 5.0*cos(1.60)        | -0.1460      | Y = 0.0 + 5.0*sin(1.60)          | 4.9979
#  18   | 1.70         | X = 0.0 + 5.0*cos(1.70)        | -0.6442      | Y = 0.0 + 5.0*sin(1.70)          | 4.9583
#  19   | 1.80         | X = 0.0 + 5.0*cos(1.80)        | -1.1360      | Y = 0.0 + 5.0*sin(1.80)          | 4.8692
#  20   | 1.90         | X = 0.0 + 5.0*cos(1.90)        | -1.6164      | Y = 0.0 + 5.0*sin(1.90)          | 4.7315
#  21   | 2.00         | X = 0.0 + 5.0*cos(2.00)        | -2.0807      | Y = 0.0 + 5.0*sin(2.00)          | 4.5465
#  22   | 2.10         | X = 0.0 + 5.0*cos(2.10)        | -2.5242      | Y = 0.0 + 5.0*sin(2.10)          | 4.3160
#  23   | 2.20         | X = 0.0 + 5.0*cos(2.20)        | -2.9425      | Y = 0.0 + 5.0*sin(2.20)          | 4.0425
#  24   | 2.30         | X = 0.0 + 5.0*cos(2.30)        | -3.3314      | Y = 0.0 + 5.0*sin(2.30)          | 3.7285
#  25   | 2.40         | X = 0.0 + 5.0*cos(2.40)        | -3.6870      | Y = 0.0 + 5.0*sin(2.40)          | 3.3773
#  26   | 2.50         | X = 0.0 + 5.0*cos(2.50)        | -4.0057      | Y = 0.0 + 5.0*sin(2.50)          | 2.9924
#  27   | 2.60         | X = 0.0 + 5.0*cos(2.60)        | -4.2844      | Y = 0.0 + 5.0*sin(2.60)          | 2.5775
#  28   | 2.70         | X = 0.0 + 5.0*cos(2.70)        | -4.5204      | Y = 0.0 + 5.0*sin(2.70)          | 2.1369
#  29   | 2.80         | X = 0.0 + 5.0*cos(2.80)        | -4.7111      | Y = 0.0 + 5.0*sin(2.80)          | 1.6749
#  30   | 2.90         | X = 0.0 + 5.0*cos(2.90)        | -4.8548      | Y = 0.0 + 5.0*sin(2.90)          | 1.1962
#  31   | 3.00         | X = 0.0 + 5.0*cos(3.00)        | -4.9500      | Y = 0.0 + 5.0*sin(3.00)          | 0.7056
#  32   | 3.10         | X = 0.0 + 5.0*cos(3.10)        | -4.9957      | Y = 0.0 + 5.0*sin(3.10)          | 0.2079
#  33   | 3.20         | X = 0.0 + 5.0*cos(3.20)        | -4.9915      | Y = 0.0 + 5.0*sin(3.20)          | -0.2919
#  34   | 3.30         | X = 0.0 + 5.0*cos(3.30)        | -4.9374      | Y = 0.0 + 5.0*sin(3.30)          | -0.7887
#  35   | 3.40         | X = 0.0 + 5.0*cos(3.40)        | -4.8340      | Y = 0.0 + 5.0*sin(3.40)          | -1.2777
#  36   | 3.50         | X = 0.0 + 5.0*cos(3.50)        | -4.6823      | Y = 0.0 + 5.0*sin(3.50)          | -1.7539
#  37   | 3.60         | X = 0.0 + 5.0*cos(3.60)        | -4.4838      | Y = 0.0 + 5.0*sin(3.60)          | -2.2126
#  38   | 3.70         | X = 0.0 + 5.0*cos(3.70)        | -4.2405      | Y = 0.0 + 5.0*sin(3.70)          | -2.6492
#  39   | 3.80         | X = 0.0 + 5.0*cos(3.80)        | -3.9548      | Y = 0.0 + 5.0*sin(3.80)          | -3.0593
#  40   | 3.90         | X = 0.0 + 5.0*cos(3.90)        | -3.6297      | Y = 0.0 + 5.0*sin(3.90)          | -3.4388
#  41   | 4.00         | X = 0.0 + 5.0*cos(4.00)        | -3.2682      | Y = 0.0 + 5.0*sin(4.00)          | -3.7840
#  42   | 4.10         | X = 0.0 + 5.0*cos(4.10)        | -2.8741      | Y = 0.0 + 5.0*sin(4.10)          | -4.0914
#  43   | 4.20         | X = 0.0 + 5.0*cos(4.20)        | -2.4513      | Y = 0.0 + 5.0*sin(4.20)          | -4.3579
#  44   | 4.30         | X = 0.0 + 5.0*cos(4.30)        | -2.0040      | Y = 0.0 + 5.0*sin(4.30)          | -4.5808
#  45   | 4.40         | X = 0.0 + 5.0*cos(4.40)        | -1.5367      | Y = 0.0 + 5.0*sin(4.40)          | -4.7580
#  46   | 4.50         | X = 0.0 + 5.0*cos(4.50)        | -1.0540      | Y = 0.0 + 5.0*sin(4.50)          | -4.8877
#  47   | 4.60         | X = 0.0 + 5.0*cos(4.60)        | -0.5608      | Y = 0.0 + 5.0*sin(4.60)          | -4.9685
#  48   | 4.70         | X = 0.0 + 5.0*cos(4.70)        | -0.0619      | Y = 0.0 + 5.0*sin(4.70)          | -4.9996
#  49   | 4.80         | X = 0.0 + 5.0*cos(4.80)        | 0.4375       | Y = 0.0 + 5.0*sin(4.80)          | -4.9808
#  50   | 4.90         | X = 0.0 + 5.0*cos(4.90)        | 0.9326       | Y = 0.0 + 5.0*sin(4.90)          | -4.9123
#  51   | 5.00         | X = 0.0 + 5.0*cos(5.00)        | 1.4183       | Y = 0.0 + 5.0*sin(5.00)          | -4.7946
#  52   | 5.10         | X = 0.0 + 5.0*cos(5.10)        | 1.8899       | Y = 0.0 + 5.0*sin(5.10)          | -4.6291
#  53   | 5.20         | X = 0.0 + 5.0*cos(5.20)        | 2.3426       | Y = 0.0 + 5.0*sin(5.20)          | -4.4173
#  54   | 5.30         | X = 0.0 + 5.0*cos(5.30)        | 2.7719       | Y = 0.0 + 5.0*sin(5.30)          | -4.1613
#  55   | 5.40         | X = 0.0 + 5.0*cos(5.40)        | 3.1735       | Y = 0.0 + 5.0*sin(5.40)          | -3.8638
#  56   | 5.50         | X = 0.0 + 5.0*cos(5.50)        | 3.5433       | Y = 0.0 + 5.0*sin(5.50)          | -3.5277
#  57   | 5.60         | X = 0.0 + 5.0*cos(5.60)        | 3.8778       | Y = 0.0 + 5.0*sin(5.60)          | -3.1563
#  58   | 5.70         | X = 0.0 + 5.0*cos(5.70)        | 4.1736       | Y = 0.0 + 5.0*sin(5.70)          | -2.7534
#  59   | 5.80         | X = 0.0 + 5.0*cos(5.80)        | 4.4276       | Y = 0.0 + 5.0*sin(5.80)          | -2.3230
#  60   | 5.90         | X = 0.0 + 5.0*cos(5.90)        | 4.6374       | Y = 0.0 + 5.0*sin(5.90)          | -1.8694
#  61   | 6.00         | X = 0.0 + 5.0*cos(6.00)        | 4.8009       | Y = 0.0 + 5.0*sin(6.00)          | -1.3971
#  62   | 6.10         | X = 0.0 + 5.0*cos(6.10)        | 4.9163       | Y = 0.0 + 5.0*sin(6.10)          | -0.9108
#  63   | 6.20         | X = 0.0 + 5.0*cos(6.20)        | 4.9827       | Y = 0.0 + 5.0*sin(6.20)          | -0.4154
#  64   | 6.28         | X = 0.0 + 5.0*cos(6.28)        | 5.0000       | Y = 0.0 + 5.0*sin(6.28)          | -0.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA ELIPS PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA ELIPS - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 8.0 * cos(θ)  |  y(θ) = 0.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 8.0*cos(0.00)        | 8.0000       | Y = 0.0 + 5.0*sin(0.00)          | 0.0000
#  2    | 0.80         | X = 0.0 + 8.0*cos(0.80)        | 5.5737       | Y = 0.0 + 5.0*sin(0.80)          | 3.5868
#  3    | 1.60         | X = 0.0 + 8.0*cos(1.60)        | -0.2336      | Y = 0.0 + 5.0*sin(1.60)          | 4.9979
#  4    | 2.40         | X = 0.0 + 8.0*cos(2.40)        | -5.8991      | Y = 0.0 + 5.0*sin(2.40)          | 3.3773
#  5    | 3.20         | X = 0.0 + 8.0*cos(3.20)        | -7.9864      | Y = 0.0 + 5.0*sin(3.20)          | -0.2919
#  6    | 4.00         | X = 0.0 + 8.0*cos(4.00)        | -5.2291      | Y = 0.0 + 5.0*sin(4.00)          | -3.7840
#  7    | 4.80         | X = 0.0 + 8.0*cos(4.80)        | 0.7000       | Y = 0.0 + 5.0*sin(4.80)          | -4.9808
#  8    | 5.60         | X = 0.0 + 8.0*cos(5.60)        | 6.2045       | Y = 0.0 + 5.0*sin(5.60)          | -3.1563
#  9    | 6.28         | X = 0.0 + 8.0*cos(6.28)        | 8.0000       | Y = 0.0 + 5.0*sin(6.28)          | -0.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA ELIPS - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 8.0 * cos(θ)  |  y(θ) = 0.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 8.0*cos(0.00)        | 8.0000       | Y = 0.0 + 5.0*sin(0.00)          | 0.0000
#  2    | 0.10         | X = 0.0 + 8.0*cos(0.10)        | 7.9600       | Y = 0.0 + 5.0*sin(0.10)          | 0.4992
#  3    | 0.20         | X = 0.0 + 8.0*cos(0.20)        | 7.8405       | Y = 0.0 + 5.0*sin(0.20)          | 0.9933
#  4    | 0.30         | X = 0.0 + 8.0*cos(0.30)        | 7.6427       | Y = 0.0 + 5.0*sin(0.30)          | 1.4776
#  5    | 0.40         | X = 0.0 + 8.0*cos(0.40)        | 7.3685       | Y = 0.0 + 5.0*sin(0.40)          | 1.9471
#  6    | 0.50         | X = 0.0 + 8.0*cos(0.50)        | 7.0207       | Y = 0.0 + 5.0*sin(0.50)          | 2.3971
#  7    | 0.60         | X = 0.0 + 8.0*cos(0.60)        | 6.6027       | Y = 0.0 + 5.0*sin(0.60)          | 2.8232
#  8    | 0.70         | X = 0.0 + 8.0*cos(0.70)        | 6.1187       | Y = 0.0 + 5.0*sin(0.70)          | 3.2211
#  9    | 0.80         | X = 0.0 + 8.0*cos(0.80)        | 5.5737       | Y = 0.0 + 5.0*sin(0.80)          | 3.5868
#  10   | 0.90         | X = 0.0 + 8.0*cos(0.90)        | 4.9729       | Y = 0.0 + 5.0*sin(0.90)          | 3.9166
#  11   | 1.00         | X = 0.0 + 8.0*cos(1.00)        | 4.3224       | Y = 0.0 + 5.0*sin(1.00)          | 4.2074
#  12   | 1.10         | X = 0.0 + 8.0*cos(1.10)        | 3.6288       | Y = 0.0 + 5.0*sin(1.10)          | 4.4560
#  13   | 1.20         | X = 0.0 + 8.0*cos(1.20)        | 2.8989       | Y = 0.0 + 5.0*sin(1.20)          | 4.6602
#  14   | 1.30         | X = 0.0 + 8.0*cos(1.30)        | 2.1400       | Y = 0.0 + 5.0*sin(1.30)          | 4.8178
#  15   | 1.40         | X = 0.0 + 8.0*cos(1.40)        | 1.3597       | Y = 0.0 + 5.0*sin(1.40)          | 4.9272
#  16   | 1.50         | X = 0.0 + 8.0*cos(1.50)        | 0.5659       | Y = 0.0 + 5.0*sin(1.50)          | 4.9875
#  17   | 1.60         | X = 0.0 + 8.0*cos(1.60)        | -0.2336      | Y = 0.0 + 5.0*sin(1.60)          | 4.9979
#  18   | 1.70         | X = 0.0 + 8.0*cos(1.70)        | -1.0308      | Y = 0.0 + 5.0*sin(1.70)          | 4.9583
#  19   | 1.80         | X = 0.0 + 8.0*cos(1.80)        | -1.8176      | Y = 0.0 + 5.0*sin(1.80)          | 4.8692
#  20   | 1.90         | X = 0.0 + 8.0*cos(1.90)        | -2.5863      | Y = 0.0 + 5.0*sin(1.90)          | 4.7315
#  21   | 2.00         | X = 0.0 + 8.0*cos(2.00)        | -3.3292      | Y = 0.0 + 5.0*sin(2.00)          | 4.5465
#  22   | 2.10         | X = 0.0 + 8.0*cos(2.10)        | -4.0388      | Y = 0.0 + 5.0*sin(2.10)          | 4.3160
#  23   | 2.20         | X = 0.0 + 8.0*cos(2.20)        | -4.7080      | Y = 0.0 + 5.0*sin(2.20)          | 4.0425
#  24   | 2.30         | X = 0.0 + 8.0*cos(2.30)        | -5.3302      | Y = 0.0 + 5.0*sin(2.30)          | 3.7285
#  25   | 2.40         | X = 0.0 + 8.0*cos(2.40)        | -5.8991      | Y = 0.0 + 5.0*sin(2.40)          | 3.3773
#  26   | 2.50         | X = 0.0 + 8.0*cos(2.50)        | -6.4091      | Y = 0.0 + 5.0*sin(2.50)          | 2.9924
#  27   | 2.60         | X = 0.0 + 8.0*cos(2.60)        | -6.8551      | Y = 0.0 + 5.0*sin(2.60)          | 2.5775
#  28   | 2.70         | X = 0.0 + 8.0*cos(2.70)        | -7.2326      | Y = 0.0 + 5.0*sin(2.70)          | 2.1369
#  29   | 2.80         | X = 0.0 + 8.0*cos(2.80)        | -7.5378      | Y = 0.0 + 5.0*sin(2.80)          | 1.6749
#  30   | 2.90         | X = 0.0 + 8.0*cos(2.90)        | -7.7677      | Y = 0.0 + 5.0*sin(2.90)          | 1.1962
#  31   | 3.00         | X = 0.0 + 8.0*cos(3.00)        | -7.9199      | Y = 0.0 + 5.0*sin(3.00)          | 0.7056
#  32   | 3.10         | X = 0.0 + 8.0*cos(3.10)        | -7.9931      | Y = 0.0 + 5.0*sin(3.10)          | 0.2079
#  33   | 3.20         | X = 0.0 + 8.0*cos(3.20)        | -7.9864      | Y = 0.0 + 5.0*sin(3.20)          | -0.2919
#  34   | 3.30         | X = 0.0 + 8.0*cos(3.30)        | -7.8998      | Y = 0.0 + 5.0*sin(3.30)          | -0.7887
#  35   | 3.40         | X = 0.0 + 8.0*cos(3.40)        | -7.7344      | Y = 0.0 + 5.0*sin(3.40)          | -1.2777
#  36   | 3.50         | X = 0.0 + 8.0*cos(3.50)        | -7.4917      | Y = 0.0 + 5.0*sin(3.50)          | -1.7539
#  37   | 3.60         | X = 0.0 + 8.0*cos(3.60)        | -7.1741      | Y = 0.0 + 5.0*sin(3.60)          | -2.2126
#  38   | 3.70         | X = 0.0 + 8.0*cos(3.70)        | -6.7848      | Y = 0.0 + 5.0*sin(3.70)          | -2.6492
#  39   | 3.80         | X = 0.0 + 8.0*cos(3.80)        | -6.3277      | Y = 0.0 + 5.0*sin(3.80)          | -3.0593
#  40   | 3.90         | X = 0.0 + 8.0*cos(3.90)        | -5.8075      | Y = 0.0 + 5.0*sin(3.90)          | -3.4388
#  41   | 4.00         | X = 0.0 + 8.0*cos(4.00)        | -5.2291      | Y = 0.0 + 5.0*sin(4.00)          | -3.7840
#  42   | 4.10         | X = 0.0 + 8.0*cos(4.10)        | -4.5986      | Y = 0.0 + 5.0*sin(4.10)          | -4.0914
#  43   | 4.20         | X = 0.0 + 8.0*cos(4.20)        | -3.9221      | Y = 0.0 + 5.0*sin(4.20)          | -4.3579
#  44   | 4.30         | X = 0.0 + 8.0*cos(4.30)        | -3.2064      | Y = 0.0 + 5.0*sin(4.30)          | -4.5808
#  45   | 4.40         | X = 0.0 + 8.0*cos(4.40)        | -2.4587      | Y = 0.0 + 5.0*sin(4.40)          | -4.7580
#  46   | 4.50         | X = 0.0 + 8.0*cos(4.50)        | -1.6864      | Y = 0.0 + 5.0*sin(4.50)          | -4.8877
#  47   | 4.60         | X = 0.0 + 8.0*cos(4.60)        | -0.8972      | Y = 0.0 + 5.0*sin(4.60)          | -4.9685
#  48   | 4.70         | X = 0.0 + 8.0*cos(4.70)        | -0.0991      | Y = 0.0 + 5.0*sin(4.70)          | -4.9996
#  49   | 4.80         | X = 0.0 + 8.0*cos(4.80)        | 0.7000       | Y = 0.0 + 5.0*sin(4.80)          | -4.9808
#  50   | 4.90         | X = 0.0 + 8.0*cos(4.90)        | 1.4921       | Y = 0.0 + 5.0*sin(4.90)          | -4.9123
#  51   | 5.00         | X = 0.0 + 8.0*cos(5.00)        | 2.2693       | Y = 0.0 + 5.0*sin(5.00)          | -4.7946
#  52   | 5.10         | X = 0.0 + 8.0*cos(5.10)        | 3.0238       | Y = 0.0 + 5.0*sin(5.10)          | -4.6291
#  53   | 5.20         | X = 0.0 + 8.0*cos(5.20)        | 3.7481       | Y = 0.0 + 5.0*sin(5.20)          | -4.4173
#  54   | 5.30         | X = 0.0 + 8.0*cos(5.30)        | 4.4350       | Y = 0.0 + 5.0*sin(5.30)          | -4.1613
#  55   | 5.40         | X = 0.0 + 8.0*cos(5.40)        | 5.0775       | Y = 0.0 + 5.0*sin(5.40)          | -3.8638
#  56   | 5.50         | X = 0.0 + 8.0*cos(5.50)        | 5.6694       | Y = 0.0 + 5.0*sin(5.50)          | -3.5277
#  57   | 5.60         | X = 0.0 + 8.0*cos(5.60)        | 6.2045       | Y = 0.0 + 5.0*sin(5.60)          | -3.1563
#  58   | 5.70         | X = 0.0 + 8.0*cos(5.70)        | 6.6777       | Y = 0.0 + 5.0*sin(5.70)          | -2.7534
#  59   | 5.80         | X = 0.0 + 8.0*cos(5.80)        | 7.0842       | Y = 0.0 + 5.0*sin(5.80)          | -2.3230
#  60   | 5.90         | X = 0.0 + 8.0*cos(5.90)        | 7.4198       | Y = 0.0 + 5.0*sin(5.90)          | -1.8694
#  61   | 6.00         | X = 0.0 + 8.0*cos(6.00)        | 7.6814       | Y = 0.0 + 5.0*sin(6.00)          | -1.3971
#  62   | 6.10         | X = 0.0 + 8.0*cos(6.10)        | 7.8661       | Y = 0.0 + 5.0*sin(6.10)          | -0.9108
#  63   | 6.20         | X = 0.0 + 8.0*cos(6.20)        | 7.9723       | Y = 0.0 + 5.0*sin(6.20)          | -0.4154
#  64   | 6.28         | X = 0.0 + 8.0*cos(6.28)        | 8.0000       | Y = 0.0 + 5.0*sin(6.28)          | -0.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA ELIPS PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA ELIPS - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 9.0 * cos(θ)  |  y(θ) = 0.0 + 3.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 9.0*cos(0.00)        | 9.0000       | Y = 0.0 + 3.0*sin(0.00)          | 0.0000
#  2    | 0.50         | X = 0.0 + 9.0*cos(0.50)        | 7.8982       | Y = 0.0 + 3.0*sin(0.50)          | 1.4383
#  3    | 1.00         | X = 0.0 + 9.0*cos(1.00)        | 4.8627       | Y = 0.0 + 3.0*sin(1.00)          | 2.5244
#  4    | 1.50         | X = 0.0 + 9.0*cos(1.50)        | 0.6366       | Y = 0.0 + 3.0*sin(1.50)          | 2.9925
#  5    | 2.00         | X = 0.0 + 9.0*cos(2.00)        | -3.7453      | Y = 0.0 + 3.0*sin(2.00)          | 2.7279
#  6    | 2.50         | X = 0.0 + 9.0*cos(2.50)        | -7.2103      | Y = 0.0 + 3.0*sin(2.50)          | 1.7954
#  7    | 3.00         | X = 0.0 + 9.0*cos(3.00)        | -8.9099      | Y = 0.0 + 3.0*sin(3.00)          | 0.4234
#  8    | 3.50         | X = 0.0 + 9.0*cos(3.50)        | -8.4281      | Y = 0.0 + 3.0*sin(3.50)          | -1.0523
#  9    | 4.00         | X = 0.0 + 9.0*cos(4.00)        | -5.8828      | Y = 0.0 + 3.0*sin(4.00)          | -2.2704
#  10   | 4.50         | X = 0.0 + 9.0*cos(4.50)        | -1.8972      | Y = 0.0 + 3.0*sin(4.50)          | -2.9326
#  11   | 5.00         | X = 0.0 + 9.0*cos(5.00)        | 2.5530       | Y = 0.0 + 3.0*sin(5.00)          | -2.8768
#  12   | 5.50         | X = 0.0 + 9.0*cos(5.50)        | 6.3780       | Y = 0.0 + 3.0*sin(5.50)          | -2.1166
#  13   | 6.00         | X = 0.0 + 9.0*cos(6.00)        | 8.6415       | Y = 0.0 + 3.0*sin(6.00)          | -0.8382
#  14   | 6.28         | X = 0.0 + 9.0*cos(6.28)        | 9.0000       | Y = 0.0 + 3.0*sin(6.28)          | -0.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA ELIPS - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 9.0 * cos(θ)  |  y(θ) = 0.0 + 3.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 9.0*cos(0.00)        | 9.0000       | Y = 0.0 + 3.0*sin(0.00)          | 0.0000
#  2    | 0.02         | X = 0.0 + 9.0*cos(0.02)        | 8.9982       | Y = 0.0 + 3.0*sin(0.02)          | 0.0600
#  3    | 0.04         | X = 0.0 + 9.0*cos(0.04)        | 8.9928       | Y = 0.0 + 3.0*sin(0.04)          | 0.1200
#  4    | 0.06         | X = 0.0 + 9.0*cos(0.06)        | 8.9838       | Y = 0.0 + 3.0*sin(0.06)          | 0.1799
#  5    | 0.08         | X = 0.0 + 9.0*cos(0.08)        | 8.9712       | Y = 0.0 + 3.0*sin(0.08)          | 0.2397
#  6    | 0.10         | X = 0.0 + 9.0*cos(0.10)        | 8.9550       | Y = 0.0 + 3.0*sin(0.10)          | 0.2995
#  7    | 0.12         | X = 0.0 + 9.0*cos(0.12)        | 8.9353       | Y = 0.0 + 3.0*sin(0.12)          | 0.3591
#  8    | 0.14         | X = 0.0 + 9.0*cos(0.14)        | 8.9119       | Y = 0.0 + 3.0*sin(0.14)          | 0.4186
#  9    | 0.16         | X = 0.0 + 9.0*cos(0.16)        | 8.8850       | Y = 0.0 + 3.0*sin(0.16)          | 0.4780
#  10   | 0.18         | X = 0.0 + 9.0*cos(0.18)        | 8.8546       | Y = 0.0 + 3.0*sin(0.18)          | 0.5371
#  11   | 0.20         | X = 0.0 + 9.0*cos(0.20)        | 8.8206       | Y = 0.0 + 3.0*sin(0.20)          | 0.5960
#  12   | 0.22         | X = 0.0 + 9.0*cos(0.22)        | 8.7831       | Y = 0.0 + 3.0*sin(0.22)          | 0.6547
#  13   | 0.24         | X = 0.0 + 9.0*cos(0.24)        | 8.7420       | Y = 0.0 + 3.0*sin(0.24)          | 0.7131
#  14   | 0.26         | X = 0.0 + 9.0*cos(0.26)        | 8.6975       | Y = 0.0 + 3.0*sin(0.26)          | 0.7712
#  15   | 0.28         | X = 0.0 + 9.0*cos(0.28)        | 8.6495       | Y = 0.0 + 3.0*sin(0.28)          | 0.8291
#  16   | 0.30         | X = 0.0 + 9.0*cos(0.30)        | 8.5980       | Y = 0.0 + 3.0*sin(0.30)          | 0.8866
#  17   | 0.32         | X = 0.0 + 9.0*cos(0.32)        | 8.5431       | Y = 0.0 + 3.0*sin(0.32)          | 0.9437
#  18   | 0.34         | X = 0.0 + 9.0*cos(0.34)        | 8.4848       | Y = 0.0 + 3.0*sin(0.34)          | 1.0005
#  19   | 0.36         | X = 0.0 + 9.0*cos(0.36)        | 8.4231       | Y = 0.0 + 3.0*sin(0.36)          | 1.0568
#  20   | 0.38         | X = 0.0 + 9.0*cos(0.38)        | 8.3580       | Y = 0.0 + 3.0*sin(0.38)          | 1.1128
#  21   | 0.40         | X = 0.0 + 9.0*cos(0.40)        | 8.2895       | Y = 0.0 + 3.0*sin(0.40)          | 1.1683
#  22   | 0.42         | X = 0.0 + 9.0*cos(0.42)        | 8.2178       | Y = 0.0 + 3.0*sin(0.42)          | 1.2233
#  23   | 0.44         | X = 0.0 + 9.0*cos(0.44)        | 8.1428       | Y = 0.0 + 3.0*sin(0.44)          | 1.2778
#  24   | 0.46         | X = 0.0 + 9.0*cos(0.46)        | 8.0645       | Y = 0.0 + 3.0*sin(0.46)          | 1.3318
#  25   | 0.48         | X = 0.0 + 9.0*cos(0.48)        | 7.9830       | Y = 0.0 + 3.0*sin(0.48)          | 1.3853
#  26   | 0.50         | X = 0.0 + 9.0*cos(0.50)        | 7.8982       | Y = 0.0 + 3.0*sin(0.50)          | 1.4383
#  27   | 0.52         | X = 0.0 + 9.0*cos(0.52)        | 7.8104       | Y = 0.0 + 3.0*sin(0.52)          | 1.4906
#  28   | 0.54         | X = 0.0 + 9.0*cos(0.54)        | 7.7194       | Y = 0.0 + 3.0*sin(0.54)          | 1.5424
#  29   | 0.56         | X = 0.0 + 9.0*cos(0.56)        | 7.6253       | Y = 0.0 + 3.0*sin(0.56)          | 1.5936
#  30   | 0.58         | X = 0.0 + 9.0*cos(0.58)        | 7.5282       | Y = 0.0 + 3.0*sin(0.58)          | 1.6441
#  31   | 0.60         | X = 0.0 + 9.0*cos(0.60)        | 7.4280       | Y = 0.0 + 3.0*sin(0.60)          | 1.6939
#  32   | 0.62         | X = 0.0 + 9.0*cos(0.62)        | 7.3249       | Y = 0.0 + 3.0*sin(0.62)          | 1.7431
#  33   | 0.64         | X = 0.0 + 9.0*cos(0.64)        | 7.2189       | Y = 0.0 + 3.0*sin(0.64)          | 1.7916
#  34   | 0.66         | X = 0.0 + 9.0*cos(0.66)        | 7.1099       | Y = 0.0 + 3.0*sin(0.66)          | 1.8394
#  35   | 0.68         | X = 0.0 + 9.0*cos(0.68)        | 6.9982       | Y = 0.0 + 3.0*sin(0.68)          | 1.8864
#  36   | 0.70         | X = 0.0 + 9.0*cos(0.70)        | 6.8836       | Y = 0.0 + 3.0*sin(0.70)          | 1.9327
#  37   | 0.72         | X = 0.0 + 9.0*cos(0.72)        | 6.7663       | Y = 0.0 + 3.0*sin(0.72)          | 1.9782
#  38   | 0.74         | X = 0.0 + 9.0*cos(0.74)        | 6.6462       | Y = 0.0 + 3.0*sin(0.74)          | 2.0229
#  39   | 0.76         | X = 0.0 + 9.0*cos(0.76)        | 6.5235       | Y = 0.0 + 3.0*sin(0.76)          | 2.0668
#  40   | 0.78         | X = 0.0 + 9.0*cos(0.78)        | 6.3982       | Y = 0.0 + 3.0*sin(0.78)          | 2.1098
#  41   | 0.80         | X = 0.0 + 9.0*cos(0.80)        | 6.2704       | Y = 0.0 + 3.0*sin(0.80)          | 2.1521
#  42   | 0.82         | X = 0.0 + 9.0*cos(0.82)        | 6.1400       | Y = 0.0 + 3.0*sin(0.82)          | 2.1934
#  43   | 0.84         | X = 0.0 + 9.0*cos(0.84)        | 6.0072       | Y = 0.0 + 3.0*sin(0.84)          | 2.2339
#  44   | 0.86         | X = 0.0 + 9.0*cos(0.86)        | 5.8719       | Y = 0.0 + 3.0*sin(0.86)          | 2.2735
#  45   | 0.88         | X = 0.0 + 9.0*cos(0.88)        | 5.7344       | Y = 0.0 + 3.0*sin(0.88)          | 2.3122
#  46   | 0.90         | X = 0.0 + 9.0*cos(0.90)        | 5.5945       | Y = 0.0 + 3.0*sin(0.90)          | 2.3500
#  47   | 0.92         | X = 0.0 + 9.0*cos(0.92)        | 5.4524       | Y = 0.0 + 3.0*sin(0.92)          | 2.3868
#  48   | 0.94         | X = 0.0 + 9.0*cos(0.94)        | 5.3081       | Y = 0.0 + 3.0*sin(0.94)          | 2.4227
#  49   | 0.96         | X = 0.0 + 9.0*cos(0.96)        | 5.1617       | Y = 0.0 + 3.0*sin(0.96)          | 2.4576
#  50   | 0.98         | X = 0.0 + 9.0*cos(0.98)        | 5.0132       | Y = 0.0 + 3.0*sin(0.98)          | 2.4915
#  51   | 1.00         | X = 0.0 + 9.0*cos(1.00)        | 4.8627       | Y = 0.0 + 3.0*sin(1.00)          | 2.5244
#  52   | 1.02         | X = 0.0 + 9.0*cos(1.02)        | 4.7103       | Y = 0.0 + 3.0*sin(1.02)          | 2.5563
#  53   | 1.04         | X = 0.0 + 9.0*cos(1.04)        | 4.5560       | Y = 0.0 + 3.0*sin(1.04)          | 2.5872
#  54   | 1.06         | X = 0.0 + 9.0*cos(1.06)        | 4.3998       | Y = 0.0 + 3.0*sin(1.06)          | 2.6171
#  55   | 1.08         | X = 0.0 + 9.0*cos(1.08)        | 4.2420       | Y = 0.0 + 3.0*sin(1.08)          | 2.6459
#  56   | 1.10         | X = 0.0 + 9.0*cos(1.10)        | 4.0824       | Y = 0.0 + 3.0*sin(1.10)          | 2.6736
#  57   | 1.12         | X = 0.0 + 9.0*cos(1.12)        | 3.9211       | Y = 0.0 + 3.0*sin(1.12)          | 2.7003
#  58   | 1.14         | X = 0.0 + 9.0*cos(1.14)        | 3.7584       | Y = 0.0 + 3.0*sin(1.14)          | 2.7259
#  59   | 1.16         | X = 0.0 + 9.0*cos(1.16)        | 3.5941       | Y = 0.0 + 3.0*sin(1.16)          | 2.7504
#  60   | 1.18         | X = 0.0 + 9.0*cos(1.18)        | 3.4283       | Y = 0.0 + 3.0*sin(1.18)          | 2.7738
#  61   | 1.20         | X = 0.0 + 9.0*cos(1.20)        | 3.2612       | Y = 0.0 + 3.0*sin(1.20)          | 2.7961
#  62   | 1.22         | X = 0.0 + 9.0*cos(1.22)        | 3.0928       | Y = 0.0 + 3.0*sin(1.22)          | 2.8173
#  63   | 1.24         | X = 0.0 + 9.0*cos(1.24)        | 2.9232       | Y = 0.0 + 3.0*sin(1.24)          | 2.8374
#  64   | 1.26         | X = 0.0 + 9.0*cos(1.26)        | 2.7524       | Y = 0.0 + 3.0*sin(1.26)          | 2.8563
#  65   | 1.28         | X = 0.0 + 9.0*cos(1.28)        | 2.5804       | Y = 0.0 + 3.0*sin(1.28)          | 2.8740
#  66   | 1.30         | X = 0.0 + 9.0*cos(1.30)        | 2.4075       | Y = 0.0 + 3.0*sin(1.30)          | 2.8907
#  67   | 1.32         | X = 0.0 + 9.0*cos(1.32)        | 2.2336       | Y = 0.0 + 3.0*sin(1.32)          | 2.9061
#  68   | 1.34         | X = 0.0 + 9.0*cos(1.34)        | 2.0588       | Y = 0.0 + 3.0*sin(1.34)          | 2.9205
#  69   | 1.36         | X = 0.0 + 9.0*cos(1.36)        | 1.8831       | Y = 0.0 + 3.0*sin(1.36)          | 2.9336
#  70   | 1.38         | X = 0.0 + 9.0*cos(1.38)        | 1.7068       | Y = 0.0 + 3.0*sin(1.38)          | 2.9456
#  71   | 1.40         | X = 0.0 + 9.0*cos(1.40)        | 1.5297       | Y = 0.0 + 3.0*sin(1.40)          | 2.9563
#  72   | 1.42         | X = 0.0 + 9.0*cos(1.42)        | 1.3520       | Y = 0.0 + 3.0*sin(1.42)          | 2.9660
#  73   | 1.44         | X = 0.0 + 9.0*cos(1.44)        | 1.1738       | Y = 0.0 + 3.0*sin(1.44)          | 2.9744
#  74   | 1.46         | X = 0.0 + 9.0*cos(1.46)        | 0.9951       | Y = 0.0 + 3.0*sin(1.46)          | 2.9816
#  75   | 1.48         | X = 0.0 + 9.0*cos(1.48)        | 0.8160       | Y = 0.0 + 3.0*sin(1.48)          | 2.9876
#  76   | 1.50         | X = 0.0 + 9.0*cos(1.50)        | 0.6366       | Y = 0.0 + 3.0*sin(1.50)          | 2.9925
#  77   | 1.52         | X = 0.0 + 9.0*cos(1.52)        | 0.4570       | Y = 0.0 + 3.0*sin(1.52)          | 2.9961
#  78   | 1.54         | X = 0.0 + 9.0*cos(1.54)        | 0.2771       | Y = 0.0 + 3.0*sin(1.54)          | 2.9986
#  79   | 1.56         | X = 0.0 + 9.0*cos(1.56)        | 0.0972       | Y = 0.0 + 3.0*sin(1.56)          | 2.9998
#  80   | 1.58         | X = 0.0 + 9.0*cos(1.58)        | -0.0828      | Y = 0.0 + 3.0*sin(1.58)          | 2.9999
#  81   | 1.60         | X = 0.0 + 9.0*cos(1.60)        | -0.2628      | Y = 0.0 + 3.0*sin(1.60)          | 2.9987
#  82   | 1.62         | X = 0.0 + 9.0*cos(1.62)        | -0.4427      | Y = 0.0 + 3.0*sin(1.62)          | 2.9964
#  83   | 1.64         | X = 0.0 + 9.0*cos(1.64)        | -0.6223      | Y = 0.0 + 3.0*sin(1.64)          | 2.9928
#  84   | 1.66         | X = 0.0 + 9.0*cos(1.66)        | -0.8018      | Y = 0.0 + 3.0*sin(1.66)          | 2.9881
#  85   | 1.68         | X = 0.0 + 9.0*cos(1.68)        | -0.9809      | Y = 0.0 + 3.0*sin(1.68)          | 2.9821
#  86   | 1.70         | X = 0.0 + 9.0*cos(1.70)        | -1.1596      | Y = 0.0 + 3.0*sin(1.70)          | 2.9750
#  87   | 1.72         | X = 0.0 + 9.0*cos(1.72)        | -1.3379      | Y = 0.0 + 3.0*sin(1.72)          | 2.9667
#  88   | 1.74         | X = 0.0 + 9.0*cos(1.74)        | -1.5156      | Y = 0.0 + 3.0*sin(1.74)          | 2.9572
#  89   | 1.76         | X = 0.0 + 9.0*cos(1.76)        | -1.6927      | Y = 0.0 + 3.0*sin(1.76)          | 2.9465
#  90   | 1.78         | X = 0.0 + 9.0*cos(1.78)        | -1.8691      | Y = 0.0 + 3.0*sin(1.78)          | 2.9346
#  91   | 1.80         | X = 0.0 + 9.0*cos(1.80)        | -2.0448      | Y = 0.0 + 3.0*sin(1.80)          | 2.9215
#  92   | 1.82         | X = 0.0 + 9.0*cos(1.82)        | -2.2197      | Y = 0.0 + 3.0*sin(1.82)          | 2.9073
#  93   | 1.84         | X = 0.0 + 9.0*cos(1.84)        | -2.3937      | Y = 0.0 + 3.0*sin(1.84)          | 2.8919
#  94   | 1.86         | X = 0.0 + 9.0*cos(1.86)        | -2.5667      | Y = 0.0 + 3.0*sin(1.86)          | 2.8754
#  95   | 1.88         | X = 0.0 + 9.0*cos(1.88)        | -2.7387      | Y = 0.0 + 3.0*sin(1.88)          | 2.8577
#  96   | 1.90         | X = 0.0 + 9.0*cos(1.90)        | -2.9096      | Y = 0.0 + 3.0*sin(1.90)          | 2.8389
#  97   | 1.92         | X = 0.0 + 9.0*cos(1.92)        | -3.0793      | Y = 0.0 + 3.0*sin(1.92)          | 2.8189
#  98   | 1.94         | X = 0.0 + 9.0*cos(1.94)        | -3.2479      | Y = 0.0 + 3.0*sin(1.94)          | 2.7978
#  99   | 1.96         | X = 0.0 + 9.0*cos(1.96)        | -3.4151      | Y = 0.0 + 3.0*sin(1.96)          | 2.7756
#  100  | 1.98         | X = 0.0 + 9.0*cos(1.98)        | -3.5809      | Y = 0.0 + 3.0*sin(1.98)          | 2.7523
#  101  | 2.00         | X = 0.0 + 9.0*cos(2.00)        | -3.7453      | Y = 0.0 + 3.0*sin(2.00)          | 2.7279
#  102  | 2.02         | X = 0.0 + 9.0*cos(2.02)        | -3.9082      | Y = 0.0 + 3.0*sin(2.02)          | 2.7024
#  103  | 2.04         | X = 0.0 + 9.0*cos(2.04)        | -4.0696      | Y = 0.0 + 3.0*sin(2.04)          | 2.6758
#  104  | 2.06         | X = 0.0 + 9.0*cos(2.06)        | -4.2293      | Y = 0.0 + 3.0*sin(2.06)          | 2.6481
#  105  | 2.08         | X = 0.0 + 9.0*cos(2.08)        | -4.3873      | Y = 0.0 + 3.0*sin(2.08)          | 2.6194
#  106  | 2.10         | X = 0.0 + 9.0*cos(2.10)        | -4.5436      | Y = 0.0 + 3.0*sin(2.10)          | 2.5896
#  107  | 2.12         | X = 0.0 + 9.0*cos(2.12)        | -4.6981      | Y = 0.0 + 3.0*sin(2.12)          | 2.5588
#  108  | 2.14         | X = 0.0 + 9.0*cos(2.14)        | -4.8507      | Y = 0.0 + 3.0*sin(2.14)          | 2.5270
#  109  | 2.16         | X = 0.0 + 9.0*cos(2.16)        | -5.0013      | Y = 0.0 + 3.0*sin(2.16)          | 2.4942
#  110  | 2.18         | X = 0.0 + 9.0*cos(2.18)        | -5.1499      | Y = 0.0 + 3.0*sin(2.18)          | 2.4603
#  111  | 2.20         | X = 0.0 + 9.0*cos(2.20)        | -5.2965      | Y = 0.0 + 3.0*sin(2.20)          | 2.4255
#  112  | 2.22         | X = 0.0 + 9.0*cos(2.22)        | -5.4410      | Y = 0.0 + 3.0*sin(2.22)          | 2.3897
#  113  | 2.24         | X = 0.0 + 9.0*cos(2.24)        | -5.5833      | Y = 0.0 + 3.0*sin(2.24)          | 2.3529
#  114  | 2.26         | X = 0.0 + 9.0*cos(2.26)        | -5.7233      | Y = 0.0 + 3.0*sin(2.26)          | 2.3153
#  115  | 2.28         | X = 0.0 + 9.0*cos(2.28)        | -5.8611      | Y = 0.0 + 3.0*sin(2.28)          | 2.2766
#  116  | 2.30         | X = 0.0 + 9.0*cos(2.30)        | -5.9965      | Y = 0.0 + 3.0*sin(2.30)          | 2.2371
#  117  | 2.32         | X = 0.0 + 9.0*cos(2.32)        | -6.1295      | Y = 0.0 + 3.0*sin(2.32)          | 2.1967
#  118  | 2.34         | X = 0.0 + 9.0*cos(2.34)        | -6.2601      | Y = 0.0 + 3.0*sin(2.34)          | 2.1554
#  119  | 2.36         | X = 0.0 + 9.0*cos(2.36)        | -6.3881      | Y = 0.0 + 3.0*sin(2.36)          | 2.1132
#  120  | 2.38         | X = 0.0 + 9.0*cos(2.38)        | -6.5136      | Y = 0.0 + 3.0*sin(2.38)          | 2.0702
#  121  | 2.40         | X = 0.0 + 9.0*cos(2.40)        | -6.6365      | Y = 0.0 + 3.0*sin(2.40)          | 2.0264
#  122  | 2.42         | X = 0.0 + 9.0*cos(2.42)        | -6.7568      | Y = 0.0 + 3.0*sin(2.42)          | 1.9817
#  123  | 2.44         | X = 0.0 + 9.0*cos(2.44)        | -6.8743      | Y = 0.0 + 3.0*sin(2.44)          | 1.9363
#  124  | 2.46         | X = 0.0 + 9.0*cos(2.46)        | -6.9891      | Y = 0.0 + 3.0*sin(2.46)          | 1.8901
#  125  | 2.48         | X = 0.0 + 9.0*cos(2.48)        | -7.1011      | Y = 0.0 + 3.0*sin(2.48)          | 1.8431
#  126  | 2.50         | X = 0.0 + 9.0*cos(2.50)        | -7.2103      | Y = 0.0 + 3.0*sin(2.50)          | 1.7954
#  127  | 2.52         | X = 0.0 + 9.0*cos(2.52)        | -7.3166      | Y = 0.0 + 3.0*sin(2.52)          | 1.7470
#  128  | 2.54         | X = 0.0 + 9.0*cos(2.54)        | -7.4199      | Y = 0.0 + 3.0*sin(2.54)          | 1.6979
#  129  | 2.56         | X = 0.0 + 9.0*cos(2.56)        | -7.5203      | Y = 0.0 + 3.0*sin(2.56)          | 1.6481
#  130  | 2.58         | X = 0.0 + 9.0*cos(2.58)        | -7.6177      | Y = 0.0 + 3.0*sin(2.58)          | 1.5976
#  131  | 2.60         | X = 0.0 + 9.0*cos(2.60)        | -7.7120      | Y = 0.0 + 3.0*sin(2.60)          | 1.5465
#  132  | 2.62         | X = 0.0 + 9.0*cos(2.62)        | -7.8032      | Y = 0.0 + 3.0*sin(2.62)          | 1.4948
#  133  | 2.64         | X = 0.0 + 9.0*cos(2.64)        | -7.8914      | Y = 0.0 + 3.0*sin(2.64)          | 1.4425
#  134  | 2.66         | X = 0.0 + 9.0*cos(2.66)        | -7.9763      | Y = 0.0 + 3.0*sin(2.66)          | 1.3896
#  135  | 2.68         | X = 0.0 + 9.0*cos(2.68)        | -8.0581      | Y = 0.0 + 3.0*sin(2.68)          | 1.3361
#  136  | 2.70         | X = 0.0 + 9.0*cos(2.70)        | -8.1366      | Y = 0.0 + 3.0*sin(2.70)          | 1.2821
#  137  | 2.72         | X = 0.0 + 9.0*cos(2.72)        | -8.2119      | Y = 0.0 + 3.0*sin(2.72)          | 1.2276
#  138  | 2.74         | X = 0.0 + 9.0*cos(2.74)        | -8.2840      | Y = 0.0 + 3.0*sin(2.74)          | 1.1727
#  139  | 2.76         | X = 0.0 + 9.0*cos(2.76)        | -8.3527      | Y = 0.0 + 3.0*sin(2.76)          | 1.1172
#  140  | 2.78         | X = 0.0 + 9.0*cos(2.78)        | -8.4180      | Y = 0.0 + 3.0*sin(2.78)          | 1.0613
#  141  | 2.80         | X = 0.0 + 9.0*cos(2.80)        | -8.4800      | Y = 0.0 + 3.0*sin(2.80)          | 1.0050
#  142  | 2.82         | X = 0.0 + 9.0*cos(2.82)        | -8.5386      | Y = 0.0 + 3.0*sin(2.82)          | 0.9482
#  143  | 2.84         | X = 0.0 + 9.0*cos(2.84)        | -8.5938      | Y = 0.0 + 3.0*sin(2.84)          | 0.8911
#  144  | 2.86         | X = 0.0 + 9.0*cos(2.86)        | -8.6455      | Y = 0.0 + 3.0*sin(2.86)          | 0.8337
#  145  | 2.88         | X = 0.0 + 9.0*cos(2.88)        | -8.6938      | Y = 0.0 + 3.0*sin(2.88)          | 0.7759
#  146  | 2.90         | X = 0.0 + 9.0*cos(2.90)        | -8.7386      | Y = 0.0 + 3.0*sin(2.90)          | 0.7177
#  147  | 2.92         | X = 0.0 + 9.0*cos(2.92)        | -8.7799      | Y = 0.0 + 3.0*sin(2.92)          | 0.6594
#  148  | 2.94         | X = 0.0 + 9.0*cos(2.94)        | -8.8177      | Y = 0.0 + 3.0*sin(2.94)          | 0.6007
#  149  | 2.96         | X = 0.0 + 9.0*cos(2.96)        | -8.8520      | Y = 0.0 + 3.0*sin(2.96)          | 0.5418
#  150  | 2.98         | X = 0.0 + 9.0*cos(2.98)        | -8.8828      | Y = 0.0 + 3.0*sin(2.98)          | 0.4827
#  151  | 3.00         | X = 0.0 + 9.0*cos(3.00)        | -8.9099      | Y = 0.0 + 3.0*sin(3.00)          | 0.4234
#  152  | 3.02         | X = 0.0 + 9.0*cos(3.02)        | -8.9336      | Y = 0.0 + 3.0*sin(3.02)          | 0.3639
#  153  | 3.04         | X = 0.0 + 9.0*cos(3.04)        | -8.9536      | Y = 0.0 + 3.0*sin(3.04)          | 0.3043
#  154  | 3.06         | X = 0.0 + 9.0*cos(3.06)        | -8.9701      | Y = 0.0 + 3.0*sin(3.06)          | 0.2445
#  155  | 3.08         | X = 0.0 + 9.0*cos(3.08)        | -8.9829      | Y = 0.0 + 3.0*sin(3.08)          | 0.1847
#  156  | 3.10         | X = 0.0 + 9.0*cos(3.10)        | -8.9922      | Y = 0.0 + 3.0*sin(3.10)          | 0.1247
#  157  | 3.12         | X = 0.0 + 9.0*cos(3.12)        | -8.9979      | Y = 0.0 + 3.0*sin(3.12)          | 0.0648
#  158  | 3.14         | X = 0.0 + 9.0*cos(3.14)        | -9.0000      | Y = 0.0 + 3.0*sin(3.14)          | 0.0048
#  159  | 3.16         | X = 0.0 + 9.0*cos(3.16)        | -8.9985      | Y = 0.0 + 3.0*sin(3.16)          | -0.0552
#  160  | 3.18         | X = 0.0 + 9.0*cos(3.18)        | -8.9934      | Y = 0.0 + 3.0*sin(3.18)          | -0.1152
#  161  | 3.20         | X = 0.0 + 9.0*cos(3.20)        | -8.9847      | Y = 0.0 + 3.0*sin(3.20)          | -0.1751
#  162  | 3.22         | X = 0.0 + 9.0*cos(3.22)        | -8.9723      | Y = 0.0 + 3.0*sin(3.22)          | -0.2350
#  163  | 3.24         | X = 0.0 + 9.0*cos(3.24)        | -8.9565      | Y = 0.0 + 3.0*sin(3.24)          | -0.2947
#  164  | 3.26         | X = 0.0 + 9.0*cos(3.26)        | -8.9370      | Y = 0.0 + 3.0*sin(3.26)          | -0.3544
#  165  | 3.28         | X = 0.0 + 9.0*cos(3.28)        | -8.9139      | Y = 0.0 + 3.0*sin(3.28)          | -0.4139
#  166  | 3.30         | X = 0.0 + 9.0*cos(3.30)        | -8.8873      | Y = 0.0 + 3.0*sin(3.30)          | -0.4732
#  167  | 3.32         | X = 0.0 + 9.0*cos(3.32)        | -8.8571      | Y = 0.0 + 3.0*sin(3.32)          | -0.5324
#  168  | 3.34         | X = 0.0 + 9.0*cos(3.34)        | -8.8234      | Y = 0.0 + 3.0*sin(3.34)          | -0.5913
#  169  | 3.36         | X = 0.0 + 9.0*cos(3.36)        | -8.7862      | Y = 0.0 + 3.0*sin(3.36)          | -0.6500
#  170  | 3.38         | X = 0.0 + 9.0*cos(3.38)        | -8.7454      | Y = 0.0 + 3.0*sin(3.38)          | -0.7085
#  171  | 3.40         | X = 0.0 + 9.0*cos(3.40)        | -8.7012      | Y = 0.0 + 3.0*sin(3.40)          | -0.7666
#  172  | 3.42         | X = 0.0 + 9.0*cos(3.42)        | -8.6534      | Y = 0.0 + 3.0*sin(3.42)          | -0.8245
#  173  | 3.44         | X = 0.0 + 9.0*cos(3.44)        | -8.6023      | Y = 0.0 + 3.0*sin(3.44)          | -0.8820
#  174  | 3.46         | X = 0.0 + 9.0*cos(3.46)        | -8.5476      | Y = 0.0 + 3.0*sin(3.46)          | -0.9392
#  175  | 3.48         | X = 0.0 + 9.0*cos(3.48)        | -8.4896      | Y = 0.0 + 3.0*sin(3.48)          | -0.9960
#  176  | 3.50         | X = 0.0 + 9.0*cos(3.50)        | -8.4281      | Y = 0.0 + 3.0*sin(3.50)          | -1.0523
#  177  | 3.52         | X = 0.0 + 9.0*cos(3.52)        | -8.3633      | Y = 0.0 + 3.0*sin(3.52)          | -1.1083
#  178  | 3.54         | X = 0.0 + 9.0*cos(3.54)        | -8.2951      | Y = 0.0 + 3.0*sin(3.54)          | -1.1639
#  179  | 3.56         | X = 0.0 + 9.0*cos(3.56)        | -8.2236      | Y = 0.0 + 3.0*sin(3.56)          | -1.2189
#  180  | 3.58         | X = 0.0 + 9.0*cos(3.58)        | -8.1489      | Y = 0.0 + 3.0*sin(3.58)          | -1.2735
#  181  | 3.60         | X = 0.0 + 9.0*cos(3.60)        | -8.0708      | Y = 0.0 + 3.0*sin(3.60)          | -1.3276
#  182  | 3.62         | X = 0.0 + 9.0*cos(3.62)        | -7.9896      | Y = 0.0 + 3.0*sin(3.62)          | -1.3811
#  183  | 3.64         | X = 0.0 + 9.0*cos(3.64)        | -7.9051      | Y = 0.0 + 3.0*sin(3.64)          | -1.4341
# ...
#  55   | 0.40         | X = 0.0 + 0.40                 | 0.4000       | Y = 0.0 + -0.3*(0.40)²           | -0.0480
#  56   | 0.50         | X = 0.0 + 0.50                 | 0.5000       | Y = 0.0 + -0.3*(0.50)²           | -0.0750
#  57   | 0.60         | X = 0.0 + 0.60                 | 0.6000       | Y = 0.0 + -0.3*(0.60)²           | -0.1080
#  58   | 0.70         | X = 0.0 + 0.70                 | 0.7000       | Y = 0.0 + -0.3*(0.70)²           | -0.1470
#  59   | 0.80         | X = 0.0 + 0.80                 | 0.8000       | Y = 0.0 + -0.3*(0.80)²           | -0.1920
#  60   | 0.90         | X = 0.0 + 0.90                 | 0.9000       | Y = 0.0 + -0.3*(0.90)²           | -0.2430
#  61   | 1.00         | X = 0.0 + 1.00                 | 1.0000       | Y = 0.0 + -0.3*(1.00)²           | -0.3000
#  62   | 1.10         | X = 0.0 + 1.10                 | 1.1000       | Y = 0.0 + -0.3*(1.10)²           | -0.3630
#  63   | 1.20         | X = 0.0 + 1.20                 | 1.2000       | Y = 0.0 + -0.3*(1.20)²           | -0.4320
#  64   | 1.30         | X = 0.0 + 1.30                 | 1.3000       | Y = 0.0 + -0.3*(1.30)²           | -0.5070
#  65   | 1.40         | X = 0.0 + 1.40                 | 1.4000       | Y = 0.0 + -0.3*(1.40)²           | -0.5880
#  66   | 1.50         | X = 0.0 + 1.50                 | 1.5000       | Y = 0.0 + -0.3*(1.50)²           | -0.6750
#  67   | 1.60         | X = 0.0 + 1.60                 | 1.6000       | Y = 0.0 + -0.3*(1.60)²           | -0.7680
#  68   | 1.70         | X = 0.0 + 1.70                 | 1.7000       | Y = 0.0 + -0.3*(1.70)²           | -0.8670
#  69   | 1.80         | X = 0.0 + 1.80                 | 1.8000       | Y = 0.0 + -0.3*(1.80)²           | -0.9720
#  70   | 1.90         | X = 0.0 + 1.90                 | 1.9000       | Y = 0.0 + -0.3*(1.90)²           | -1.0830
#  71   | 2.00         | X = 0.0 + 2.00                 | 2.0000       | Y = 0.0 + -0.3*(2.00)²           | -1.2000
#  72   | 2.10         | X = 0.0 + 2.10                 | 2.1000       | Y = 0.0 + -0.3*(2.10)²           | -1.3230
#  73   | 2.20         | X = 0.0 + 2.20                 | 2.2000       | Y = 0.0 + -0.3*(2.20)²           | -1.4520
#  74   | 2.30         | X = 0.0 + 2.30                 | 2.3000       | Y = 0.0 + -0.3*(2.30)²           | -1.5870
#  75   | 2.40         | X = 0.0 + 2.40                 | 2.4000       | Y = 0.0 + -0.3*(2.40)²           | -1.7280
#  76   | 2.50         | X = 0.0 + 2.50                 | 2.5000       | Y = 0.0 + -0.3*(2.50)²           | -1.8750
#  77   | 2.60         | X = 0.0 + 2.60                 | 2.6000       | Y = 0.0 + -0.3*(2.60)²           | -2.0280
#  78   | 2.70         | X = 0.0 + 2.70                 | 2.7000       | Y = 0.0 + -0.3*(2.70)²           | -2.1870
#  79   | 2.80         | X = 0.0 + 2.80                 | 2.8000       | Y = 0.0 + -0.3*(2.80)²           | -2.3520
#  80   | 2.90         | X = 0.0 + 2.90                 | 2.9000       | Y = 0.0 + -0.3*(2.90)²           | -2.5230
#  81   | 3.00         | X = 0.0 + 3.00                 | 3.0000       | Y = 0.0 + -0.3*(3.00)²           | -2.7000
#  82   | 3.10         | X = 0.0 + 3.10                 | 3.1000       | Y = 0.0 + -0.3*(3.10)²           | -2.8830
#  83   | 3.20         | X = 0.0 + 3.20                 | 3.2000       | Y = 0.0 + -0.3*(3.20)²           | -3.0720
#  84   | 3.30         | X = 0.0 + 3.30                 | 3.3000       | Y = 0.0 + -0.3*(3.30)²           | -3.2670
#  85   | 3.40         | X = 0.0 + 3.40                 | 3.4000       | Y = 0.0 + -0.3*(3.40)²           | -3.4680
#  86   | 3.50         | X = 0.0 + 3.50                 | 3.5000       | Y = 0.0 + -0.3*(3.50)²           | -3.6750
#  87   | 3.60         | X = 0.0 + 3.60                 | 3.6000       | Y = 0.0 + -0.3*(3.60)²           | -3.8880
#  88   | 3.70         | X = 0.0 + 3.70                 | 3.7000       | Y = 0.0 + -0.3*(3.70)²           | -4.1070
#  89   | 3.80         | X = 0.0 + 3.80                 | 3.8000       | Y = 0.0 + -0.3*(3.80)²           | -4.3320
#  90   | 3.90         | X = 0.0 + 3.90                 | 3.9000       | Y = 0.0 + -0.3*(3.90)²           | -4.5630
#  91   | 4.00         | X = 0.0 + 4.00                 | 4.0000       | Y = 0.0 + -0.3*(4.00)²           | -4.8000
#  92   | 4.10         | X = 0.0 + 4.10                 | 4.1000       | Y = 0.0 + -0.3*(4.10)²           | -5.0430
#  93   | 4.20         | X = 0.0 + 4.20                 | 4.2000       | Y = 0.0 + -0.3*(4.20)²           | -5.2920
#  94   | 4.30         | X = 0.0 + 4.30                 | 4.3000       | Y = 0.0 + -0.3*(4.30)²           | -5.5470
#  95   | 4.40         | X = 0.0 + 4.40                 | 4.4000       | Y = 0.0 + -0.3*(4.40)²           | -5.8080
#  96   | 4.50         | X = 0.0 + 4.50                 | 4.5000       | Y = 0.0 + -0.3*(4.50)²           | -6.0750
#  97   | 4.60         | X = 0.0 + 4.60                 | 4.6000       | Y = 0.0 + -0.3*(4.60)²           | -6.3480
#  98   | 4.70         | X = 0.0 + 4.70                 | 4.7000       | Y = 0.0 + -0.3*(4.70)²           | -6.6270
#  99   | 4.80         | X = 0.0 + 4.80                 | 4.8000       | Y = 0.0 + -0.3*(4.80)²           | -6.9120
#  100  | 4.90         | X = 0.0 + 4.90                 | 4.9000       | Y = 0.0 + -0.3*(4.90)²           | -7.2030
#  101  | 5.00         | X = 0.0 + 5.00                 | 5.0000       | Y = 0.0 + -0.3*(5.00)²           | -7.5000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA HIPERBOLA PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA HIPERBOLA (CABANG KANAN) - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + a / cos(θ)  |  y(θ) = yc + b * tan(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 4.0 / cos(θ)  |  y(θ) = 0.0 + 3.0 * tan(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA CABANG KANAN X         | HASIL X      | FORMULA CABANG KANAN Y           | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -1.25        | X = 0.0 + 4.0/cos(-1.25)       | 12.6854      | Y = 0.0 + 3.0*tan(-1.25)         | -9.0287
#  2    | -1.00        | X = 0.0 + 4.0/cos(-1.00)       | 7.4033       | Y = 0.0 + 3.0*tan(-1.00)         | -4.6722
#  3    | -0.75        | X = 0.0 + 4.0/cos(-0.75)       | 5.4668       | Y = 0.0 + 3.0*tan(-0.75)         | -2.7948
#  4    | -0.50        | X = 0.0 + 4.0/cos(-0.50)       | 4.5580       | Y = 0.0 + 3.0*tan(-0.50)         | -1.6389
#  5    | -0.25        | X = 0.0 + 4.0/cos(-0.25)       | 4.1283       | Y = 0.0 + 3.0*tan(-0.25)         | -0.7660
#  6    | 0.00         | X = 0.0 + 4.0/cos(0.00)        | 4.0000       | Y = 0.0 + 3.0*tan(0.00)          | 0.0000
#  7    | 0.25         | X = 0.0 + 4.0/cos(0.25)        | 4.1283       | Y = 0.0 + 3.0*tan(0.25)          | 0.7660
#  8    | 0.50         | X = 0.0 + 4.0/cos(0.50)        | 4.5580       | Y = 0.0 + 3.0*tan(0.50)          | 1.6389
#  9    | 0.75         | X = 0.0 + 4.0/cos(0.75)        | 5.4668       | Y = 0.0 + 3.0*tan(0.75)          | 2.7948
#  10   | 1.00         | X = 0.0 + 4.0/cos(1.00)        | 7.4033       | Y = 0.0 + 3.0*tan(1.00)          | 4.6722
#  11   | 1.25         | X = 0.0 + 4.0/cos(1.25)        | 12.6854      | Y = 0.0 + 3.0*tan(1.25)          | 9.0287
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA HIPERBOLA (CABANG KANAN) - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + a / cos(θ)  |  y(θ) = yc + b * tan(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 4.0 / cos(θ)  |  y(θ) = 0.0 + 3.0 * tan(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA CABANG KANAN X         | HASIL X      | FORMULA CABANG KANAN Y           | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -1.25        | X = 0.0 + 4.0/cos(-1.25)       | 12.6854      | Y = 0.0 + 3.0*tan(-1.25)         | -9.0287
#  2    | -1.20        | X = 0.0 + 4.0/cos(-1.20)       | 11.0388      | Y = 0.0 + 3.0*tan(-1.20)         | -7.7165
#  3    | -1.15        | X = 0.0 + 4.0/cos(-1.15)       | 9.7922       | Y = 0.0 + 3.0*tan(-1.15)         | -6.7035
#  4    | -1.10        | X = 0.0 + 4.0/cos(-1.10)       | 8.8184       | Y = 0.0 + 3.0*tan(-1.10)         | -5.8943
#  5    | -1.05        | X = 0.0 + 4.0/cos(-1.05)       | 8.0391       | Y = 0.0 + 3.0*tan(-1.05)         | -5.2299
#  6    | -1.00        | X = 0.0 + 4.0/cos(-1.00)       | 7.4033       | Y = 0.0 + 3.0*tan(-1.00)         | -4.6722
#  7    | -0.95        | X = 0.0 + 4.0/cos(-0.95)       | 6.8766       | Y = 0.0 + 3.0*tan(-0.95)         | -4.1951
#  8    | -0.90        | X = 0.0 + 4.0/cos(-0.90)       | 6.4349       | Y = 0.0 + 3.0*tan(-0.90)         | -3.7805
#  9    | -0.85        | X = 0.0 + 4.0/cos(-0.85)       | 6.0608       | Y = 0.0 + 3.0*tan(-0.85)         | -3.4150
#  10   | -0.80        | X = 0.0 + 4.0/cos(-0.80)       | 5.7413       | Y = 0.0 + 3.0*tan(-0.80)         | -3.0889
#  11   | -0.75        | X = 0.0 + 4.0/cos(-0.75)       | 5.4668       | Y = 0.0 + 3.0*tan(-0.75)         | -2.7948
#  12   | -0.70        | X = 0.0 + 4.0/cos(-0.70)       | 5.2298       | Y = 0.0 + 3.0*tan(-0.70)         | -2.5269
#  13   | -0.65        | X = 0.0 + 4.0/cos(-0.65)       | 5.0246       | Y = 0.0 + 3.0*tan(-0.65)         | -2.2806
#  14   | -0.60        | X = 0.0 + 4.0/cos(-0.60)       | 4.8465       | Y = 0.0 + 3.0*tan(-0.60)         | -2.0524
#  15   | -0.55        | X = 0.0 + 4.0/cos(-0.55)       | 4.6919       | Y = 0.0 + 3.0*tan(-0.55)         | -1.8393
#  16   | -0.50        | X = 0.0 + 4.0/cos(-0.50)       | 4.5580       | Y = 0.0 + 3.0*tan(-0.50)         | -1.6389
#  17   | -0.45        | X = 0.0 + 4.0/cos(-0.45)       | 4.4422       | Y = 0.0 + 3.0*tan(-0.45)         | -1.4492
#  18   | -0.40        | X = 0.0 + 4.0/cos(-0.40)       | 4.3428       | Y = 0.0 + 3.0*tan(-0.40)         | -1.2684
#  19   | -0.35        | X = 0.0 + 4.0/cos(-0.35)       | 4.2582       | Y = 0.0 + 3.0*tan(-0.35)         | -1.0951
#  20   | -0.30        | X = 0.0 + 4.0/cos(-0.30)       | 4.1870       | Y = 0.0 + 3.0*tan(-0.30)         | -0.9280
#  21   | -0.25        | X = 0.0 + 4.0/cos(-0.25)       | 4.1283       | Y = 0.0 + 3.0*tan(-0.25)         | -0.7660
#  22   | -0.20        | X = 0.0 + 4.0/cos(-0.20)       | 4.0814       | Y = 0.0 + 3.0*tan(-0.20)         | -0.6081
#  23   | -0.15        | X = 0.0 + 4.0/cos(-0.15)       | 4.0454       | Y = 0.0 + 3.0*tan(-0.15)         | -0.4534
#  24   | -0.10        | X = 0.0 + 4.0/cos(-0.10)       | 4.0201       | Y = 0.0 + 3.0*tan(-0.10)         | -0.3010
#  25   | -0.05        | X = 0.0 + 4.0/cos(-0.05)       | 4.0050       | Y = 0.0 + 3.0*tan(-0.05)         | -0.1501
#  26   | 0.00         | X = 0.0 + 4.0/cos(0.00)        | 4.0000       | Y = 0.0 + 3.0*tan(0.00)          | 0.0000
#  27   | 0.05         | X = 0.0 + 4.0/cos(0.05)        | 4.0050       | Y = 0.0 + 3.0*tan(0.05)          | 0.1501
#  28   | 0.10         | X = 0.0 + 4.0/cos(0.10)        | 4.0201       | Y = 0.0 + 3.0*tan(0.10)          | 0.3010
#  29   | 0.15         | X = 0.0 + 4.0/cos(0.15)        | 4.0454       | Y = 0.0 + 3.0*tan(0.15)          | 0.4534
#  30   | 0.20         | X = 0.0 + 4.0/cos(0.20)        | 4.0814       | Y = 0.0 + 3.0*tan(0.20)          | 0.6081
#  31   | 0.25         | X = 0.0 + 4.0/cos(0.25)        | 4.1283       | Y = 0.0 + 3.0*tan(0.25)          | 0.7660
#  32   | 0.30         | X = 0.0 + 4.0/cos(0.30)        | 4.1870       | Y = 0.0 + 3.0*tan(0.30)          | 0.9280
#  33   | 0.35         | X = 0.0 + 4.0/cos(0.35)        | 4.2582       | Y = 0.0 + 3.0*tan(0.35)          | 1.0951
#  34   | 0.40         | X = 0.0 + 4.0/cos(0.40)        | 4.3428       | Y = 0.0 + 3.0*tan(0.40)          | 1.2684
#  35   | 0.45         | X = 0.0 + 4.0/cos(0.45)        | 4.4422       | Y = 0.0 + 3.0*tan(0.45)          | 1.4492
#  36   | 0.50         | X = 0.0 + 4.0/cos(0.50)        | 4.5580       | Y = 0.0 + 3.0*tan(0.50)          | 1.6389
#  37   | 0.55         | X = 0.0 + 4.0/cos(0.55)        | 4.6919       | Y = 0.0 + 3.0*tan(0.55)          | 1.8393
#  38   | 0.60         | X = 0.0 + 4.0/cos(0.60)        | 4.8465       | Y = 0.0 + 3.0*tan(0.60)          | 2.0524
#  39   | 0.65         | X = 0.0 + 4.0/cos(0.65)        | 5.0246       | Y = 0.0 + 3.0*tan(0.65)          | 2.2806
#  40   | 0.70         | X = 0.0 + 4.0/cos(0.70)        | 5.2298       | Y = 0.0 + 3.0*tan(0.70)          | 2.5269
#  41   | 0.75         | X = 0.0 + 4.0/cos(0.75)        | 5.4668       | Y = 0.0 + 3.0*tan(0.75)          | 2.7948
#  42   | 0.80         | X = 0.0 + 4.0/cos(0.80)        | 5.7413       | Y = 0.0 + 3.0*tan(0.80)          | 3.0889
#  43   | 0.85         | X = 0.0 + 4.0/cos(0.85)        | 6.0608       | Y = 0.0 + 3.0*tan(0.85)          | 3.4150
#  44   | 0.90         | X = 0.0 + 4.0/cos(0.90)        | 6.4349       | Y = 0.0 + 3.0*tan(0.90)          | 3.7805
#  45   | 0.95         | X = 0.0 + 4.0/cos(0.95)        | 6.8766       | Y = 0.0 + 3.0*tan(0.95)          | 4.1951
#  46   | 1.00         | X = 0.0 + 4.0/cos(1.00)        | 7.4033       | Y = 0.0 + 3.0*tan(1.00)          | 4.6722
#  47   | 1.05         | X = 0.0 + 4.0/cos(1.05)        | 8.0391       | Y = 0.0 + 3.0*tan(1.05)          | 5.2299
#  48   | 1.10         | X = 0.0 + 4.0/cos(1.10)        | 8.8184       | Y = 0.0 + 3.0*tan(1.10)          | 5.8943
#  49   | 1.15         | X = 0.0 + 4.0/cos(1.15)        | 9.7922       | Y = 0.0 + 3.0*tan(1.15)          | 6.7035
#  50   | 1.20         | X = 0.0 + 4.0/cos(1.20)        | 11.0388      | Y = 0.0 + 3.0*tan(1.20)          | 7.7165
#  51   | 1.25         | X = 0.0 + 4.0/cos(1.25)        | 12.6854      | Y = 0.0 + 3.0*tan(1.25)          | 9.0287
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
#
#  Eksekusi dihentikan. Program selesai dengan sukses!
