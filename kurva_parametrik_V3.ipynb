# %%
import numpy as np
import matplotlib.pyplot as plt

# Mengatur tema gelap bawaan matplotlib
plt.style.use('dark_background')


# =====================================================
# VISUALISASI UTAMA (GAYA DASHBOARD CLEAN & BINGKAI LUAR)
# =====================================================

def tampilkan_gaya_pro(param_array, x1, y1, xc, yc, a, b, title, n_pts, step, teks_panel, tipe_kurva="ELIPS", x2=None, y2=None):
    
    warna_kurva = '#00FFCC'   # Cyan-Neon
    warna_kurva2 = '#FF007F'  # Magenta-Neon (Khusus Hiperbola)
    warna_titik = '#FFFFFF'   # Putih
    warna_teks  = '#E0E0E0'
    
    fig, ax = plt.subplots(figsize=(11, 6.5))
    fig.subplots_adjust(left=0.08, right=0.70, top=0.88, bottom=0.10)

    # Judul Utama Gambar
    fig.suptitle(
        f"✦ VISUALISASI {tipe_kurva} PARAMETRIK ✦\nResolusi: {title} | Delta = {step:.4f}",
        fontsize=13, fontweight='bold', color=warna_kurva, y=0.96
    )

    # Plot Jalur Kurva dan Titik Sampel
    if x2 is not None and y2 is not None:
        ax.plot(x1, y1, color=warna_kurva, linewidth=2.5, zorder=2, label='Cabang Kanan')
        ax.plot(x2, y2, color=warna_kurva2, linewidth=2.5, zorder=2, label='Cabang Kiri')
        ax.scatter(x1, y1, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5)
        ax.scatter(x2, y2, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5)
    else:
        ax.plot(x1, y1, color=warna_kurva, linewidth=2.5, zorder=2, label=f'Kurva {tipe_kurva.title()}')
        ax.scatter(x1, y1, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5, label=f'Koordinat ({n_pts} titik)')

    # Titik Pusat / Vertex
    ax.scatter(xc, yc, color='#FFFF00', s=100, marker='P', zorder=5)
    ax.annotate(f"PUSAT ({xc:.1f}, {yc:.1f})", xy=(xc, yc), xytext=(5, 5),
                textcoords="offset points", color='#FFFF00', fontsize=8.5, fontweight='bold')

    # --- PENANDA TITIK AWAL & AKHIR ---
    ax.scatter(x1[0], y1[0], color='#00FF00', marker='s', s=80, zorder=6, label='Titik Awal')
    ax.annotate(f"► START ({x1[0]:.1f}, {y1[0]:.1f})", xy=(x1[0], y1[0]), 
                xytext=(x1[0] + max(a, 1) * 0.15, y1[0] + max(b, 1) * 0.15),
                color='#00FF00', fontsize=8.5, fontweight='bold',
                arrowprops=dict(arrowstyle='->', color='#00FF00', lw=1.2))

    ax.scatter(x1[-1], y1[-1], color='#FF9900', marker='x', s=90, zorder=7, label='Titik Akhir')
    ax.annotate(f"■ END ({x1[-1]:.1f}, {y1[-1]:.1f})", xy=(x1[-1], y1[-1]), 
                xytext=(x1[-1] + max(a, 1) * 0.15, y1[-1] - max(b, 1) * 0.15),
                color='#FF9900', fontsize=8.5, fontweight='bold',
                arrowprops=dict(arrowstyle='->', color='#FF9900', lw=1.2))

    # Teks Koordinat Tipis
    step_lbl = max(1, len(x1) // 6)
    for i in range(1, len(x1) - 1, step_lbl):
        ax.annotate(f"({x1[i]:.1f}, {y1[i]:.1f})", (x1[i], y1[i]),
                    textcoords="offset points", xytext=(5, 5), fontsize=7, color='#888888')
        if x2 is not None and y2 is not None:
            ax.annotate(f"({x2[i]:.1f}, {y2[i]:.1f})", (x2[i], y2[i]),
                        textcoords="offset points", xytext=(5, 5), fontsize=7, color='#888888')

    # --- KOTAK INFO PANEL TUNGGAL ---
    bbox_style = dict(boxstyle="square,pad=0.7", fc="#0B1320", ec=warna_kurva, lw=1.2, alpha=0.95)
    
    # Mencetak panel informasi yang dikirim dari fungsi masing-masing geometri
    fig.text(0.73, 0.5, teks_panel, fontsize=9.5, color=warna_teks, family='monospace', bbox=bbox_style, va='center')

    # Konfigurasi Batas Grafik
    if tipe_kurva in ("ELIPS", "LINGKARAN"):
        ax.set_aspect('equal', adjustable='box')
        ax.set_xlim(xc - a * 1.6, xc + a * 1.6)
        ax.set_ylim(yc - b * 1.6, yc + b * 1.6)
    else:
        all_x = x1 if x2 is None else np.concatenate([x1, x2])
        all_y = y1 if y2 is None else np.concatenate([y1, y2])
        ax.set_xlim(np.min(all_x) - 2, np.max(all_x) + 2)
        ax.set_ylim(np.min(all_y) - 2, np.max(all_y) + 2)

    # Style Background Grid
    ax.grid(True, linestyle='--', alpha=0.3, color='gray')
    ax.tick_params(colors=warna_teks, labelsize=9)
    for spine in ax.spines.values():
        spine.set_color('white')
        spine.set_linewidth(1)

    ax.axvline(xc, color='gray', linestyle=':', linewidth=0.8, alpha=0.4, zorder=1)
    ax.axhline(yc, color='gray', linestyle=':', linewidth=0.8, alpha=0.4, zorder=1)
    ax.legend(loc='lower left', facecolor='#0B1320', edgecolor='none', labelcolor='white', fontsize=8)
    plt.show()


# =====================================================
# INPUT HELPER UTALITAS
# =====================================================

def input_float(prompt):
    while True:
        try:
            return float(input(prompt))
        except ValueError:
            print("  ⚠  Masukkan angka koordinat yang valid!")


def input_step(prompt):
    while True:
        val = input_float(prompt)
        if val > 0:
            return val
        print("  ⚠  Nilai step pembagi harus lebih besar dari 0!")


# =====================================================
# BANGUN 1: LINGKARAN
# =====================================================

def lingkaran():
    print("================================================================================")
    print(" COMPILER KURVA LINGKARAN PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat X (xc) [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Y (yc) [contoh: 0.0] : ")
    r  = input_float("Ukuran Radius  (r) [contoh: 5.0] : ")
    if r <= 0:
        print("  ⚠  Radius wajib bernilai positif!")
        return

    step_besar = input_step("Jarak Interval Step Besar θ (rad) [contoh: 0.5]  : ")
    step_kecil = input_step("Jarak Interval Step Kecil θ (rad) [contoh: 0.05] : ")

    configs = [
        ("Resolusi Rendah", step_besar),
        ("Resolusi Tinggi", step_kecil),
    ]

    keliling = 2 * np.pi * r
    luas = np.pi * r**2

    for title, step_val in configs:
        theta = np.append(np.arange(0, 2 * np.pi, step_val), 2 * np.pi)
        n_pts = len(theta)
        actual_step = 2 * np.pi / (n_pts - 1) if n_pts > 1 else 0

        x = xc + r * np.cos(theta)
        y = yc + r * np.sin(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA LINGKARAN - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {r} * cos(θ)  |  y(θ) = {yc} + {r} * sin(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {r}*cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {r}*sin({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI LINGKARAN\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Radius (r)   : {r}\n"
            f" Luas Area    : {luas:.4f}\n"
            f" Keliling     : {keliling:.4f}\n"
            f" Total Titik  : {n_pts}\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})² + (y-{yc})² = {r}²"
        )
        tampilkan_gaya_pro(theta, x, y, xc, yc, r, r, title, n_pts, actual_step, teks_panel, "LINGKARAN")


# =====================================================
# BANGUN 2: ELIPS
# =====================================================

def elips():
    print("================================================================================")
    print(" COMPILER KURVA ELIPS PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat X (xc)         [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Y (yc)         [contoh: 0.0] : ")
    a  = input_float("Panjang Sumbu Horizontal a [contoh: 8.0] : ")
    b  = input_float("Panjang Sumbu Vertikal b   [contoh: 5.0] : ")
    if a <= 0 or b <= 0:
        print("  ⚠  Nilai sumbu komponen harus di atas 0!")
        return

    step_besar = input_step("Jarak Interval Step Besar θ (rad) [contoh: 0.5]  : ")
    step_kecil = input_step("Jarak Interval Step Kecil θ (rad) [contoh: 0.05] : ")

    c = np.sqrt(abs(a**2 - b**2))
    e = c / max(a, b)
    luas = np.pi * a * b
    keliling = np.pi * (3*(a+b) - np.sqrt((3*a+b)*(a+3*b))) # Ramanujan approx

    configs = [
        ("Resolusi Rendah", step_besar),
        ("Resolusi Tinggi", step_kecil),
    ]

    for title, step_val in configs:
        theta = np.append(np.arange(0, 2 * np.pi, step_val), 2 * np.pi)
        n_pts = len(theta)
        actual_step = 2 * np.pi / (n_pts - 1) if n_pts > 1 else 0

        x = xc + a * np.cos(theta)
        y = yc + b * np.sin(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA ELIPS - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {a} * cos(θ)  |  y(θ) = {yc} + {b} * sin(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {a}*cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {b}*sin({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        # Informasi panel dinamis spesifik untuk elips (termasuk properti lanjutan)
        teks_panel = (
            f" ⚙ DATA SPESIFIKASI ELIPS\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Sumbu hor (a): {a}\n"
            f" Sumbu ver (b): {b}\n"
            f" Jarak Fokus c: {c:.4f}\n"
            f" Eksentrisitas: {e:.4f}\n"
            f" Luas Area    : {luas:.4f}\n"
            f" Keliling     : {keliling:.4f}\n"
            f" Total Titik  : {n_pts}\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})²/{a}² + (y-{yc})²/{b}² = 1"
        )
        tampilkan_gaya_pro(theta, x, y, xc, yc, a, b, title, n_pts, actual_step, teks_panel, "ELIPS")


# =====================================================
# BANGUN 3: PARABOLA
# =====================================================

def parabola():
    print("================================================================================")
    print(" COMPILER KURVA PARABOLA PARAMETRIK")
    print("================================================================================\n")
    orientasi = input(" Tentukan Orientasi [H/V, contoh: H]: ").strip().upper()
    if orientasi not in ('H', 'V'):
        print("  ⚠  Pilihan orientasi tidak valid!")
        return

    xp = input_float("Titik Vertex X (xp)  [contoh: 0.0] : ")
    yp = input_float("Titik Vertex Y (yp)  [contoh: 0.0] : ")
    a  = input_float("Faktor Ketajaman a   [contoh: 1.0] : ")

    step_besar = input_step("Interval Step Batas Besar parameter t [contoh: 1.0] : ")
    step_kecil = input_step("Interval Step Batas Kecil parameter t [contoh: 0.1] : ")

    configs = [("Resolusi Rendah", step_besar), ("Resolusi Tinggi", step_kecil)]

    for title, step_val in configs:
        t = np.arange(-5, 5 + step_val, step_val)
        n_pts = len(t)
        
        if orientasi == 'H':
            x = xp + a * t**2
            y = yp + t
            rumus_std = f"(y-{yp})² = {1/a:.4f} * (x-{xp})"
        else:
            x = xp + t
            y = yp + a * t**2
            rumus_std = f"(x-{xp})² = {1/a:.4f} * (y-{yp})"

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA PARABOLA - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        if orientasi == 'H':
            print(f"   x(t) = xp + a * t²  |  y(t) = yp + t\n")
        else:
            print(f"   x(t) = xp + t     |  y(t) = yp + a * t²\n")
            
        print(f" Persamaan Parametrik (Substitusi):")
        if orientasi == 'H':
            print(f"   x(t) = {xp} + {a} * t²  |  y(t) = {yp} + t\n")
        else:
            print(f"   x(t) = {xp} + t     |  y(t) = {yp} + {a} * t²\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'NILAI t':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(t)):
            calc_x = f"X = {xp} + {a}*({t[i]:.2f})²" if orientasi == 'H' else f"X = {xp} + {t[i]:.2f}"
            calc_y = f"Y = {yp} + {t[i]:.2f}" if orientasi == 'H' else f"Y = {yp} + {a}*({t[i]:.2f})²"
            print(f" {i+1:<4} | {t[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        fokus_dist = 1 / (4 * a) if a != 0 else 0
        arah = "Horizontal" if orientasi == 'H' else "Vertikal"

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI PARABOLA\n"
            f" ════════════════════════════\n"
            f" Vertex (xp,yp): ({xp:.2f}, {yp:.2f})\n"
            f" Orientasi     : {arah}\n"
            f" Parameter a   : {a}\n"
            f" Dist. Fokus   : {fokus_dist:.4f}\n"
            f" Total Titik   : {n_pts}\n"
            f" Skema         : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" {rumus_std}"
        )
        tampilkan_gaya_pro(t, x, y, xp, yp, a, a, title, n_pts, step_val, teks_panel, "PARABOLA")


# =====================================================
# BANGUN 4: HIPERBOLA
# =====================================================

def hiperbola():
    print("================================================================================")
    print(" COMPILER KURVA HIPERBOLA PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat Domain X (xc)      [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Domain Y (yc)      [contoh: 0.0] : ")
    a  = input_float("Semi-Sumbu Transversal Nilai a [contoh: 4.0] : ")
    b  = input_float("Semi-Sumbu Konjugasi Nilai b   [contoh: 3.0] : ")
    if a <= 0 or b <= 0: return

    step_besar = input_step("Interval Pembagi Step Besar θ (rad) [contoh: 0.2]  : ")
    step_kecil = input_step("Interval Pembagi Step Kecil θ (rad) [contoh: 0.02] : ")

    batas = 1.25  
    configs = [("Resolusi Rendah", step_besar), ("Resolusi Tinggi", step_kecil)]

    c = np.sqrt(a**2 + b**2)
    e = c / a

    for title, step_val in configs:
        theta = np.arange(-batas, batas + step_val, step_val)
        n_pts = len(theta)

        x1 = xc + a / np.cos(theta); y1 = yc + b * np.tan(theta)
        x2 = xc - a / np.cos(theta); y2 = yc + b * np.tan(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA HIPERBOLA (CABANG KANAN) - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + a / cos(θ)  |  y(θ) = yc + b * tan(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {a} / cos(θ)  |  y(θ) = {yc} + {b} * tan(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA CABANG KANAN X':<30} | {'HASIL X':<12} | {'FORMULA CABANG KANAN Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {a}/cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {b}*tan({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x1[i]:<12.4f} | {calc_y:<32} | {y1[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI HIPERBOLA\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Transversal a: {a}\n"
            f" Konjugasi b  : {b}\n"
            f" Jarak Fokus c: {c:.4f}\n"
            f" Eksentrisitas: {e:.4f}\n"
            f" Total Titik  : {n_pts} per cb\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})²/{a}² - (y-{yc})²/{b}² = 1"
        )
        tampilkan_gaya_pro(theta, x1, y1, xc, yc, a, b, title, n_pts, step_val, teks_panel, "HIPERBOLA", x2, y2)


# =====================================================
# HUB KONTROL MENU UTAMA
# =====================================================

def menu():
    while True:
        print("\n" + "═" * 42)
        print("   SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF   ")
        print("═" * 42)
        print("  [1]  Kurva Lingkaran Parametrik")
        print("  [2]  Kurva Elips Parametrik")
        print("  [3]  Kurva Parabola Parametrik")
        print("  [4]  Kurva Hiperbola Parametrik")
        print("  [0]  Hentikan & Keluar Program")
        print("─" * 42)

        pilih = input(" Tentukan Opsi Operasi Menu : ").strip()

        if pilih == "1": lingkaran()
        elif pilih == "2": elips()
        elif pilih == "3": parabola()
        elif pilih == "4": hiperbola()
        elif pilih == "0":
            print("\n Eksekusi dihentikan. Program selesai dengan sukses!\n")
            break
        else: print("  ⚠  Pilihan tidak tersedia!")


if __name__ == "__main__":
    menu()
# Out:
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA LINGKARAN PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA LINGKARAN - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 2.0 + 5.0 * cos(θ)  |  y(θ) = 4.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 2.0 + 5.0*cos(0.00)        | 7.0000       | Y = 4.0 + 5.0*sin(0.00)          | 4.0000
#  2    | 0.50         | X = 2.0 + 5.0*cos(0.50)        | 6.3879       | Y = 4.0 + 5.0*sin(0.50)          | 6.3971
#  3    | 1.00         | X = 2.0 + 5.0*cos(1.00)        | 4.7015       | Y = 4.0 + 5.0*sin(1.00)          | 8.2074
#  4    | 1.50         | X = 2.0 + 5.0*cos(1.50)        | 2.3537       | Y = 4.0 + 5.0*sin(1.50)          | 8.9875
#  5    | 2.00         | X = 2.0 + 5.0*cos(2.00)        | -0.0807      | Y = 4.0 + 5.0*sin(2.00)          | 8.5465
#  6    | 2.50         | X = 2.0 + 5.0*cos(2.50)        | -2.0057      | Y = 4.0 + 5.0*sin(2.50)          | 6.9924
#  7    | 3.00         | X = 2.0 + 5.0*cos(3.00)        | -2.9500      | Y = 4.0 + 5.0*sin(3.00)          | 4.7056
#  8    | 3.50         | X = 2.0 + 5.0*cos(3.50)        | -2.6823      | Y = 4.0 + 5.0*sin(3.50)          | 2.2461
#  9    | 4.00         | X = 2.0 + 5.0*cos(4.00)        | -1.2682      | Y = 4.0 + 5.0*sin(4.00)          | 0.2160
#  10   | 4.50         | X = 2.0 + 5.0*cos(4.50)        | 0.9460       | Y = 4.0 + 5.0*sin(4.50)          | -0.8877
#  11   | 5.00         | X = 2.0 + 5.0*cos(5.00)        | 3.4183       | Y = 4.0 + 5.0*sin(5.00)          | -0.7946
#  12   | 5.50         | X = 2.0 + 5.0*cos(5.50)        | 5.5433       | Y = 4.0 + 5.0*sin(5.50)          | 0.4723
#  13   | 6.00         | X = 2.0 + 5.0*cos(6.00)        | 6.8009       | Y = 4.0 + 5.0*sin(6.00)          | 2.6029
#  14   | 6.28         | X = 2.0 + 5.0*cos(6.28)        | 7.0000       | Y = 4.0 + 5.0*sin(6.28)          | 4.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA LINGKARAN - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 2.0 + 5.0 * cos(θ)  |  y(θ) = 4.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 2.0 + 5.0*cos(0.00)        | 7.0000       | Y = 4.0 + 5.0*sin(0.00)          | 4.0000
#  2    | 0.05         | X = 2.0 + 5.0*cos(0.05)        | 6.9938       | Y = 4.0 + 5.0*sin(0.05)          | 4.2499
#  3    | 0.10         | X = 2.0 + 5.0*cos(0.10)        | 6.9750       | Y = 4.0 + 5.0*sin(0.10)          | 4.4992
#  4    | 0.15         | X = 2.0 + 5.0*cos(0.15)        | 6.9439       | Y = 4.0 + 5.0*sin(0.15)          | 4.7472
#  5    | 0.20         | X = 2.0 + 5.0*cos(0.20)        | 6.9003       | Y = 4.0 + 5.0*sin(0.20)          | 4.9933
#  6    | 0.25         | X = 2.0 + 5.0*cos(0.25)        | 6.8446       | Y = 4.0 + 5.0*sin(0.25)          | 5.2370
#  7    | 0.30         | X = 2.0 + 5.0*cos(0.30)        | 6.7767       | Y = 4.0 + 5.0*sin(0.30)          | 5.4776
#  8    | 0.35         | X = 2.0 + 5.0*cos(0.35)        | 6.6969       | Y = 4.0 + 5.0*sin(0.35)          | 5.7145
#  9    | 0.40         | X = 2.0 + 5.0*cos(0.40)        | 6.6053       | Y = 4.0 + 5.0*sin(0.40)          | 5.9471
#  10   | 0.45         | X = 2.0 + 5.0*cos(0.45)        | 6.5022       | Y = 4.0 + 5.0*sin(0.45)          | 6.1748
#  11   | 0.50         | X = 2.0 + 5.0*cos(0.50)        | 6.3879       | Y = 4.0 + 5.0*sin(0.50)          | 6.3971
#  12   | 0.55         | X = 2.0 + 5.0*cos(0.55)        | 6.2626       | Y = 4.0 + 5.0*sin(0.55)          | 6.6134
#  13   | 0.60         | X = 2.0 + 5.0*cos(0.60)        | 6.1267       | Y = 4.0 + 5.0*sin(0.60)          | 6.8232
#  14   | 0.65         | X = 2.0 + 5.0*cos(0.65)        | 5.9804       | Y = 4.0 + 5.0*sin(0.65)          | 7.0259
#  15   | 0.70         | X = 2.0 + 5.0*cos(0.70)        | 5.8242       | Y = 4.0 + 5.0*sin(0.70)          | 7.2211
#  16   | 0.75         | X = 2.0 + 5.0*cos(0.75)        | 5.6584       | Y = 4.0 + 5.0*sin(0.75)          | 7.4082
#  17   | 0.80         | X = 2.0 + 5.0*cos(0.80)        | 5.4835       | Y = 4.0 + 5.0*sin(0.80)          | 7.5868
#  18   | 0.85         | X = 2.0 + 5.0*cos(0.85)        | 5.2999       | Y = 4.0 + 5.0*sin(0.85)          | 7.7564
#  19   | 0.90         | X = 2.0 + 5.0*cos(0.90)        | 5.1080       | Y = 4.0 + 5.0*sin(0.90)          | 7.9166
#  20   | 0.95         | X = 2.0 + 5.0*cos(0.95)        | 4.9084       | Y = 4.0 + 5.0*sin(0.95)          | 8.0671
#  21   | 1.00         | X = 2.0 + 5.0*cos(1.00)        | 4.7015       | Y = 4.0 + 5.0*sin(1.00)          | 8.2074
#  22   | 1.05         | X = 2.0 + 5.0*cos(1.05)        | 4.4879       | Y = 4.0 + 5.0*sin(1.05)          | 8.3371
#  23   | 1.10         | X = 2.0 + 5.0*cos(1.10)        | 4.2680       | Y = 4.0 + 5.0*sin(1.10)          | 8.4560
#  24   | 1.15         | X = 2.0 + 5.0*cos(1.15)        | 4.0424       | Y = 4.0 + 5.0*sin(1.15)          | 8.5638
#  25   | 1.20         | X = 2.0 + 5.0*cos(1.20)        | 3.8118       | Y = 4.0 + 5.0*sin(1.20)          | 8.6602
#  26   | 1.25         | X = 2.0 + 5.0*cos(1.25)        | 3.5766       | Y = 4.0 + 5.0*sin(1.25)          | 8.7449
#  27   | 1.30         | X = 2.0 + 5.0*cos(1.30)        | 3.3375       | Y = 4.0 + 5.0*sin(1.30)          | 8.8178
#  28   | 1.35         | X = 2.0 + 5.0*cos(1.35)        | 3.0950       | Y = 4.0 + 5.0*sin(1.35)          | 8.8786
#  29   | 1.40         | X = 2.0 + 5.0*cos(1.40)        | 2.8498       | Y = 4.0 + 5.0*sin(1.40)          | 8.9272
#  30   | 1.45         | X = 2.0 + 5.0*cos(1.45)        | 2.6025       | Y = 4.0 + 5.0*sin(1.45)          | 8.9636
#  31   | 1.50         | X = 2.0 + 5.0*cos(1.50)        | 2.3537       | Y = 4.0 + 5.0*sin(1.50)          | 8.9875
#  32   | 1.55         | X = 2.0 + 5.0*cos(1.55)        | 2.1040       | Y = 4.0 + 5.0*sin(1.55)          | 8.9989
#  33   | 1.60         | X = 2.0 + 5.0*cos(1.60)        | 1.8540       | Y = 4.0 + 5.0*sin(1.60)          | 8.9979
#  34   | 1.65         | X = 2.0 + 5.0*cos(1.65)        | 1.6044       | Y = 4.0 + 5.0*sin(1.65)          | 8.9843
#  35   | 1.70         | X = 2.0 + 5.0*cos(1.70)        | 1.3558       | Y = 4.0 + 5.0*sin(1.70)          | 8.9583
#  36   | 1.75         | X = 2.0 + 5.0*cos(1.75)        | 1.1088       | Y = 4.0 + 5.0*sin(1.75)          | 8.9199
#  37   | 1.80         | X = 2.0 + 5.0*cos(1.80)        | 0.8640       | Y = 4.0 + 5.0*sin(1.80)          | 8.8692
#  38   | 1.85         | X = 2.0 + 5.0*cos(1.85)        | 0.6220       | Y = 4.0 + 5.0*sin(1.85)          | 8.8064
#  39   | 1.90         | X = 2.0 + 5.0*cos(1.90)        | 0.3836       | Y = 4.0 + 5.0*sin(1.90)          | 8.7315
#  40   | 1.95         | X = 2.0 + 5.0*cos(1.95)        | 0.1491       | Y = 4.0 + 5.0*sin(1.95)          | 8.6448
#  41   | 2.00         | X = 2.0 + 5.0*cos(2.00)        | -0.0807      | Y = 4.0 + 5.0*sin(2.00)          | 8.5465
#  42   | 2.05         | X = 2.0 + 5.0*cos(2.05)        | -0.3054      | Y = 4.0 + 5.0*sin(2.05)          | 8.4368
#  43   | 2.10         | X = 2.0 + 5.0*cos(2.10)        | -0.5242      | Y = 4.0 + 5.0*sin(2.10)          | 8.3160
#  44   | 2.15         | X = 2.0 + 5.0*cos(2.15)        | -0.7368      | Y = 4.0 + 5.0*sin(2.15)          | 8.1845
#  45   | 2.20         | X = 2.0 + 5.0*cos(2.20)        | -0.9425      | Y = 4.0 + 5.0*sin(2.20)          | 8.0425
#  46   | 2.25         | X = 2.0 + 5.0*cos(2.25)        | -1.1409      | Y = 4.0 + 5.0*sin(2.25)          | 7.8904
#  47   | 2.30         | X = 2.0 + 5.0*cos(2.30)        | -1.3314      | Y = 4.0 + 5.0*sin(2.30)          | 7.7285
#  48   | 2.35         | X = 2.0 + 5.0*cos(2.35)        | -1.5136      | Y = 4.0 + 5.0*sin(2.35)          | 7.5574
#  49   | 2.40         | X = 2.0 + 5.0*cos(2.40)        | -1.6870      | Y = 4.0 + 5.0*sin(2.40)          | 7.3773
#  50   | 2.45         | X = 2.0 + 5.0*cos(2.45)        | -1.8512      | Y = 4.0 + 5.0*sin(2.45)          | 7.1888
#  51   | 2.50         | X = 2.0 + 5.0*cos(2.50)        | -2.0057      | Y = 4.0 + 5.0*sin(2.50)          | 6.9924
#  52   | 2.55         | X = 2.0 + 5.0*cos(2.55)        | -2.1503      | Y = 4.0 + 5.0*sin(2.55)          | 6.7884
#  53   | 2.60         | X = 2.0 + 5.0*cos(2.60)        | -2.2844      | Y = 4.0 + 5.0*sin(2.60)          | 6.5775
#  54   | 2.65         | X = 2.0 + 5.0*cos(2.65)        | -2.4079      | Y = 4.0 + 5.0*sin(2.65)          | 6.3602
#  55   | 2.70         | X = 2.0 + 5.0*cos(2.70)        | -2.5204      | Y = 4.0 + 5.0*sin(2.70)          | 6.1369
#  56   | 2.75         | X = 2.0 + 5.0*cos(2.75)        | -2.6215      | Y = 4.0 + 5.0*sin(2.75)          | 5.9083
#  57   | 2.80         | X = 2.0 + 5.0*cos(2.80)        | -2.7111      | Y = 4.0 + 5.0*sin(2.80)          | 5.6749
#  58   | 2.85         | X = 2.0 + 5.0*cos(2.85)        | -2.7889      | Y = 4.0 + 5.0*sin(2.85)          | 5.4374
#  59   | 2.90         | X = 2.0 + 5.0*cos(2.90)        | -2.8548      | Y = 4.0 + 5.0*sin(2.90)          | 5.1962
#  60   | 2.95         | X = 2.0 + 5.0*cos(2.95)        | -2.9085      | Y = 4.0 + 5.0*sin(2.95)          | 4.9521
#  61   | 3.00         | X = 2.0 + 5.0*cos(3.00)        | -2.9500      | Y = 4.0 + 5.0*sin(3.00)          | 4.7056
#  62   | 3.05         | X = 2.0 + 5.0*cos(3.05)        | -2.9790      | Y = 4.0 + 5.0*sin(3.05)          | 4.4573
#  63   | 3.10         | X = 2.0 + 5.0*cos(3.10)        | -2.9957      | Y = 4.0 + 5.0*sin(3.10)          | 4.2079
#  64   | 3.15         | X = 2.0 + 5.0*cos(3.15)        | -2.9998      | Y = 4.0 + 5.0*sin(3.15)          | 3.9580
#  65   | 3.20         | X = 2.0 + 5.0*cos(3.20)        | -2.9915      | Y = 4.0 + 5.0*sin(3.20)          | 3.7081
#  66   | 3.25         | X = 2.0 + 5.0*cos(3.25)        | -2.9706      | Y = 4.0 + 5.0*sin(3.25)          | 3.4590
#  67   | 3.30         | X = 2.0 + 5.0*cos(3.30)        | -2.9374      | Y = 4.0 + 5.0*sin(3.30)          | 3.2113
#  68   | 3.35         | X = 2.0 + 5.0*cos(3.35)        | -2.8918      | Y = 4.0 + 5.0*sin(3.35)          | 2.9655
#  69   | 3.40         | X = 2.0 + 5.0*cos(3.40)        | -2.8340      | Y = 4.0 + 5.0*sin(3.40)          | 2.7223
#  70   | 3.45         | X = 2.0 + 5.0*cos(3.45)        | -2.7641      | Y = 4.0 + 5.0*sin(3.45)          | 2.4823
#  71   | 3.50         | X = 2.0 + 5.0*cos(3.50)        | -2.6823      | Y = 4.0 + 5.0*sin(3.50)          | 2.2461
#  72   | 3.55         | X = 2.0 + 5.0*cos(3.55)        | -2.5888      | Y = 4.0 + 5.0*sin(3.55)          | 2.0143
#  73   | 3.60         | X = 2.0 + 5.0*cos(3.60)        | -2.4838      | Y = 4.0 + 5.0*sin(3.60)          | 1.7874
#  74   | 3.65         | X = 2.0 + 5.0*cos(3.65)        | -2.3676      | Y = 4.0 + 5.0*sin(3.65)          | 1.5661
#  75   | 3.70         | X = 2.0 + 5.0*cos(3.70)        | -2.2405      | Y = 4.0 + 5.0*sin(3.70)          | 1.3508
#  76   | 3.75         | X = 2.0 + 5.0*cos(3.75)        | -2.1028      | Y = 4.0 + 5.0*sin(3.75)          | 1.1422
#  77   | 3.80         | X = 2.0 + 5.0*cos(3.80)        | -1.9548      | Y = 4.0 + 5.0*sin(3.80)          | 0.9407
#  78   | 3.85         | X = 2.0 + 5.0*cos(3.85)        | -1.7970      | Y = 4.0 + 5.0*sin(3.85)          | 0.7469
#  79   | 3.90         | X = 2.0 + 5.0*cos(3.90)        | -1.6297      | Y = 4.0 + 5.0*sin(3.90)          | 0.5612
#  80   | 3.95         | X = 2.0 + 5.0*cos(3.95)        | -1.4533      | Y = 4.0 + 5.0*sin(3.95)          | 0.3841
#  81   | 4.00         | X = 2.0 + 5.0*cos(4.00)        | -1.2682      | Y = 4.0 + 5.0*sin(4.00)          | 0.2160
#  82   | 4.05         | X = 2.0 + 5.0*cos(4.05)        | -1.0750      | Y = 4.0 + 5.0*sin(4.05)          | 0.0574
#  83   | 4.10         | X = 2.0 + 5.0*cos(4.10)        | -0.8741      | Y = 4.0 + 5.0*sin(4.10)          | -0.0914
#  84   | 4.15         | X = 2.0 + 5.0*cos(4.15)        | -0.6660      | Y = 4.0 + 5.0*sin(4.15)          | -0.2299
#  85   | 4.20         | X = 2.0 + 5.0*cos(4.20)        | -0.4513      | Y = 4.0 + 5.0*sin(4.20)          | -0.3579
#  86   | 4.25         | X = 2.0 + 5.0*cos(4.25)        | -0.2304      | Y = 4.0 + 5.0*sin(4.25)          | -0.4749
#  87   | 4.30         | X = 2.0 + 5.0*cos(4.30)        | -0.0040      | Y = 4.0 + 5.0*sin(4.30)          | -0.5808
#  88   | 4.35         | X = 2.0 + 5.0*cos(4.35)        | 0.2275       | Y = 4.0 + 5.0*sin(4.35)          | -0.6753
#  89   | 4.40         | X = 2.0 + 5.0*cos(4.40)        | 0.4633       | Y = 4.0 + 5.0*sin(4.40)          | -0.7580
#  90   | 4.45         | X = 2.0 + 5.0*cos(4.45)        | 0.7031       | Y = 4.0 + 5.0*sin(4.45)          | -0.8289
#  91   | 4.50         | X = 2.0 + 5.0*cos(4.50)        | 0.9460       | Y = 4.0 + 5.0*sin(4.50)          | -0.8877
#  92   | 4.55         | X = 2.0 + 5.0*cos(4.55)        | 1.1916       | Y = 4.0 + 5.0*sin(4.55)          | -0.9342
#  93   | 4.60         | X = 2.0 + 5.0*cos(4.60)        | 1.4392       | Y = 4.0 + 5.0*sin(4.60)          | -0.9685
#  94   | 4.65         | X = 2.0 + 5.0*cos(4.65)        | 1.6883       | Y = 4.0 + 5.0*sin(4.65)          | -0.9903
#  95   | 4.70         | X = 2.0 + 5.0*cos(4.70)        | 1.9381       | Y = 4.0 + 5.0*sin(4.70)          | -0.9996
#  96   | 4.75         | X = 2.0 + 5.0*cos(4.75)        | 2.1880       | Y = 4.0 + 5.0*sin(4.75)          | -0.9965
#  97   | 4.80         | X = 2.0 + 5.0*cos(4.80)        | 2.4375       | Y = 4.0 + 5.0*sin(4.80)          | -0.9808
#  98   | 4.85         | X = 2.0 + 5.0*cos(4.85)        | 2.6859       | Y = 4.0 + 5.0*sin(4.85)          | -0.9527
#  99   | 4.90         | X = 2.0 + 5.0*cos(4.90)        | 2.9326       | Y = 4.0 + 5.0*sin(4.90)          | -0.9123
#  100  | 4.95         | X = 2.0 + 5.0*cos(4.95)        | 3.1769       | Y = 4.0 + 5.0*sin(4.95)          | -0.8595
#  101  | 5.00         | X = 2.0 + 5.0*cos(5.00)        | 3.4183       | Y = 4.0 + 5.0*sin(5.00)          | -0.7946
#  102  | 5.05         | X = 2.0 + 5.0*cos(5.05)        | 3.6562       | Y = 4.0 + 5.0*sin(5.05)          | -0.7177
#  103  | 5.10         | X = 2.0 + 5.0*cos(5.10)        | 3.8899       | Y = 4.0 + 5.0*sin(5.10)          | -0.6291
#  104  | 5.15         | X = 2.0 + 5.0*cos(5.15)        | 4.1189       | Y = 4.0 + 5.0*sin(5.15)          | -0.5288
#  105  | 5.20         | X = 2.0 + 5.0*cos(5.20)        | 4.3426       | Y = 4.0 + 5.0*sin(5.20)          | -0.4173
#  106  | 5.25         | X = 2.0 + 5.0*cos(5.25)        | 4.5604       | Y = 4.0 + 5.0*sin(5.25)          | -0.2947
#  107  | 5.30         | X = 2.0 + 5.0*cos(5.30)        | 4.7719       | Y = 4.0 + 5.0*sin(5.30)          | -0.1613
#  108  | 5.35         | X = 2.0 + 5.0*cos(5.35)        | 4.9764       | Y = 4.0 + 5.0*sin(5.35)          | -0.0176
#  109  | 5.40         | X = 2.0 + 5.0*cos(5.40)        | 5.1735       | Y = 4.0 + 5.0*sin(5.40)          | 0.1362
#  110  | 5.45         | X = 2.0 + 5.0*cos(5.45)        | 5.3626       | Y = 4.0 + 5.0*sin(5.45)          | 0.2996
#  111  | 5.50         | X = 2.0 + 5.0*cos(5.50)        | 5.5433       | Y = 4.0 + 5.0*sin(5.50)          | 0.4723
#  112  | 5.55         | X = 2.0 + 5.0*cos(5.55)        | 5.7152       | Y = 4.0 + 5.0*sin(5.55)          | 0.6538
#  113  | 5.60         | X = 2.0 + 5.0*cos(5.60)        | 5.8778       | Y = 4.0 + 5.0*sin(5.60)          | 0.8437
#  114  | 5.65         | X = 2.0 + 5.0*cos(5.65)        | 6.0307       | Y = 4.0 + 5.0*sin(5.65)          | 1.0414
#  115  | 5.70         | X = 2.0 + 5.0*cos(5.70)        | 6.1736       | Y = 4.0 + 5.0*sin(5.70)          | 1.2466
#  116  | 5.75         | X = 2.0 + 5.0*cos(5.75)        | 6.3060       | Y = 4.0 + 5.0*sin(5.75)          | 1.4586
#  117  | 5.80         | X = 2.0 + 5.0*cos(5.80)        | 6.4276       | Y = 4.0 + 5.0*sin(5.80)          | 1.6770
#  118  | 5.85         | X = 2.0 + 5.0*cos(5.85)        | 6.5382       | Y = 4.0 + 5.0*sin(5.85)          | 1.9012
#  119  | 5.90         | X = 2.0 + 5.0*cos(5.90)        | 6.6374       | Y = 4.0 + 5.0*sin(5.90)          | 2.1306
#  120  | 5.95         | X = 2.0 + 5.0*cos(5.95)        | 6.7250       | Y = 4.0 + 5.0*sin(5.95)          | 2.3647
#  121  | 6.00         | X = 2.0 + 5.0*cos(6.00)        | 6.8009       | Y = 4.0 + 5.0*sin(6.00)          | 2.6029
#  122  | 6.05         | X = 2.0 + 5.0*cos(6.05)        | 6.8647       | Y = 4.0 + 5.0*sin(6.05)          | 2.8446
#  123  | 6.10         | X = 2.0 + 5.0*cos(6.10)        | 6.9163       | Y = 4.0 + 5.0*sin(6.10)          | 3.0892
#  124  | 6.15         | X = 2.0 + 5.0*cos(6.15)        | 6.9557       | Y = 4.0 + 5.0*sin(6.15)          | 3.3360
#  125  | 6.20         | X = 2.0 + 5.0*cos(6.20)        | 6.9827       | Y = 4.0 + 5.0*sin(6.20)          | 3.5846
#  126  | 6.25         | X = 2.0 + 5.0*cos(6.25)        | 6.9972       | Y = 4.0 + 5.0*sin(6.25)          | 3.8341
#  127  | 6.28         | X = 2.0 + 5.0*cos(6.28)        | 7.0000       | Y = 4.0 + 5.0*sin(6.28)          | 4.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA ELIPS PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA ELIPS - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 2.0 + 8.0 * cos(θ)  |  y(θ) = 3.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 2.0 + 8.0*cos(0.00)        | 10.0000      | Y = 3.0 + 5.0*sin(0.00)          | 3.0000
#  2    | 0.50         | X = 2.0 + 8.0*cos(0.50)        | 9.0207       | Y = 3.0 + 5.0*sin(0.50)          | 5.3971
#  3    | 1.00         | X = 2.0 + 8.0*cos(1.00)        | 6.3224       | Y = 3.0 + 5.0*sin(1.00)          | 7.2074
#  4    | 1.50         | X = 2.0 + 8.0*cos(1.50)        | 2.5659       | Y = 3.0 + 5.0*sin(1.50)          | 7.9875
#  5    | 2.00         | X = 2.0 + 8.0*cos(2.00)        | -1.3292      | Y = 3.0 + 5.0*sin(2.00)          | 7.5465
#  6    | 2.50         | X = 2.0 + 8.0*cos(2.50)        | -4.4091      | Y = 3.0 + 5.0*sin(2.50)          | 5.9924
#  7    | 3.00         | X = 2.0 + 8.0*cos(3.00)        | -5.9199      | Y = 3.0 + 5.0*sin(3.00)          | 3.7056
#  8    | 3.50         | X = 2.0 + 8.0*cos(3.50)        | -5.4917      | Y = 3.0 + 5.0*sin(3.50)          | 1.2461
#  9    | 4.00         | X = 2.0 + 8.0*cos(4.00)        | -3.2291      | Y = 3.0 + 5.0*sin(4.00)          | -0.7840
#  10   | 4.50         | X = 2.0 + 8.0*cos(4.50)        | 0.3136       | Y = 3.0 + 5.0*sin(4.50)          | -1.8877
#  11   | 5.00         | X = 2.0 + 8.0*cos(5.00)        | 4.2693       | Y = 3.0 + 5.0*sin(5.00)          | -1.7946
#  12   | 5.50         | X = 2.0 + 8.0*cos(5.50)        | 7.6694       | Y = 3.0 + 5.0*sin(5.50)          | -0.5277
#  13   | 6.00         | X = 2.0 + 8.0*cos(6.00)        | 9.6814       | Y = 3.0 + 5.0*sin(6.00)          | 1.6029
#  14   | 6.28         | X = 2.0 + 8.0*cos(6.28)        | 10.0000      | Y = 3.0 + 5.0*sin(6.28)          | 3.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA ELIPS - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 2.0 + 8.0 * cos(θ)  |  y(θ) = 3.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 2.0 + 8.0*cos(0.00)        | 10.0000      | Y = 3.0 + 5.0*sin(0.00)          | 3.0000
#  2    | 0.05         | X = 2.0 + 8.0*cos(0.05)        | 9.9900       | Y = 3.0 + 5.0*sin(0.05)          | 3.2499
#  3    | 0.10         | X = 2.0 + 8.0*cos(0.10)        | 9.9600       | Y = 3.0 + 5.0*sin(0.10)          | 3.4992
#  4    | 0.15         | X = 2.0 + 8.0*cos(0.15)        | 9.9102       | Y = 3.0 + 5.0*sin(0.15)          | 3.7472
#  5    | 0.20         | X = 2.0 + 8.0*cos(0.20)        | 9.8405       | Y = 3.0 + 5.0*sin(0.20)          | 3.9933
#  6    | 0.25         | X = 2.0 + 8.0*cos(0.25)        | 9.7513       | Y = 3.0 + 5.0*sin(0.25)          | 4.2370
#  7    | 0.30         | X = 2.0 + 8.0*cos(0.30)        | 9.6427       | Y = 3.0 + 5.0*sin(0.30)          | 4.4776
#  8    | 0.35         | X = 2.0 + 8.0*cos(0.35)        | 9.5150       | Y = 3.0 + 5.0*sin(0.35)          | 4.7145
#  9    | 0.40         | X = 2.0 + 8.0*cos(0.40)        | 9.3685       | Y = 3.0 + 5.0*sin(0.40)          | 4.9471
#  10   | 0.45         | X = 2.0 + 8.0*cos(0.45)        | 9.2036       | Y = 3.0 + 5.0*sin(0.45)          | 5.1748
#  11   | 0.50         | X = 2.0 + 8.0*cos(0.50)        | 9.0207       | Y = 3.0 + 5.0*sin(0.50)          | 5.3971
#  12   | 0.55         | X = 2.0 + 8.0*cos(0.55)        | 8.8202       | Y = 3.0 + 5.0*sin(0.55)          | 5.6134
#  13   | 0.60         | X = 2.0 + 8.0*cos(0.60)        | 8.6027       | Y = 3.0 + 5.0*sin(0.60)          | 5.8232
#  14   | 0.65         | X = 2.0 + 8.0*cos(0.65)        | 8.3687       | Y = 3.0 + 5.0*sin(0.65)          | 6.0259
#  15   | 0.70         | X = 2.0 + 8.0*cos(0.70)        | 8.1187       | Y = 3.0 + 5.0*sin(0.70)          | 6.2211
#  16   | 0.75         | X = 2.0 + 8.0*cos(0.75)        | 7.8535       | Y = 3.0 + 5.0*sin(0.75)          | 6.4082
#  17   | 0.80         | X = 2.0 + 8.0*cos(0.80)        | 7.5737       | Y = 3.0 + 5.0*sin(0.80)          | 6.5868
#  18   | 0.85         | X = 2.0 + 8.0*cos(0.85)        | 7.2799       | Y = 3.0 + 5.0*sin(0.85)          | 6.7564
#  19   | 0.90         | X = 2.0 + 8.0*cos(0.90)        | 6.9729       | Y = 3.0 + 5.0*sin(0.90)          | 6.9166
#  20   | 0.95         | X = 2.0 + 8.0*cos(0.95)        | 6.6535       | Y = 3.0 + 5.0*sin(0.95)          | 7.0671
#  21   | 1.00         | X = 2.0 + 8.0*cos(1.00)        | 6.3224       | Y = 3.0 + 5.0*sin(1.00)          | 7.2074
#  22   | 1.05         | X = 2.0 + 8.0*cos(1.05)        | 5.9806       | Y = 3.0 + 5.0*sin(1.05)          | 7.3371
#  23   | 1.10         | X = 2.0 + 8.0*cos(1.10)        | 5.6288       | Y = 3.0 + 5.0*sin(1.10)          | 7.4560
#  24   | 1.15         | X = 2.0 + 8.0*cos(1.15)        | 5.2679       | Y = 3.0 + 5.0*sin(1.15)          | 7.5638
#  25   | 1.20         | X = 2.0 + 8.0*cos(1.20)        | 4.8989       | Y = 3.0 + 5.0*sin(1.20)          | 7.6602
#  26   | 1.25         | X = 2.0 + 8.0*cos(1.25)        | 4.5226       | Y = 3.0 + 5.0*sin(1.25)          | 7.7449
#  27   | 1.30         | X = 2.0 + 8.0*cos(1.30)        | 4.1400       | Y = 3.0 + 5.0*sin(1.30)          | 7.8178
#  28   | 1.35         | X = 2.0 + 8.0*cos(1.35)        | 3.7521       | Y = 3.0 + 5.0*sin(1.35)          | 7.8786
#  29   | 1.40         | X = 2.0 + 8.0*cos(1.40)        | 3.3597       | Y = 3.0 + 5.0*sin(1.40)          | 7.9272
#  30   | 1.45         | X = 2.0 + 8.0*cos(1.45)        | 2.9640       | Y = 3.0 + 5.0*sin(1.45)          | 7.9636
#  31   | 1.50         | X = 2.0 + 8.0*cos(1.50)        | 2.5659       | Y = 3.0 + 5.0*sin(1.50)          | 7.9875
#  32   | 1.55         | X = 2.0 + 8.0*cos(1.55)        | 2.1664       | Y = 3.0 + 5.0*sin(1.55)          | 7.9989
#  33   | 1.60         | X = 2.0 + 8.0*cos(1.60)        | 1.7664       | Y = 3.0 + 5.0*sin(1.60)          | 7.9979
#  34   | 1.65         | X = 2.0 + 8.0*cos(1.65)        | 1.3670       | Y = 3.0 + 5.0*sin(1.65)          | 7.9843
#  35   | 1.70         | X = 2.0 + 8.0*cos(1.70)        | 0.9692       | Y = 3.0 + 5.0*sin(1.70)          | 7.9583
#  36   | 1.75         | X = 2.0 + 8.0*cos(1.75)        | 0.5740       | Y = 3.0 + 5.0*sin(1.75)          | 7.9199
#  37   | 1.80         | X = 2.0 + 8.0*cos(1.80)        | 0.1824       | Y = 3.0 + 5.0*sin(1.80)          | 7.8692
#  38   | 1.85         | X = 2.0 + 8.0*cos(1.85)        | -0.2047      | Y = 3.0 + 5.0*sin(1.85)          | 7.8064
#  39   | 1.90         | X = 2.0 + 8.0*cos(1.90)        | -0.5863      | Y = 3.0 + 5.0*sin(1.90)          | 7.7315
#  40   | 1.95         | X = 2.0 + 8.0*cos(1.95)        | -0.9614      | Y = 3.0 + 5.0*sin(1.95)          | 7.6448
#  41   | 2.00         | X = 2.0 + 8.0*cos(2.00)        | -1.3292      | Y = 3.0 + 5.0*sin(2.00)          | 7.5465
#  42   | 2.05         | X = 2.0 + 8.0*cos(2.05)        | -1.6886      | Y = 3.0 + 5.0*sin(2.05)          | 7.4368
#  43   | 2.10         | X = 2.0 + 8.0*cos(2.10)        | -2.0388      | Y = 3.0 + 5.0*sin(2.10)          | 7.3160
#  44   | 2.15         | X = 2.0 + 8.0*cos(2.15)        | -2.3789      | Y = 3.0 + 5.0*sin(2.15)          | 7.1845
#  45   | 2.20         | X = 2.0 + 8.0*cos(2.20)        | -2.7080      | Y = 3.0 + 5.0*sin(2.20)          | 7.0425
#  46   | 2.25         | X = 2.0 + 8.0*cos(2.25)        | -3.0254      | Y = 3.0 + 5.0*sin(2.25)          | 6.8904
#  47   | 2.30         | X = 2.0 + 8.0*cos(2.30)        | -3.3302      | Y = 3.0 + 5.0*sin(2.30)          | 6.7285
#  48   | 2.35         | X = 2.0 + 8.0*cos(2.35)        | -3.6217      | Y = 3.0 + 5.0*sin(2.35)          | 6.5574
#  49   | 2.40         | X = 2.0 + 8.0*cos(2.40)        | -3.8991      | Y = 3.0 + 5.0*sin(2.40)          | 6.3773
#  50   | 2.45         | X = 2.0 + 8.0*cos(2.45)        | -4.1619      | Y = 3.0 + 5.0*sin(2.45)          | 6.1888
#  51   | 2.50         | X = 2.0 + 8.0*cos(2.50)        | -4.4091      | Y = 3.0 + 5.0*sin(2.50)          | 5.9924
#  52   | 2.55         | X = 2.0 + 8.0*cos(2.55)        | -4.6404      | Y = 3.0 + 5.0*sin(2.55)          | 5.7884
#  53   | 2.60         | X = 2.0 + 8.0*cos(2.60)        | -4.8551      | Y = 3.0 + 5.0*sin(2.60)          | 5.5775
#  54   | 2.65         | X = 2.0 + 8.0*cos(2.65)        | -5.0527      | Y = 3.0 + 5.0*sin(2.65)          | 5.3602
#  55   | 2.70         | X = 2.0 + 8.0*cos(2.70)        | -5.2326      | Y = 3.0 + 5.0*sin(2.70)          | 5.1369
#  56   | 2.75         | X = 2.0 + 8.0*cos(2.75)        | -5.3944      | Y = 3.0 + 5.0*sin(2.75)          | 4.9083
#  57   | 2.80         | X = 2.0 + 8.0*cos(2.80)        | -5.5378      | Y = 3.0 + 5.0*sin(2.80)          | 4.6749
#  58   | 2.85         | X = 2.0 + 8.0*cos(2.85)        | -5.6623      | Y = 3.0 + 5.0*sin(2.85)          | 4.4374
#  59   | 2.90         | X = 2.0 + 8.0*cos(2.90)        | -5.7677      | Y = 3.0 + 5.0*sin(2.90)          | 4.1962
#  60   | 2.95         | X = 2.0 + 8.0*cos(2.95)        | -5.8536      | Y = 3.0 + 5.0*sin(2.95)          | 3.9521
#  61   | 3.00         | X = 2.0 + 8.0*cos(3.00)        | -5.9199      | Y = 3.0 + 5.0*sin(3.00)          | 3.7056
#  62   | 3.05         | X = 2.0 + 8.0*cos(3.05)        | -5.9665      | Y = 3.0 + 5.0*sin(3.05)          | 3.4573
#  63   | 3.10         | X = 2.0 + 8.0*cos(3.10)        | -5.9931      | Y = 3.0 + 5.0*sin(3.10)          | 3.2079
#  64   | 3.15         | X = 2.0 + 8.0*cos(3.15)        | -5.9997      | Y = 3.0 + 5.0*sin(3.15)          | 2.9580
#  65   | 3.20         | X = 2.0 + 8.0*cos(3.20)        | -5.9864      | Y = 3.0 + 5.0*sin(3.20)          | 2.7081
#  66   | 3.25         | X = 2.0 + 8.0*cos(3.25)        | -5.9530      | Y = 3.0 + 5.0*sin(3.25)          | 2.4590
#  67   | 3.30         | X = 2.0 + 8.0*cos(3.30)        | -5.8998      | Y = 3.0 + 5.0*sin(3.30)          | 2.2113
#  68   | 3.35         | X = 2.0 + 8.0*cos(3.35)        | -5.8269      | Y = 3.0 + 5.0*sin(3.35)          | 1.9655
#  69   | 3.40         | X = 2.0 + 8.0*cos(3.40)        | -5.7344      | Y = 3.0 + 5.0*sin(3.40)          | 1.7223
#  70   | 3.45         | X = 2.0 + 8.0*cos(3.45)        | -5.6225      | Y = 3.0 + 5.0*sin(3.45)          | 1.4823
#  71   | 3.50         | X = 2.0 + 8.0*cos(3.50)        | -5.4917      | Y = 3.0 + 5.0*sin(3.50)          | 1.2461
#  72   | 3.55         | X = 2.0 + 8.0*cos(3.55)        | -5.3420      | Y = 3.0 + 5.0*sin(3.55)          | 1.0143
#  73   | 3.60         | X = 2.0 + 8.0*cos(3.60)        | -5.1741      | Y = 3.0 + 5.0*sin(3.60)          | 0.7874
#  74   | 3.65         | X = 2.0 + 8.0*cos(3.65)        | -4.9882      | Y = 3.0 + 5.0*sin(3.65)          | 0.5661
#  75   | 3.70         | X = 2.0 + 8.0*cos(3.70)        | -4.7848      | Y = 3.0 + 5.0*sin(3.70)          | 0.3508
#  76   | 3.75         | X = 2.0 + 8.0*cos(3.75)        | -4.5645      | Y = 3.0 + 5.0*sin(3.75)          | 0.1422
#  77   | 3.80         | X = 2.0 + 8.0*cos(3.80)        | -4.3277      | Y = 3.0 + 5.0*sin(3.80)          | -0.0593
#  78   | 3.85         | X = 2.0 + 8.0*cos(3.85)        | -4.0752      | Y = 3.0 + 5.0*sin(3.85)          | -0.2531
#  79   | 3.90         | X = 2.0 + 8.0*cos(3.90)        | -3.8075      | Y = 3.0 + 5.0*sin(3.90)          | -0.4388
#  80   | 3.95         | X = 2.0 + 8.0*cos(3.95)        | -3.5252      | Y = 3.0 + 5.0*sin(3.95)          | -0.6159
#  81   | 4.00         | X = 2.0 + 8.0*cos(4.00)        | -3.2291      | Y = 3.0 + 5.0*sin(4.00)          | -0.7840
#  82   | 4.05         | X = 2.0 + 8.0*cos(4.05)        | -2.9200      | Y = 3.0 + 5.0*sin(4.05)          | -0.9426
#  83   | 4.10         | X = 2.0 + 8.0*cos(4.10)        | -2.5986      | Y = 3.0 + 5.0*sin(4.10)          | -1.0914
#  84   | 4.15         | X = 2.0 + 8.0*cos(4.15)        | -2.2657      | Y = 3.0 + 5.0*sin(4.15)          | -1.2299
#  85   | 4.20         | X = 2.0 + 8.0*cos(4.20)        | -1.9221      | Y = 3.0 + 5.0*sin(4.20)          | -1.3579
#  86   | 4.25         | X = 2.0 + 8.0*cos(4.25)        | -1.5687      | Y = 3.0 + 5.0*sin(4.25)          | -1.4749
#  87   | 4.30         | X = 2.0 + 8.0*cos(4.30)        | -1.2064      | Y = 3.0 + 5.0*sin(4.30)          | -1.5808
#  88   | 4.35         | X = 2.0 + 8.0*cos(4.35)        | -0.8361      | Y = 3.0 + 5.0*sin(4.35)          | -1.6753
#  89   | 4.40         | X = 2.0 + 8.0*cos(4.40)        | -0.4587      | Y = 3.0 + 5.0*sin(4.40)          | -1.7580
#  90   | 4.45         | X = 2.0 + 8.0*cos(4.45)        | -0.0751      | Y = 3.0 + 5.0*sin(4.45)          | -1.8289
#  91   | 4.50         | X = 2.0 + 8.0*cos(4.50)        | 0.3136       | Y = 3.0 + 5.0*sin(4.50)          | -1.8877
#  92   | 4.55         | X = 2.0 + 8.0*cos(4.55)        | 0.7066       | Y = 3.0 + 5.0*sin(4.55)          | -1.9342
#  93   | 4.60         | X = 2.0 + 8.0*cos(4.60)        | 1.1028       | Y = 3.0 + 5.0*sin(4.60)          | -1.9685
#  94   | 4.65         | X = 2.0 + 8.0*cos(4.65)        | 1.5012       | Y = 3.0 + 5.0*sin(4.65)          | -1.9903
#  95   | 4.70         | X = 2.0 + 8.0*cos(4.70)        | 1.9009       | Y = 3.0 + 5.0*sin(4.70)          | -1.9996
#  96   | 4.75         | X = 2.0 + 8.0*cos(4.75)        | 2.3008       | Y = 3.0 + 5.0*sin(4.75)          | -1.9965
#  97   | 4.80         | X = 2.0 + 8.0*cos(4.80)        | 2.7000       | Y = 3.0 + 5.0*sin(4.80)          | -1.9808
#  98   | 4.85         | X = 2.0 + 8.0*cos(4.85)        | 3.0974       | Y = 3.0 + 5.0*sin(4.85)          | -1.9527
#  99   | 4.90         | X = 2.0 + 8.0*cos(4.90)        | 3.4921       | Y = 3.0 + 5.0*sin(4.90)          | -1.9123
#  100  | 4.95         | X = 2.0 + 8.0*cos(4.95)        | 3.8831       | Y = 3.0 + 5.0*sin(4.95)          | -1.8595
#  101  | 5.00         | X = 2.0 + 8.0*cos(5.00)        | 4.2693       | Y = 3.0 + 5.0*sin(5.00)          | -1.7946
#  102  | 5.05         | X = 2.0 + 8.0*cos(5.05)        | 4.6499       | Y = 3.0 + 5.0*sin(5.05)          | -1.7177
#  103  | 5.10         | X = 2.0 + 8.0*cos(5.10)        | 5.0238       | Y = 3.0 + 5.0*sin(5.10)          | -1.6291
#  104  | 5.15         | X = 2.0 + 8.0*cos(5.15)        | 5.3902       | Y = 3.0 + 5.0*sin(5.15)          | -1.5288
#  105  | 5.20         | X = 2.0 + 8.0*cos(5.20)        | 5.7481       | Y = 3.0 + 5.0*sin(5.20)          | -1.4173
#  106  | 5.25         | X = 2.0 + 8.0*cos(5.25)        | 6.0967       | Y = 3.0 + 5.0*sin(5.25)          | -1.2947
#  107  | 5.30         | X = 2.0 + 8.0*cos(5.30)        | 6.4350       | Y = 3.0 + 5.0*sin(5.30)          | -1.1613
#  108  | 5.35         | X = 2.0 + 8.0*cos(5.35)        | 6.7622       | Y = 3.0 + 5.0*sin(5.35)          | -1.0176
#  109  | 5.40         | X = 2.0 + 8.0*cos(5.40)        | 7.0775       | Y = 3.0 + 5.0*sin(5.40)          | -0.8638
#  110  | 5.45         | X = 2.0 + 8.0*cos(5.45)        | 7.3802       | Y = 3.0 + 5.0*sin(5.45)          | -0.7004
#  111  | 5.50         | X = 2.0 + 8.0*cos(5.50)        | 7.6694       | Y = 3.0 + 5.0*sin(5.50)          | -0.5277
#  112  | 5.55         | X = 2.0 + 8.0*cos(5.55)        | 7.9444       | Y = 3.0 + 5.0*sin(5.55)          | -0.3462
#  113  | 5.60         | X = 2.0 + 8.0*cos(5.60)        | 8.2045       | Y = 3.0 + 5.0*sin(5.60)          | -0.1563
#  114  | 5.65         | X = 2.0 + 8.0*cos(5.65)        | 8.4492       | Y = 3.0 + 5.0*sin(5.65)          | 0.0414
#  115  | 5.70         | X = 2.0 + 8.0*cos(5.70)        | 8.6777       | Y = 3.0 + 5.0*sin(5.70)          | 0.2466
#  116  | 5.75         | X = 2.0 + 8.0*cos(5.75)        | 8.8895       | Y = 3.0 + 5.0*sin(5.75)          | 0.4586
#  117  | 5.80         | X = 2.0 + 8.0*cos(5.80)        | 9.0842       | Y = 3.0 + 5.0*sin(5.80)          | 0.6770
#  118  | 5.85         | X = 2.0 + 8.0*cos(5.85)        | 9.2611       | Y = 3.0 + 5.0*sin(5.85)          | 0.9012
#  119  | 5.90         | X = 2.0 + 8.0*cos(5.90)        | 9.4198       | Y = 3.0 + 5.0*sin(5.90)          | 1.1306
#  120  | 5.95         | X = 2.0 + 8.0*cos(5.95)        | 9.5600       | Y = 3.0 + 5.0*sin(5.95)          | 1.3647
#  121  | 6.00         | X = 2.0 + 8.0*cos(6.00)        | 9.6814       | Y = 3.0 + 5.0*sin(6.00)          | 1.6029
#  122  | 6.05         | X = 2.0 + 8.0*cos(6.05)        | 9.7835       | Y = 3.0 + 5.0*sin(6.05)          | 1.8446
#  123  | 6.10         | X = 2.0 + 8.0*cos(6.10)        | 9.8661       | Y = 3.0 + 5.0*sin(6.10)          | 2.0892
#  124  | 6.15         | X = 2.0 + 8.0*cos(6.15)        | 9.9292       | Y = 3.0 + 5.0*sin(6.15)          | 2.3360
#  125  | 6.20         | X = 2.0 + 8.0*cos(6.20)        | 9.9723       | Y = 3.0 + 5.0*sin(6.20)          | 2.5846
#  126  | 6.25         | X = 2.0 + 8.0*cos(6.25)        | 9.9956       | Y = 3.0 + 5.0*sin(6.25)          | 2.8341
#  127  | 6.28         | X = 2.0 + 8.0*cos(6.28)        | 10.0000      | Y = 3.0 + 5.0*sin(6.28)          | 3.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA PARABOLA PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA PARABOLA - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(t) = xp + a * t²  |  y(t) = yp + t
#
#  Persamaan Parametrik (Substitusi):
#    x(t) = 2.0 + 1.0 * t²  |  y(t) = 3.0 + t
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | NILAI t      | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -5.00        | X = 2.0 + 1.0*(-5.00)²         | 27.0000      | Y = 3.0 + -5.00                  | -2.0000
#  2    | -4.00        | X = 2.0 + 1.0*(-4.00)²         | 18.0000      | Y = 3.0 + -4.00                  | -1.0000
#  3    | -3.00        | X = 2.0 + 1.0*(-3.00)²         | 11.0000      | Y = 3.0 + -3.00                  | 0.0000
#  4    | -2.00        | X = 2.0 + 1.0*(-2.00)²         | 6.0000       | Y = 3.0 + -2.00                  | 1.0000
#  5    | -1.00        | X = 2.0 + 1.0*(-1.00)²         | 3.0000       | Y = 3.0 + -1.00                  | 2.0000
#  6    | 0.00         | X = 2.0 + 1.0*(0.00)²          | 2.0000       | Y = 3.0 + 0.00                   | 3.0000
#  7    | 1.00         | X = 2.0 + 1.0*(1.00)²          | 3.0000       | Y = 3.0 + 1.00                   | 4.0000
#  8    | 2.00         | X = 2.0 + 1.0*(2.00)²          | 6.0000       | Y = 3.0 + 2.00                   | 5.0000
#  9    | 3.00         | X = 2.0 + 1.0*(3.00)²          | 11.0000      | Y = 3.0 + 3.00                   | 6.0000
#  10   | 4.00         | X = 2.0 + 1.0*(4.00)²          | 18.0000      | Y = 3.0 + 4.00                   | 7.0000
#  11   | 5.00         | X = 2.0 + 1.0*(5.00)²          | 27.0000      | Y = 3.0 + 5.00                   | 8.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA PARABOLA - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(t) = xp + a * t²  |  y(t) = yp + t
#
#  Persamaan Parametrik (Substitusi):
#    x(t) = 2.0 + 1.0 * t²  |  y(t) = 3.0 + t
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | NILAI t      | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -5.00        | X = 2.0 + 1.0*(-5.00)²         | 27.0000      | Y = 3.0 + -5.00                  | -2.0000
#  2    | -4.90        | X = 2.0 + 1.0*(-4.90)²         | 26.0100      | Y = 3.0 + -4.90                  | -1.9000
#  3    | -4.80        | X = 2.0 + 1.0*(-4.80)²         | 25.0400      | Y = 3.0 + -4.80                  | -1.8000
#  4    | -4.70        | X = 2.0 + 1.0*(-4.70)²         | 24.0900      | Y = 3.0 + -4.70                  | -1.7000
#  5    | -4.60        | X = 2.0 + 1.0*(-4.60)²         | 23.1600      | Y = 3.0 + -4.60                  | -1.6000
#  6    | -4.50        | X = 2.0 + 1.0*(-4.50)²         | 22.2500      | Y = 3.0 + -4.50                  | -1.5000
#  7    | -4.40        | X = 2.0 + 1.0*(-4.40)²         | 21.3600      | Y = 3.0 + -4.40                  | -1.4000
#  8    | -4.30        | X = 2.0 + 1.0*(-4.30)²         | 20.4900      | Y = 3.0 + -4.30                  | -1.3000
#  9    | -4.20        | X = 2.0 + 1.0*(-4.20)²         | 19.6400      | Y = 3.0 + -4.20                  | -1.2000
#  10   | -4.10        | X = 2.0 + 1.0*(-4.10)²         | 18.8100      | Y = 3.0 + -4.10                  | -1.1000
#  11   | -4.00        | X = 2.0 + 1.0*(-4.00)²         | 18.0000      | Y = 3.0 + -4.00                  | -1.0000
#  12   | -3.90        | X = 2.0 + 1.0*(-3.90)²         | 17.2100      | Y = 3.0 + -3.90                  | -0.9000
#  13   | -3.80        | X = 2.0 + 1.0*(-3.80)²         | 16.4400      | Y = 3.0 + -3.80                  | -0.8000
#  14   | -3.70        | X = 2.0 + 1.0*(-3.70)²         | 15.6900      | Y = 3.0 + -3.70                  | -0.7000
#  15   | -3.60        | X = 2.0 + 1.0*(-3.60)²         | 14.9600      | Y = 3.0 + -3.60                  | -0.6000
#  16   | -3.50        | X = 2.0 + 1.0*(-3.50)²         | 14.2500      | Y = 3.0 + -3.50                  | -0.5000
#  17   | -3.40        | X = 2.0 + 1.0*(-3.40)²         | 13.5600      | Y = 3.0 + -3.40                  | -0.4000
#  18   | -3.30        | X = 2.0 + 1.0*(-3.30)²         | 12.8900      | Y = 3.0 + -3.30                  | -0.3000
#  19   | -3.20        | X = 2.0 + 1.0*(-3.20)²         | 12.2400      | Y = 3.0 + -3.20                  | -0.2000
#  20   | -3.10        | X = 2.0 + 1.0*(-3.10)²         | 11.6100      | Y = 3.0 + -3.10                  | -0.1000
#  21   | -3.00        | X = 2.0 + 1.0*(-3.00)²         | 11.0000      | Y = 3.0 + -3.00                  | -0.0000
#  22   | -2.90        | X = 2.0 + 1.0*(-2.90)²         | 10.4100      | Y = 3.0 + -2.90                  | 0.1000
#  23   | -2.80        | X = 2.0 + 1.0*(-2.80)²         | 9.8400       | Y = 3.0 + -2.80                  | 0.2000
#  24   | -2.70        | X = 2.0 + 1.0*(-2.70)²         | 9.2900       | Y = 3.0 + -2.70                  | 0.3000
#  25   | -2.60        | X = 2.0 + 1.0*(-2.60)²         | 8.7600       | Y = 3.0 + -2.60                  | 0.4000
#  26   | -2.50        | X = 2.0 + 1.0*(-2.50)²         | 8.2500       | Y = 3.0 + -2.50                  | 0.5000
#  27   | -2.40        | X = 2.0 + 1.0*(-2.40)²         | 7.7600       | Y = 3.0 + -2.40                  | 0.6000
#  28   | -2.30        | X = 2.0 + 1.0*(-2.30)²         | 7.2900       | Y = 3.0 + -2.30                  | 0.7000
#  29   | -2.20        | X = 2.0 + 1.0*(-2.20)²         | 6.8400       | Y = 3.0 + -2.20                  | 0.8000
#  30   | -2.10        | X = 2.0 + 1.0*(-2.10)²         | 6.4100       | Y = 3.0 + -2.10                  | 0.9000
#  31   | -2.00        | X = 2.0 + 1.0*(-2.00)²         | 6.0000       | Y = 3.0 + -2.00                  | 1.0000
#  32   | -1.90        | X = 2.0 + 1.0*(-1.90)²         | 5.6100       | Y = 3.0 + -1.90                  | 1.1000
#  33   | -1.80        | X = 2.0 + 1.0*(-1.80)²         | 5.2400       | Y = 3.0 + -1.80                  | 1.2000
#  34   | -1.70        | X = 2.0 + 1.0*(-1.70)²         | 4.8900       | Y = 3.0 + -1.70                  | 1.3000
#  35   | -1.60        | X = 2.0 + 1.0*(-1.60)²         | 4.5600       | Y = 3.0 + -1.60                  | 1.4000
#  36   | -1.50        | X = 2.0 + 1.0*(-1.50)²         | 4.2500       | Y = 3.0 + -1.50                  | 1.5000
#  37   | -1.40        | X = 2.0 + 1.0*(-1.40)²         | 3.9600       | Y = 3.0 + -1.40                  | 1.6000
#  38   | -1.30        | X = 2.0 + 1.0*(-1.30)²         | 3.6900       | Y = 3.0 + -1.30                  | 1.7000
#  39   | -1.20        | X = 2.0 + 1.0*(-1.20)²         | 3.4400       | Y = 3.0 + -1.20                  | 1.8000
#  40   | -1.10        | X = 2.0 + 1.0*(-1.10)²         | 3.2100       | Y = 3.0 + -1.10                  | 1.9000
#  41   | -1.00        | X = 2.0 + 1.0*(-1.00)²         | 3.0000       | Y = 3.0 + -1.00                  | 2.0000
#  42   | -0.90        | X = 2.0 + 1.0*(-0.90)²         | 2.8100       | Y = 3.0 + -0.90                  | 2.1000
#  43   | -0.80        | X = 2.0 + 1.0*(-0.80)²         | 2.6400       | Y = 3.0 + -0.80                  | 2.2000
#  44   | -0.70        | X = 2.0 + 1.0*(-0.70)²         | 2.4900       | Y = 3.0 + -0.70                  | 2.3000
#  45   | -0.60        | X = 2.0 + 1.0*(-0.60)²         | 2.3600       | Y = 3.0 + -0.60                  | 2.4000
#  46   | -0.50        | X = 2.0 + 1.0*(-0.50)²         | 2.2500       | Y = 3.0 + -0.50                  | 2.5000
#  47   | -0.40        | X = 2.0 + 1.0*(-0.40)²         | 2.1600       | Y = 3.0 + -0.40                  | 2.6000
#  48   | -0.30        | X = 2.0 + 1.0*(-0.30)²         | 2.0900       | Y = 3.0 + -0.30                  | 2.7000
#  49   | -0.20        | X = 2.0 + 1.0*(-0.20)²         | 2.0400       | Y = 3.0 + -0.20                  | 2.8000
#  50   | -0.10        | X = 2.0 + 1.0*(-0.10)²         | 2.0100       | Y = 3.0 + -0.10                  | 2.9000
#  51   | -0.00        | X = 2.0 + 1.0*(-0.00)²         | 2.0000       | Y = 3.0 + -0.00                  | 3.0000
# ...
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 2.0 + 4.0 / cos(θ)  |  y(θ) = 4.0 + 3.0 * tan(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA CABANG KANAN X         | HASIL X      | FORMULA CABANG KANAN Y           | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -1.25        | X = 2.0 + 4.0/cos(-1.25)       | 14.6854      | Y = 4.0 + 3.0*tan(-1.25)         | -5.0287
#  2    | -1.23        | X = 2.0 + 4.0/cos(-1.23)       | 13.9675      | Y = 4.0 + 3.0*tan(-1.23)         | -4.4594
#  3    | -1.21        | X = 2.0 + 4.0/cos(-1.21)       | 13.3308      | Y = 4.0 + 3.0*tan(-1.21)         | -3.9510
#  4    | -1.19        | X = 2.0 + 4.0/cos(-1.19)       | 12.7625      | Y = 4.0 + 3.0*tan(-1.19)         | -3.4937
#  5    | -1.17        | X = 2.0 + 4.0/cos(-1.17)       | 12.2524      | Y = 4.0 + 3.0*tan(-1.17)         | -3.0799
#  6    | -1.15        | X = 2.0 + 4.0/cos(-1.15)       | 11.7922      | Y = 4.0 + 3.0*tan(-1.15)         | -2.7035
#  7    | -1.13        | X = 2.0 + 4.0/cos(-1.13)       | 11.3752      | Y = 4.0 + 3.0*tan(-1.13)         | -2.3593
#  8    | -1.11        | X = 2.0 + 4.0/cos(-1.11)       | 10.9956      | Y = 4.0 + 3.0*tan(-1.11)         | -2.0430
#  9    | -1.09        | X = 2.0 + 4.0/cos(-1.09)       | 10.6489      | Y = 4.0 + 3.0*tan(-1.09)         | -1.7513
#  10   | -1.07        | X = 2.0 + 4.0/cos(-1.07)       | 10.3312      | Y = 4.0 + 3.0*tan(-1.07)         | -1.4811
#  11   | -1.05        | X = 2.0 + 4.0/cos(-1.05)       | 10.0391      | Y = 4.0 + 3.0*tan(-1.05)         | -1.2299
#  12   | -1.03        | X = 2.0 + 4.0/cos(-1.03)       | 9.7697       | Y = 4.0 + 3.0*tan(-1.03)         | -0.9957
#  13   | -1.01        | X = 2.0 + 4.0/cos(-1.01)       | 9.5208       | Y = 4.0 + 3.0*tan(-1.01)         | -0.7766
#  14   | -0.99        | X = 2.0 + 4.0/cos(-0.99)       | 9.2901       | Y = 4.0 + 3.0*tan(-0.99)         | -0.5710
#  15   | -0.97        | X = 2.0 + 4.0/cos(-0.97)       | 9.0759       | Y = 4.0 + 3.0*tan(-0.97)         | -0.3776
#  16   | -0.95        | X = 2.0 + 4.0/cos(-0.95)       | 8.8766       | Y = 4.0 + 3.0*tan(-0.95)         | -0.1951
#  17   | -0.93        | X = 2.0 + 4.0/cos(-0.93)       | 8.6908       | Y = 4.0 + 3.0*tan(-0.93)         | -0.0226
#  18   | -0.91        | X = 2.0 + 4.0/cos(-0.91)       | 8.5174       | Y = 4.0 + 3.0*tan(-0.91)         | 0.1409
#  19   | -0.89        | X = 2.0 + 4.0/cos(-0.89)       | 8.3551       | Y = 4.0 + 3.0*tan(-0.89)         | 0.2962
#  20   | -0.87        | X = 2.0 + 4.0/cos(-0.87)       | 8.2032       | Y = 4.0 + 3.0*tan(-0.87)         | 0.4440
#  21   | -0.85        | X = 2.0 + 4.0/cos(-0.85)       | 8.0608       | Y = 4.0 + 3.0*tan(-0.85)         | 0.5850
#  22   | -0.83        | X = 2.0 + 4.0/cos(-0.83)       | 7.9270       | Y = 4.0 + 3.0*tan(-0.83)         | 0.7197
#  23   | -0.81        | X = 2.0 + 4.0/cos(-0.81)       | 7.8013       | Y = 4.0 + 3.0*tan(-0.81)         | 0.8486
#  24   | -0.79        | X = 2.0 + 4.0/cos(-0.79)       | 7.6831       | Y = 4.0 + 3.0*tan(-0.79)         | 0.9723
#  25   | -0.77        | X = 2.0 + 4.0/cos(-0.77)       | 7.5717       | Y = 4.0 + 3.0*tan(-0.77)         | 1.0910
#  26   | -0.75        | X = 2.0 + 4.0/cos(-0.75)       | 7.4668       | Y = 4.0 + 3.0*tan(-0.75)         | 1.2052
#  27   | -0.73        | X = 2.0 + 4.0/cos(-0.73)       | 7.3679       | Y = 4.0 + 3.0*tan(-0.73)         | 1.3152
#  28   | -0.71        | X = 2.0 + 4.0/cos(-0.71)       | 7.2745       | Y = 4.0 + 3.0*tan(-0.71)         | 1.4214
#  29   | -0.69        | X = 2.0 + 4.0/cos(-0.69)       | 7.1864       | Y = 4.0 + 3.0*tan(-0.69)         | 1.5240
#  30   | -0.67        | X = 2.0 + 4.0/cos(-0.67)       | 7.1032       | Y = 4.0 + 3.0*tan(-0.67)         | 1.6232
#  31   | -0.65        | X = 2.0 + 4.0/cos(-0.65)       | 7.0246       | Y = 4.0 + 3.0*tan(-0.65)         | 1.7194
#  32   | -0.63        | X = 2.0 + 4.0/cos(-0.63)       | 6.9503       | Y = 4.0 + 3.0*tan(-0.63)         | 1.8127
#  33   | -0.61        | X = 2.0 + 4.0/cos(-0.61)       | 6.8801       | Y = 4.0 + 3.0*tan(-0.61)         | 1.9032
#  34   | -0.59        | X = 2.0 + 4.0/cos(-0.59)       | 6.8138       | Y = 4.0 + 3.0*tan(-0.59)         | 1.9913
#  35   | -0.57        | X = 2.0 + 4.0/cos(-0.57)       | 6.7512       | Y = 4.0 + 3.0*tan(-0.57)         | 2.0771
#  36   | -0.55        | X = 2.0 + 4.0/cos(-0.55)       | 6.6919       | Y = 4.0 + 3.0*tan(-0.55)         | 2.1607
#  37   | -0.53        | X = 2.0 + 4.0/cos(-0.53)       | 6.6360       | Y = 4.0 + 3.0*tan(-0.53)         | 2.2422
#  38   | -0.51        | X = 2.0 + 4.0/cos(-0.51)       | 6.5832       | Y = 4.0 + 3.0*tan(-0.51)         | 2.3219
#  39   | -0.49        | X = 2.0 + 4.0/cos(-0.49)       | 6.5334       | Y = 4.0 + 3.0*tan(-0.49)         | 2.3998
#  40   | -0.47        | X = 2.0 + 4.0/cos(-0.47)       | 6.4865       | Y = 4.0 + 3.0*tan(-0.47)         | 2.4761
#  41   | -0.45        | X = 2.0 + 4.0/cos(-0.45)       | 6.4422       | Y = 4.0 + 3.0*tan(-0.45)         | 2.5508
#  42   | -0.43        | X = 2.0 + 4.0/cos(-0.43)       | 6.4006       | Y = 4.0 + 3.0*tan(-0.43)         | 2.6241
#  43   | -0.41        | X = 2.0 + 4.0/cos(-0.41)       | 6.3615       | Y = 4.0 + 3.0*tan(-0.41)         | 2.6961
#  44   | -0.39        | X = 2.0 + 4.0/cos(-0.39)       | 6.3247       | Y = 4.0 + 3.0*tan(-0.39)         | 2.7668
#  45   | -0.37        | X = 2.0 + 4.0/cos(-0.37)       | 6.2903       | Y = 4.0 + 3.0*tan(-0.37)         | 2.8364
#  46   | -0.35        | X = 2.0 + 4.0/cos(-0.35)       | 6.2582       | Y = 4.0 + 3.0*tan(-0.35)         | 2.9049
#  47   | -0.33        | X = 2.0 + 4.0/cos(-0.33)       | 6.2281       | Y = 4.0 + 3.0*tan(-0.33)         | 2.9724
#  48   | -0.31        | X = 2.0 + 4.0/cos(-0.31)       | 6.2002       | Y = 4.0 + 3.0*tan(-0.31)         | 3.0390
#  49   | -0.29        | X = 2.0 + 4.0/cos(-0.29)       | 6.1743       | Y = 4.0 + 3.0*tan(-0.29)         | 3.1048
#  50   | -0.27        | X = 2.0 + 4.0/cos(-0.27)       | 6.1504       | Y = 4.0 + 3.0*tan(-0.27)         | 3.1697
#  51   | -0.25        | X = 2.0 + 4.0/cos(-0.25)       | 6.1283       | Y = 4.0 + 3.0*tan(-0.25)         | 3.2340
#  52   | -0.23        | X = 2.0 + 4.0/cos(-0.23)       | 6.1082       | Y = 4.0 + 3.0*tan(-0.23)         | 3.2976
#  53   | -0.21        | X = 2.0 + 4.0/cos(-0.21)       | 6.0899       | Y = 4.0 + 3.0*tan(-0.21)         | 3.3606
#  54   | -0.19        | X = 2.0 + 4.0/cos(-0.19)       | 6.0733       | Y = 4.0 + 3.0*tan(-0.19)         | 3.4230
#  55   | -0.17        | X = 2.0 + 4.0/cos(-0.17)       | 6.0585       | Y = 4.0 + 3.0*tan(-0.17)         | 3.4850
#  56   | -0.15        | X = 2.0 + 4.0/cos(-0.15)       | 6.0454       | Y = 4.0 + 3.0*tan(-0.15)         | 3.5466
#  57   | -0.13        | X = 2.0 + 4.0/cos(-0.13)       | 6.0340       | Y = 4.0 + 3.0*tan(-0.13)         | 3.6078
#  58   | -0.11        | X = 2.0 + 4.0/cos(-0.11)       | 6.0243       | Y = 4.0 + 3.0*tan(-0.11)         | 3.6687
#  59   | -0.09        | X = 2.0 + 4.0/cos(-0.09)       | 6.0163       | Y = 4.0 + 3.0*tan(-0.09)         | 3.7293
#  60   | -0.07        | X = 2.0 + 4.0/cos(-0.07)       | 6.0098       | Y = 4.0 + 3.0*tan(-0.07)         | 3.7897
#  61   | -0.05        | X = 2.0 + 4.0/cos(-0.05)       | 6.0050       | Y = 4.0 + 3.0*tan(-0.05)         | 3.8499
#  62   | -0.03        | X = 2.0 + 4.0/cos(-0.03)       | 6.0018       | Y = 4.0 + 3.0*tan(-0.03)         | 3.9100
#  63   | -0.01        | X = 2.0 + 4.0/cos(-0.01)       | 6.0002       | Y = 4.0 + 3.0*tan(-0.01)         | 3.9700
#  64   | 0.01         | X = 2.0 + 4.0/cos(0.01)        | 6.0002       | Y = 4.0 + 3.0*tan(0.01)          | 4.0300
#  65   | 0.03         | X = 2.0 + 4.0/cos(0.03)        | 6.0018       | Y = 4.0 + 3.0*tan(0.03)          | 4.0900
#  66   | 0.05         | X = 2.0 + 4.0/cos(0.05)        | 6.0050       | Y = 4.0 + 3.0*tan(0.05)          | 4.1501
#  67   | 0.07         | X = 2.0 + 4.0/cos(0.07)        | 6.0098       | Y = 4.0 + 3.0*tan(0.07)          | 4.2103
#  68   | 0.09         | X = 2.0 + 4.0/cos(0.09)        | 6.0163       | Y = 4.0 + 3.0*tan(0.09)          | 4.2707
#  69   | 0.11         | X = 2.0 + 4.0/cos(0.11)        | 6.0243       | Y = 4.0 + 3.0*tan(0.11)          | 4.3313
#  70   | 0.13         | X = 2.0 + 4.0/cos(0.13)        | 6.0340       | Y = 4.0 + 3.0*tan(0.13)          | 4.3922
#  71   | 0.15         | X = 2.0 + 4.0/cos(0.15)        | 6.0454       | Y = 4.0 + 3.0*tan(0.15)          | 4.4534
#  72   | 0.17         | X = 2.0 + 4.0/cos(0.17)        | 6.0585       | Y = 4.0 + 3.0*tan(0.17)          | 4.5150
#  73   | 0.19         | X = 2.0 + 4.0/cos(0.19)        | 6.0733       | Y = 4.0 + 3.0*tan(0.19)          | 4.5770
#  74   | 0.21         | X = 2.0 + 4.0/cos(0.21)        | 6.0899       | Y = 4.0 + 3.0*tan(0.21)          | 4.6394
#  75   | 0.23         | X = 2.0 + 4.0/cos(0.23)        | 6.1082       | Y = 4.0 + 3.0*tan(0.23)          | 4.7024
#  76   | 0.25         | X = 2.0 + 4.0/cos(0.25)        | 6.1283       | Y = 4.0 + 3.0*tan(0.25)          | 4.7660
#  77   | 0.27         | X = 2.0 + 4.0/cos(0.27)        | 6.1504       | Y = 4.0 + 3.0*tan(0.27)          | 4.8303
#  78   | 0.29         | X = 2.0 + 4.0/cos(0.29)        | 6.1743       | Y = 4.0 + 3.0*tan(0.29)          | 4.8952
#  79   | 0.31         | X = 2.0 + 4.0/cos(0.31)        | 6.2002       | Y = 4.0 + 3.0*tan(0.31)          | 4.9610
#  80   | 0.33         | X = 2.0 + 4.0/cos(0.33)        | 6.2281       | Y = 4.0 + 3.0*tan(0.33)          | 5.0276
#  81   | 0.35         | X = 2.0 + 4.0/cos(0.35)        | 6.2582       | Y = 4.0 + 3.0*tan(0.35)          | 5.0951
#  82   | 0.37         | X = 2.0 + 4.0/cos(0.37)        | 6.2903       | Y = 4.0 + 3.0*tan(0.37)          | 5.1636
#  83   | 0.39         | X = 2.0 + 4.0/cos(0.39)        | 6.3247       | Y = 4.0 + 3.0*tan(0.39)          | 5.2332
#  84   | 0.41         | X = 2.0 + 4.0/cos(0.41)        | 6.3615       | Y = 4.0 + 3.0*tan(0.41)          | 5.3039
#  85   | 0.43         | X = 2.0 + 4.0/cos(0.43)        | 6.4006       | Y = 4.0 + 3.0*tan(0.43)          | 5.3759
#  86   | 0.45         | X = 2.0 + 4.0/cos(0.45)        | 6.4422       | Y = 4.0 + 3.0*tan(0.45)          | 5.4492
#  87   | 0.47         | X = 2.0 + 4.0/cos(0.47)        | 6.4865       | Y = 4.0 + 3.0*tan(0.47)          | 5.5239
#  88   | 0.49         | X = 2.0 + 4.0/cos(0.49)        | 6.5334       | Y = 4.0 + 3.0*tan(0.49)          | 5.6002
#  89   | 0.51         | X = 2.0 + 4.0/cos(0.51)        | 6.5832       | Y = 4.0 + 3.0*tan(0.51)          | 5.6781
#  90   | 0.53         | X = 2.0 + 4.0/cos(0.53)        | 6.6360       | Y = 4.0 + 3.0*tan(0.53)          | 5.7578
#  91   | 0.55         | X = 2.0 + 4.0/cos(0.55)        | 6.6919       | Y = 4.0 + 3.0*tan(0.55)          | 5.8393
#  92   | 0.57         | X = 2.0 + 4.0/cos(0.57)        | 6.7512       | Y = 4.0 + 3.0*tan(0.57)          | 5.9229
#  93   | 0.59         | X = 2.0 + 4.0/cos(0.59)        | 6.8138       | Y = 4.0 + 3.0*tan(0.59)          | 6.0087
#  94   | 0.61         | X = 2.0 + 4.0/cos(0.61)        | 6.8801       | Y = 4.0 + 3.0*tan(0.61)          | 6.0968
#  95   | 0.63         | X = 2.0 + 4.0/cos(0.63)        | 6.9503       | Y = 4.0 + 3.0*tan(0.63)          | 6.1873
#  96   | 0.65         | X = 2.0 + 4.0/cos(0.65)        | 7.0246       | Y = 4.0 + 3.0*tan(0.65)          | 6.2806
#  97   | 0.67         | X = 2.0 + 4.0/cos(0.67)        | 7.1032       | Y = 4.0 + 3.0*tan(0.67)          | 6.3768
#  98   | 0.69         | X = 2.0 + 4.0/cos(0.69)        | 7.1864       | Y = 4.0 + 3.0*tan(0.69)          | 6.4760
#  99   | 0.71         | X = 2.0 + 4.0/cos(0.71)        | 7.2745       | Y = 4.0 + 3.0*tan(0.71)          | 6.5786
#  100  | 0.73         | X = 2.0 + 4.0/cos(0.73)        | 7.3679       | Y = 4.0 + 3.0*tan(0.73)          | 6.6848
#  101  | 0.75         | X = 2.0 + 4.0/cos(0.75)        | 7.4668       | Y = 4.0 + 3.0*tan(0.75)          | 6.7948
#  102  | 0.77         | X = 2.0 + 4.0/cos(0.77)        | 7.5717       | Y = 4.0 + 3.0*tan(0.77)          | 6.9090
#  103  | 0.79         | X = 2.0 + 4.0/cos(0.79)        | 7.6831       | Y = 4.0 + 3.0*tan(0.79)          | 7.0277
#  104  | 0.81         | X = 2.0 + 4.0/cos(0.81)        | 7.8013       | Y = 4.0 + 3.0*tan(0.81)          | 7.1514
#  105  | 0.83         | X = 2.0 + 4.0/cos(0.83)        | 7.9270       | Y = 4.0 + 3.0*tan(0.83)          | 7.2803
#  106  | 0.85         | X = 2.0 + 4.0/cos(0.85)        | 8.0608       | Y = 4.0 + 3.0*tan(0.85)          | 7.4150
#  107  | 0.87         | X = 2.0 + 4.0/cos(0.87)        | 8.2032       | Y = 4.0 + 3.0*tan(0.87)          | 7.5560
#  108  | 0.89         | X = 2.0 + 4.0/cos(0.89)        | 8.3551       | Y = 4.0 + 3.0*tan(0.89)          | 7.7038
#  109  | 0.91         | X = 2.0 + 4.0/cos(0.91)        | 8.5174       | Y = 4.0 + 3.0*tan(0.91)          | 7.8591
#  110  | 0.93         | X = 2.0 + 4.0/cos(0.93)        | 8.6908       | Y = 4.0 + 3.0*tan(0.93)          | 8.0226
#  111  | 0.95         | X = 2.0 + 4.0/cos(0.95)        | 8.8766       | Y = 4.0 + 3.0*tan(0.95)          | 8.1951
#  112  | 0.97         | X = 2.0 + 4.0/cos(0.97)        | 9.0759       | Y = 4.0 + 3.0*tan(0.97)          | 8.3776
#  113  | 0.99         | X = 2.0 + 4.0/cos(0.99)        | 9.2901       | Y = 4.0 + 3.0*tan(0.99)          | 8.5710
#  114  | 1.01         | X = 2.0 + 4.0/cos(1.01)        | 9.5208       | Y = 4.0 + 3.0*tan(1.01)          | 8.7766
#  115  | 1.03         | X = 2.0 + 4.0/cos(1.03)        | 9.7697       | Y = 4.0 + 3.0*tan(1.03)          | 8.9957
#  116  | 1.05         | X = 2.0 + 4.0/cos(1.05)        | 10.0391      | Y = 4.0 + 3.0*tan(1.05)          | 9.2299
#  117  | 1.07         | X = 2.0 + 4.0/cos(1.07)        | 10.3312      | Y = 4.0 + 3.0*tan(1.07)          | 9.4811
#  118  | 1.09         | X = 2.0 + 4.0/cos(1.09)        | 10.6489      | Y = 4.0 + 3.0*tan(1.09)          | 9.7513
#  119  | 1.11         | X = 2.0 + 4.0/cos(1.11)        | 10.9956      | Y = 4.0 + 3.0*tan(1.11)          | 10.0430
#  120  | 1.13         | X = 2.0 + 4.0/cos(1.13)        | 11.3752      | Y = 4.0 + 3.0*tan(1.13)          | 10.3593
#  121  | 1.15         | X = 2.0 + 4.0/cos(1.15)        | 11.7922      | Y = 4.0 + 3.0*tan(1.15)          | 10.7035
#  122  | 1.17         | X = 2.0 + 4.0/cos(1.17)        | 12.2524      | Y = 4.0 + 3.0*tan(1.17)          | 11.0799
#  123  | 1.19         | X = 2.0 + 4.0/cos(1.19)        | 12.7625      | Y = 4.0 + 3.0*tan(1.19)          | 11.4937
#  124  | 1.21         | X = 2.0 + 4.0/cos(1.21)        | 13.3308      | Y = 4.0 + 3.0*tan(1.21)          | 11.9510
#  125  | 1.23         | X = 2.0 + 4.0/cos(1.23)        | 13.9675      | Y = 4.0 + 3.0*tan(1.23)          | 12.4594
#  126  | 1.25         | X = 2.0 + 4.0/cos(1.25)        | 14.6854      | Y = 4.0 + 3.0*tan(1.25)          | 13.0287
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
#
#  Eksekusi dihentikan. Program selesai dengan sukses!
