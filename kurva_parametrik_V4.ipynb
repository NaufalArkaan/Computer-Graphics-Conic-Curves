# %%
import numpy as np
import matplotlib.pyplot as plt

# Mengatur tema gelap bawaan matplotlib
plt.style.use('dark_background')


# =====================================================
# VISUALISASI UTAMA (GAYA DASHBOARD CLEAN & BINGKAI LUAR)
# =====================================================

def tampilkan_gaya_pro(param_array, x1, y1, xc, yc, a, b, title, n_pts, step, teks_panel, tipe_kurva="ELIPS", x2=None, y2=None):
    
    warna_kurva = '#00FFCC'   # Cyan-Neon
    warna_kurva2 = '#FF007F'  # Magenta-Neon (Khusus Hiperbola)
    warna_titik = '#FFFFFF'   # Putih
    warna_teks  = '#E0E0E0'
    
    fig, ax = plt.subplots(figsize=(11, 6.5))
    fig.subplots_adjust(left=0.08, right=0.70, top=0.88, bottom=0.10)

    # Judul Utama Gambar (SEKARANG MENGGUNAKAN NILAI STEP ASLI DARI INPUT)
    fig.suptitle(
        f"✦ VISUALISASI {tipe_kurva} PARAMETRIK ✦\nResolusi: {title} | Delta = {step:.4f}",
        fontsize=13, fontweight='bold', color=warna_kurva, y=0.96
    )

    # Plot Jalur Kurva dan Titik Sampel
    if x2 is not None and y2 is not None:
        ax.plot(x1, y1, color=warna_kurva, linewidth=2.5, zorder=2, label='Cabang Kanan')
        ax.plot(x2, y2, color=warna_kurva2, linewidth=2.5, zorder=2, label='Cabang Kiri')
        ax.scatter(x1, y1, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5)
        ax.scatter(x2, y2, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5)
    else:
        ax.plot(x1, y1, color=warna_kurva, linewidth=2.5, zorder=2, label=f'Kurva {tipe_kurva.title()}')
        ax.scatter(x1, y1, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5, label=f'Koordinat ({n_pts} titik)')

    # Titik Pusat / Vertex
    ax.scatter(xc, yc, color='#FFFF00', s=100, marker='P', zorder=5)
    ax.annotate(f"PUSAT ({xc:.1f}, {yc:.1f})", xy=(xc, yc), xytext=(5, 5),
                textcoords="offset points", color='#FFFF00', fontsize=8.5, fontweight='bold')

    # --- PENANDA TITIK AWAL & AKHIR ---
    if len(x1) > 0:
        ax.scatter(x1[0], y1[0], color='#00FF00', marker='s', s=80, zorder=6, label='Titik Awal')
        ax.annotate(f"► START ({x1[0]:.1f}, {y1[0]:.1f})", xy=(x1[0], y1[0]), 
                    xytext=(x1[0] + max(a, 1) * 0.15, y1[0] + max(b, 1) * 0.15),
                    color='#00FF00', fontsize=8.5, fontweight='bold',
                    arrowprops=dict(arrowstyle='->', color='#00FF00', lw=1.2))

        ax.scatter(x1[-1], y1[-1], color='#FF9900', marker='x', s=90, zorder=7, label='Titik Akhir')
        ax.annotate(f"■ END ({x1[-1]:.1f}, {y1[-1]:.1f})", xy=(x1[-1], y1[-1]), 
                    xytext=(x1[-1] + max(a, 1) * 0.15, y1[-1] - max(b, 1) * 0.15),
                    color='#FF9900', fontsize=8.5, fontweight='bold',
                    arrowprops=dict(arrowstyle='->', color='#FF9900', lw=1.2))

    # Teks Koordinat Tipis
    step_lbl = max(1, len(x1) // 6)
    for i in range(1, len(x1) - 1, step_lbl):
        ax.annotate(f"({x1[i]:.1f}, {y1[i]:.1f})", (x1[i], y1[i]),
                    textcoords="offset points", xytext=(5, 5), fontsize=7, color='#888888')
        if x2 is not None and y2 is not None:
            ax.annotate(f"({x2[i]:.1f}, {y2[i]:.1f})", (x2[i], y2[i]),
                        textcoords="offset points", xytext=(5, 5), fontsize=7, color='#888888')

    # --- KOTAK INFO PANEL TUNGGAL ---
    bbox_style = dict(boxstyle="square,pad=0.7", fc="#0B1320", ec=warna_kurva, lw=1.2, alpha=0.95)
    
    fig.text(0.73, 0.5, teks_panel, fontsize=9.5, color=warna_teks, family='monospace', bbox=bbox_style, va='center')

    # Konfigurasi Batas Grafik
    if tipe_kurva in ("ELIPS", "LINGKARAN"):
        ax.set_aspect('equal', adjustable='box')
        ax.set_xlim(xc - a * 1.6, xc + a * 1.6)
        ax.set_ylim(yc - b * 1.6, yc + b * 1.6)
    else:
        all_x = x1 if x2 is None else np.concatenate([x1, x2])
        all_y = y1 if y2 is None else np.concatenate([y1, y2])
        if len(all_x) > 0 and len(all_y) > 0:
            ax.set_xlim(np.min(all_x) - 2, np.max(all_x) + 2)
            ax.set_ylim(np.min(all_y) - 2, np.max(all_y) + 2)

    # Style Background Grid
    ax.grid(True, linestyle='--', alpha=0.3, color='gray')
    ax.tick_params(colors=warna_teks, labelsize=9)
    for spine in ax.spines.values():
        spine.set_color('white')
        spine.set_linewidth(1)

    ax.axvline(xc, color='gray', linestyle=':', linewidth=0.8, alpha=0.4, zorder=1)
    ax.axhline(yc, color='gray', linestyle=':', linewidth=0.8, alpha=0.4, zorder=1)
    ax.legend(loc='lower left', facecolor='#0B1320', edgecolor='none', labelcolor='white', fontsize=8)
    plt.show()


# =====================================================
# INPUT HELPER UTALITAS
# =====================================================

def input_float(prompt):
    while True:
        try:
            return float(input(prompt))
        except ValueError:
            print("  ⚠  Masukkan angka koordinat yang valid!")

def input_step(prompt):
    while True:
        val = input_float(prompt)
        if val > 0:
            return val
        print("  ⚠  Nilai step pembagi harus lebih besar dari 0!")


# =====================================================
# BANGUN 1: LINGKARAN
# =====================================================

def lingkaran():
    print("================================================================================")
    print(" COMPILER KURVA LINGKARAN PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat X (xc) [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Y (yc) [contoh: 0.0] : ")
    r  = input_float("Ukuran Radius  (r) [contoh: 5.0] : ")
    if r <= 0:
        print("  ⚠  Radius wajib bernilai positif!")
        return

    step_besar = input_step("Jarak Interval Step Besar θ (rad) [contoh: 0.5]  : ")
    step_kecil = input_step("Jarak Interval Step Kecil θ (rad) [contoh: 0.05] : ")

    configs = [
        ("Resolusi Rendah", step_besar),
        ("Resolusi Tinggi", step_kecil),
    ]

    keliling = 2 * np.pi * r
    luas = np.pi * r**2

    for title, step_val in configs:
        theta = np.append(np.arange(0, 2 * np.pi, step_val), 2 * np.pi)
        n_pts = len(theta)

        x = xc + r * np.cos(theta)
        y = yc + r * np.sin(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA LINGKARAN - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {r} * cos(θ)  |  y(θ) = {yc} + {r} * sin(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {r}*cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {r}*sin({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI LINGKARAN\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Radius (r)   : {r}\n"
            f" Luas Area    : {luas:.4f}\n"
            f" Keliling     : {keliling:.4f}\n"
            f" Total Titik  : {n_pts}\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})² + (y-{yc})² = {r}²"
        )
        tampilkan_gaya_pro(theta, x, y, xc, yc, r, r, title, n_pts, step_val, teks_panel, "LINGKARAN")


# =====================================================
# BANGUN 2: ELIPS
# =====================================================

def elips():
    print("================================================================================")
    print(" COMPILER KURVA ELIPS PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat X (xc)         [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Y (yc)         [contoh: 0.0] : ")
    a  = input_float("Panjang Sumbu Horizontal a [contoh: 8.0] : ")
    b  = input_float("Panjang Sumbu Vertikal b   [contoh: 5.0] : ")
    if a <= 0 or b <= 0:
        print("  ⚠  Nilai sumbu komponen harus di atas 0!")
        return

    step_besar = input_step("Jarak Interval Step Besar θ (rad) [contoh: 0.5]  : ")
    step_kecil = input_step("Jarak Interval Step Kecil θ (rad) [contoh: 0.05] : ")

    c = np.sqrt(abs(a**2 - b**2))
    e = c / max(a, b)
    luas = np.pi * a * b
    keliling = np.pi * (3*(a+b) - np.sqrt((3*a+b)*(a+3*b))) # Ramanujan approx

    configs = [
        ("Resolusi Rendah", step_besar),
        ("Resolusi Tinggi", step_kecil),
    ]

    for title, step_val in configs:
        theta = np.append(np.arange(0, 2 * np.pi, step_val), 2 * np.pi)
        n_pts = len(theta)

        x = xc + a * np.cos(theta)
        y = yc + b * np.sin(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA ELIPS - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {a} * cos(θ)  |  y(θ) = {yc} + {b} * sin(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {a}*cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {b}*sin({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI ELIPS\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Sumbu hor (a): {a}\n"
            f" Sumbu ver (b): {b}\n"
            f" Jarak Fokus c: {c:.4f}\n"
            f" Eksentrisitas: {e:.4f}\n"
            f" Luas Area    : {luas:.4f}\n"
            f" Keliling     : {keliling:.4f}\n"
            f" Total Titik  : {n_pts}\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})²/{a}² + (y-{yc})²/{b}² = 1"
        )
        tampilkan_gaya_pro(theta, x, y, xc, yc, a, b, title, n_pts, step_val, teks_panel, "ELIPS")


# =====================================================
# BANGUN 3: PARABOLA (FIX 100% SESUAI PPT DOSEN)
# =====================================================

def parabola():
    print("================================================================================")
    print(" COMPILER KURVA PARABOLA PARAMETRIK")
    print("================================================================================\n")
    
    xp = input_float("Titik Vertex X (xp)  [contoh: 0.0] : ")
    yp = input_float("Titik Vertex Y (yp)  [contoh: 0.0] : ")
    a  = input_float("Jarak Fokus a        [contoh: 1.0] : ")

    step_besar = input_step("Interval Step Batas Besar parameter t [contoh: 1.0] : ")
    step_kecil = input_step("Interval Step Batas Kecil parameter t [contoh: 0.1] : ")

    configs = [("Resolusi Rendah", step_besar), ("Resolusi Tinggi", step_kecil)]

    for title, step_val in configs:
        t = np.arange(-5, 5 + step_val, step_val)
        n_pts = len(t)
        
        # PERUBAHAN RUMUS KALKULASI MENGIKUTI PPT DOSEN
        x = xp + a * t**2
        y = yp + 2 * a * t
        
        # Persamaan kartesian yang setara dengan paramaterisasi PPT Dosen
        rumus_std = f"(y-{yp})² = {4*a} * (x-{xp})"

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA PARABOLA - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Sesuai PPT Dosen):")
        print(f"   x(t) = xp + a * t²  |  y(t) = yp + 2 * a * t\n")
            
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(t) = {xp} + {a} * t²  |  y(t) = {yp} + 2 * {a} * t\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'NILAI t':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        
        for i in range(len(t)):
            calc_x = f"X = {xp} + {a}*({t[i]:.2f})²"
            calc_y = f"Y = {yp} + 2*{a}*({t[i]:.2f})"
            print(f" {i+1:<4} | {t[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI PARABOLA\n"
            f" ════════════════════════════\n"
            f" Vertex (xp,yp): ({xp:.2f}, {yp:.2f})\n"
            f" Orientasi     : Horizontal\n"
            f" Jarak Fokus a : {a}\n"
            f" Total Titik   : {n_pts}\n"
            f" Skema         : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" {rumus_std}"
        )
        tampilkan_gaya_pro(t, x, y, xp, yp, a, a, title, n_pts, step_val, teks_panel, "PARABOLA")


# =====================================================
# BANGUN 4: HIPERBOLA (FIX KAKI SIMETRIS & TEKS SEC(THETA))
# =====================================================

def hiperbola():
    print("================================================================================")
    print(" COMPILER KURVA HIPERBOLA PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat Domain X (xc)      [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Domain Y (yc)      [contoh: 0.0] : ")
    a  = input_float("Semi-Sumbu Transversal Nilai a [contoh: 4.0] : ")
    b  = input_float("Semi-Sumbu Konjugasi Nilai b   [contoh: 3.0] : ")
    if a <= 0 or b <= 0: return

    step_besar = input_step("Interval Pembagi Step Besar θ (rad) [contoh: 0.2]  : ")
    step_kecil = input_step("Interval Pembagi Step Kecil θ (rad) [contoh: 0.02] : ")

    # Batas 1.25 mendekati pi/2 (1.57) untuk menghindari error infinity (tak terhingga)
    batas = 1.25  
    configs = [("Resolusi Rendah", step_besar), ("Resolusi Tinggi", step_kecil)]

    c = np.sqrt(a**2 + b**2)
    e = c / a

    for title, step_val in configs:
        
        # PERBAIKAN: Mengunci array agar titik akhir selalu simetris tepat di batas (1.25)
        # Menghindari kaki panjang sebelah pada resolusi rendah
        theta = np.append(np.arange(-batas, batas, step_val), batas)
        n_pts = len(theta)

        # KALKULASI ASLI DENGAN 2 CABANG (Agar gambar visualnya utuh)
        # 1 / np.cos(theta) adalah ekuivalen matematis dari sec(theta)
        x1 = xc + a / np.cos(theta); y1 = yc + b * np.tan(theta) # Cabang Kanan
        x2 = xc - a / np.cos(theta); y2 = yc + b * np.tan(theta) # Cabang Kiri (Pencerminan)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA HIPERBOLA (CABANG KANAN) - {title.upper()}")
        print("=" * 115)
        
        # TEKS KOSMETIK: Menggunakan kata 'sec(θ)' agar persis PPT Dosen
        print(f" Persamaan Parametrik (Sesuai PPT Dosen):")
        print(f"   x(θ) = xc + a * sec(θ)  |  y(θ) = yc + b * tan(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {a} * sec(θ)  |  y(θ) = {yc} + {b} * tan(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA CABANG KANAN X':<30} | {'HASIL X':<12} | {'FORMULA CABANG KANAN Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            # Mencetak tabel dengan teks 'sec'
            calc_x = f"X = {xc} + {a}*sec({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {b}*tan({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x1[i]:<12.4f} | {calc_y:<32} | {y1[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI HIPERBOLA\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Transversal a: {a}\n"
            f" Konjugasi b  : {b}\n"
            f" Jarak Fokus c: {c:.4f}\n"
            f" Eksentrisitas: {e:.4f}\n"
            f" Total Titik  : {n_pts} per cb\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})²/{a}² - (y-{yc})²/{b}² = 1"
        )
        
        # Memanggil x1 dan x2 agar kedua lengkungan digambar seimbang di layar
        tampilkan_gaya_pro(theta, x1, y1, xc, yc, a, b, title, n_pts, step_val, teks_panel, "HIPERBOLA", x2, y2)


# =====================================================
# HUB KONTROL MENU UTAMA
# =====================================================

def menu():
    while True:
        print("\n" + "═" * 42)
        print("   SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF   ")
        print("═" * 42)
        print("  [1]  Kurva Lingkaran Parametrik")
        print("  [2]  Kurva Elips Parametrik")
        print("  [3]  Kurva Parabola Parametrik")
        print("  [4]  Kurva Hiperbola Parametrik")
        print("  [0]  Hentikan & Keluar Program")
        print("─" * 42)

        pilih = input(" Tentukan Opsi Operasi Menu : ").strip()

        if pilih == "1": lingkaran()
        elif pilih == "2": elips()
        elif pilih == "3": parabola()
        elif pilih == "4": hiperbola()
        elif pilih == "0":
            print("\n Eksekusi dihentikan. Program selesai dengan sukses!\n")
            break
        else: print("  ⚠  Pilihan tidak tersedia!")


if __name__ == "__main__":
    menu()
# Out:
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA HIPERBOLA PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA HIPERBOLA (CABANG KANAN) - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Sesuai PPT Dosen):
#    x(θ) = xc + a * sec(θ)  |  y(θ) = yc + b * tan(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 4.0 * sec(θ)  |  y(θ) = 0.0 + 3.0 * tan(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA CABANG KANAN X         | HASIL X      | FORMULA CABANG KANAN Y           | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -1.25        | X = 0.0 + 4.0*sec(-1.25)       | 12.6854      | Y = 0.0 + 3.0*tan(-1.25)         | -9.0287
#  2    | -1.05        | X = 0.0 + 4.0*sec(-1.05)       | 8.0391       | Y = 0.0 + 3.0*tan(-1.05)         | -5.2299
#  3    | -0.85        | X = 0.0 + 4.0*sec(-0.85)       | 6.0608       | Y = 0.0 + 3.0*tan(-0.85)         | -3.4150
#  4    | -0.65        | X = 0.0 + 4.0*sec(-0.65)       | 5.0246       | Y = 0.0 + 3.0*tan(-0.65)         | -2.2806
#  5    | -0.45        | X = 0.0 + 4.0*sec(-0.45)       | 4.4422       | Y = 0.0 + 3.0*tan(-0.45)         | -1.4492
#  6    | -0.25        | X = 0.0 + 4.0*sec(-0.25)       | 4.1283       | Y = 0.0 + 3.0*tan(-0.25)         | -0.7660
#  7    | -0.05        | X = 0.0 + 4.0*sec(-0.05)       | 4.0050       | Y = 0.0 + 3.0*tan(-0.05)         | -0.1501
#  8    | 0.15         | X = 0.0 + 4.0*sec(0.15)        | 4.0454       | Y = 0.0 + 3.0*tan(0.15)          | 0.4534
#  9    | 0.35         | X = 0.0 + 4.0*sec(0.35)        | 4.2582       | Y = 0.0 + 3.0*tan(0.35)          | 1.0951
#  10   | 0.55         | X = 0.0 + 4.0*sec(0.55)        | 4.6919       | Y = 0.0 + 3.0*tan(0.55)          | 1.8393
#  11   | 0.75         | X = 0.0 + 4.0*sec(0.75)        | 5.4668       | Y = 0.0 + 3.0*tan(0.75)          | 2.7948
#  12   | 0.95         | X = 0.0 + 4.0*sec(0.95)        | 6.8766       | Y = 0.0 + 3.0*tan(0.95)          | 4.1951
#  13   | 1.15         | X = 0.0 + 4.0*sec(1.15)        | 9.7922       | Y = 0.0 + 3.0*tan(1.15)          | 6.7035
#  14   | 1.25         | X = 0.0 + 4.0*sec(1.25)        | 12.6854      | Y = 0.0 + 3.0*tan(1.25)          | 9.0287
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA HIPERBOLA (CABANG KANAN) - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Sesuai PPT Dosen):
#    x(θ) = xc + a * sec(θ)  |  y(θ) = yc + b * tan(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 4.0 * sec(θ)  |  y(θ) = 0.0 + 3.0 * tan(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA CABANG KANAN X         | HASIL X      | FORMULA CABANG KANAN Y           | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -1.25        | X = 0.0 + 4.0*sec(-1.25)       | 12.6854      | Y = 0.0 + 3.0*tan(-1.25)         | -9.0287
#  2    | -1.23        | X = 0.0 + 4.0*sec(-1.23)       | 11.9675      | Y = 0.0 + 3.0*tan(-1.23)         | -8.4594
#  3    | -1.21        | X = 0.0 + 4.0*sec(-1.21)       | 11.3308      | Y = 0.0 + 3.0*tan(-1.21)         | -7.9510
#  4    | -1.19        | X = 0.0 + 4.0*sec(-1.19)       | 10.7625      | Y = 0.0 + 3.0*tan(-1.19)         | -7.4937
#  5    | -1.17        | X = 0.0 + 4.0*sec(-1.17)       | 10.2524      | Y = 0.0 + 3.0*tan(-1.17)         | -7.0799
#  6    | -1.15        | X = 0.0 + 4.0*sec(-1.15)       | 9.7922       | Y = 0.0 + 3.0*tan(-1.15)         | -6.7035
#  7    | -1.13        | X = 0.0 + 4.0*sec(-1.13)       | 9.3752       | Y = 0.0 + 3.0*tan(-1.13)         | -6.3593
#  8    | -1.11        | X = 0.0 + 4.0*sec(-1.11)       | 8.9956       | Y = 0.0 + 3.0*tan(-1.11)         | -6.0430
#  9    | -1.09        | X = 0.0 + 4.0*sec(-1.09)       | 8.6489       | Y = 0.0 + 3.0*tan(-1.09)         | -5.7513
#  10   | -1.07        | X = 0.0 + 4.0*sec(-1.07)       | 8.3312       | Y = 0.0 + 3.0*tan(-1.07)         | -5.4811
#  11   | -1.05        | X = 0.0 + 4.0*sec(-1.05)       | 8.0391       | Y = 0.0 + 3.0*tan(-1.05)         | -5.2299
#  12   | -1.03        | X = 0.0 + 4.0*sec(-1.03)       | 7.7697       | Y = 0.0 + 3.0*tan(-1.03)         | -4.9957
#  13   | -1.01        | X = 0.0 + 4.0*sec(-1.01)       | 7.5208       | Y = 0.0 + 3.0*tan(-1.01)         | -4.7766
#  14   | -0.99        | X = 0.0 + 4.0*sec(-0.99)       | 7.2901       | Y = 0.0 + 3.0*tan(-0.99)         | -4.5710
#  15   | -0.97        | X = 0.0 + 4.0*sec(-0.97)       | 7.0759       | Y = 0.0 + 3.0*tan(-0.97)         | -4.3776
#  16   | -0.95        | X = 0.0 + 4.0*sec(-0.95)       | 6.8766       | Y = 0.0 + 3.0*tan(-0.95)         | -4.1951
#  17   | -0.93        | X = 0.0 + 4.0*sec(-0.93)       | 6.6908       | Y = 0.0 + 3.0*tan(-0.93)         | -4.0226
#  18   | -0.91        | X = 0.0 + 4.0*sec(-0.91)       | 6.5174       | Y = 0.0 + 3.0*tan(-0.91)         | -3.8591
#  19   | -0.89        | X = 0.0 + 4.0*sec(-0.89)       | 6.3551       | Y = 0.0 + 3.0*tan(-0.89)         | -3.7038
#  20   | -0.87        | X = 0.0 + 4.0*sec(-0.87)       | 6.2032       | Y = 0.0 + 3.0*tan(-0.87)         | -3.5560
#  21   | -0.85        | X = 0.0 + 4.0*sec(-0.85)       | 6.0608       | Y = 0.0 + 3.0*tan(-0.85)         | -3.4150
#  22   | -0.83        | X = 0.0 + 4.0*sec(-0.83)       | 5.9270       | Y = 0.0 + 3.0*tan(-0.83)         | -3.2803
#  23   | -0.81        | X = 0.0 + 4.0*sec(-0.81)       | 5.8013       | Y = 0.0 + 3.0*tan(-0.81)         | -3.1514
#  24   | -0.79        | X = 0.0 + 4.0*sec(-0.79)       | 5.6831       | Y = 0.0 + 3.0*tan(-0.79)         | -3.0277
#  25   | -0.77        | X = 0.0 + 4.0*sec(-0.77)       | 5.5717       | Y = 0.0 + 3.0*tan(-0.77)         | -2.9090
#  26   | -0.75        | X = 0.0 + 4.0*sec(-0.75)       | 5.4668       | Y = 0.0 + 3.0*tan(-0.75)         | -2.7948
#  27   | -0.73        | X = 0.0 + 4.0*sec(-0.73)       | 5.3679       | Y = 0.0 + 3.0*tan(-0.73)         | -2.6848
#  28   | -0.71        | X = 0.0 + 4.0*sec(-0.71)       | 5.2745       | Y = 0.0 + 3.0*tan(-0.71)         | -2.5786
#  29   | -0.69        | X = 0.0 + 4.0*sec(-0.69)       | 5.1864       | Y = 0.0 + 3.0*tan(-0.69)         | -2.4760
#  30   | -0.67        | X = 0.0 + 4.0*sec(-0.67)       | 5.1032       | Y = 0.0 + 3.0*tan(-0.67)         | -2.3768
#  31   | -0.65        | X = 0.0 + 4.0*sec(-0.65)       | 5.0246       | Y = 0.0 + 3.0*tan(-0.65)         | -2.2806
#  32   | -0.63        | X = 0.0 + 4.0*sec(-0.63)       | 4.9503       | Y = 0.0 + 3.0*tan(-0.63)         | -2.1873
#  33   | -0.61        | X = 0.0 + 4.0*sec(-0.61)       | 4.8801       | Y = 0.0 + 3.0*tan(-0.61)         | -2.0968
#  34   | -0.59        | X = 0.0 + 4.0*sec(-0.59)       | 4.8138       | Y = 0.0 + 3.0*tan(-0.59)         | -2.0087
#  35   | -0.57        | X = 0.0 + 4.0*sec(-0.57)       | 4.7512       | Y = 0.0 + 3.0*tan(-0.57)         | -1.9229
#  36   | -0.55        | X = 0.0 + 4.0*sec(-0.55)       | 4.6919       | Y = 0.0 + 3.0*tan(-0.55)         | -1.8393
#  37   | -0.53        | X = 0.0 + 4.0*sec(-0.53)       | 4.6360       | Y = 0.0 + 3.0*tan(-0.53)         | -1.7578
#  38   | -0.51        | X = 0.0 + 4.0*sec(-0.51)       | 4.5832       | Y = 0.0 + 3.0*tan(-0.51)         | -1.6781
#  39   | -0.49        | X = 0.0 + 4.0*sec(-0.49)       | 4.5334       | Y = 0.0 + 3.0*tan(-0.49)         | -1.6002
#  40   | -0.47        | X = 0.0 + 4.0*sec(-0.47)       | 4.4865       | Y = 0.0 + 3.0*tan(-0.47)         | -1.5239
#  41   | -0.45        | X = 0.0 + 4.0*sec(-0.45)       | 4.4422       | Y = 0.0 + 3.0*tan(-0.45)         | -1.4492
#  42   | -0.43        | X = 0.0 + 4.0*sec(-0.43)       | 4.4006       | Y = 0.0 + 3.0*tan(-0.43)         | -1.3759
#  43   | -0.41        | X = 0.0 + 4.0*sec(-0.41)       | 4.3615       | Y = 0.0 + 3.0*tan(-0.41)         | -1.3039
#  44   | -0.39        | X = 0.0 + 4.0*sec(-0.39)       | 4.3247       | Y = 0.0 + 3.0*tan(-0.39)         | -1.2332
#  45   | -0.37        | X = 0.0 + 4.0*sec(-0.37)       | 4.2903       | Y = 0.0 + 3.0*tan(-0.37)         | -1.1636
#  46   | -0.35        | X = 0.0 + 4.0*sec(-0.35)       | 4.2582       | Y = 0.0 + 3.0*tan(-0.35)         | -1.0951
#  47   | -0.33        | X = 0.0 + 4.0*sec(-0.33)       | 4.2281       | Y = 0.0 + 3.0*tan(-0.33)         | -1.0276
#  48   | -0.31        | X = 0.0 + 4.0*sec(-0.31)       | 4.2002       | Y = 0.0 + 3.0*tan(-0.31)         | -0.9610
#  49   | -0.29        | X = 0.0 + 4.0*sec(-0.29)       | 4.1743       | Y = 0.0 + 3.0*tan(-0.29)         | -0.8952
#  50   | -0.27        | X = 0.0 + 4.0*sec(-0.27)       | 4.1504       | Y = 0.0 + 3.0*tan(-0.27)         | -0.8303
#  51   | -0.25        | X = 0.0 + 4.0*sec(-0.25)       | 4.1283       | Y = 0.0 + 3.0*tan(-0.25)         | -0.7660
#  52   | -0.23        | X = 0.0 + 4.0*sec(-0.23)       | 4.1082       | Y = 0.0 + 3.0*tan(-0.23)         | -0.7024
#  53   | -0.21        | X = 0.0 + 4.0*sec(-0.21)       | 4.0899       | Y = 0.0 + 3.0*tan(-0.21)         | -0.6394
#  54   | -0.19        | X = 0.0 + 4.0*sec(-0.19)       | 4.0733       | Y = 0.0 + 3.0*tan(-0.19)         | -0.5770
#  55   | -0.17        | X = 0.0 + 4.0*sec(-0.17)       | 4.0585       | Y = 0.0 + 3.0*tan(-0.17)         | -0.5150
#  56   | -0.15        | X = 0.0 + 4.0*sec(-0.15)       | 4.0454       | Y = 0.0 + 3.0*tan(-0.15)         | -0.4534
#  57   | -0.13        | X = 0.0 + 4.0*sec(-0.13)       | 4.0340       | Y = 0.0 + 3.0*tan(-0.13)         | -0.3922
#  58   | -0.11        | X = 0.0 + 4.0*sec(-0.11)       | 4.0243       | Y = 0.0 + 3.0*tan(-0.11)         | -0.3313
#  59   | -0.09        | X = 0.0 + 4.0*sec(-0.09)       | 4.0163       | Y = 0.0 + 3.0*tan(-0.09)         | -0.2707
#  60   | -0.07        | X = 0.0 + 4.0*sec(-0.07)       | 4.0098       | Y = 0.0 + 3.0*tan(-0.07)         | -0.2103
#  61   | -0.05        | X = 0.0 + 4.0*sec(-0.05)       | 4.0050       | Y = 0.0 + 3.0*tan(-0.05)         | -0.1501
#  62   | -0.03        | X = 0.0 + 4.0*sec(-0.03)       | 4.0018       | Y = 0.0 + 3.0*tan(-0.03)         | -0.0900
#  63   | -0.01        | X = 0.0 + 4.0*sec(-0.01)       | 4.0002       | Y = 0.0 + 3.0*tan(-0.01)         | -0.0300
#  64   | 0.01         | X = 0.0 + 4.0*sec(0.01)        | 4.0002       | Y = 0.0 + 3.0*tan(0.01)          | 0.0300
#  65   | 0.03         | X = 0.0 + 4.0*sec(0.03)        | 4.0018       | Y = 0.0 + 3.0*tan(0.03)          | 0.0900
#  66   | 0.05         | X = 0.0 + 4.0*sec(0.05)        | 4.0050       | Y = 0.0 + 3.0*tan(0.05)          | 0.1501
#  67   | 0.07         | X = 0.0 + 4.0*sec(0.07)        | 4.0098       | Y = 0.0 + 3.0*tan(0.07)          | 0.2103
#  68   | 0.09         | X = 0.0 + 4.0*sec(0.09)        | 4.0163       | Y = 0.0 + 3.0*tan(0.09)          | 0.2707
#  69   | 0.11         | X = 0.0 + 4.0*sec(0.11)        | 4.0243       | Y = 0.0 + 3.0*tan(0.11)          | 0.3313
#  70   | 0.13         | X = 0.0 + 4.0*sec(0.13)        | 4.0340       | Y = 0.0 + 3.0*tan(0.13)          | 0.3922
#  71   | 0.15         | X = 0.0 + 4.0*sec(0.15)        | 4.0454       | Y = 0.0 + 3.0*tan(0.15)          | 0.4534
#  72   | 0.17         | X = 0.0 + 4.0*sec(0.17)        | 4.0585       | Y = 0.0 + 3.0*tan(0.17)          | 0.5150
#  73   | 0.19         | X = 0.0 + 4.0*sec(0.19)        | 4.0733       | Y = 0.0 + 3.0*tan(0.19)          | 0.5770
#  74   | 0.21         | X = 0.0 + 4.0*sec(0.21)        | 4.0899       | Y = 0.0 + 3.0*tan(0.21)          | 0.6394
#  75   | 0.23         | X = 0.0 + 4.0*sec(0.23)        | 4.1082       | Y = 0.0 + 3.0*tan(0.23)          | 0.7024
#  76   | 0.25         | X = 0.0 + 4.0*sec(0.25)        | 4.1283       | Y = 0.0 + 3.0*tan(0.25)          | 0.7660
#  77   | 0.27         | X = 0.0 + 4.0*sec(0.27)        | 4.1504       | Y = 0.0 + 3.0*tan(0.27)          | 0.8303
#  78   | 0.29         | X = 0.0 + 4.0*sec(0.29)        | 4.1743       | Y = 0.0 + 3.0*tan(0.29)          | 0.8952
#  79   | 0.31         | X = 0.0 + 4.0*sec(0.31)        | 4.2002       | Y = 0.0 + 3.0*tan(0.31)          | 0.9610
#  80   | 0.33         | X = 0.0 + 4.0*sec(0.33)        | 4.2281       | Y = 0.0 + 3.0*tan(0.33)          | 1.0276
#  81   | 0.35         | X = 0.0 + 4.0*sec(0.35)        | 4.2582       | Y = 0.0 + 3.0*tan(0.35)          | 1.0951
#  82   | 0.37         | X = 0.0 + 4.0*sec(0.37)        | 4.2903       | Y = 0.0 + 3.0*tan(0.37)          | 1.1636
#  83   | 0.39         | X = 0.0 + 4.0*sec(0.39)        | 4.3247       | Y = 0.0 + 3.0*tan(0.39)          | 1.2332
#  84   | 0.41         | X = 0.0 + 4.0*sec(0.41)        | 4.3615       | Y = 0.0 + 3.0*tan(0.41)          | 1.3039
#  85   | 0.43         | X = 0.0 + 4.0*sec(0.43)        | 4.4006       | Y = 0.0 + 3.0*tan(0.43)          | 1.3759
#  86   | 0.45         | X = 0.0 + 4.0*sec(0.45)        | 4.4422       | Y = 0.0 + 3.0*tan(0.45)          | 1.4492
#  87   | 0.47         | X = 0.0 + 4.0*sec(0.47)        | 4.4865       | Y = 0.0 + 3.0*tan(0.47)          | 1.5239
#  88   | 0.49         | X = 0.0 + 4.0*sec(0.49)        | 4.5334       | Y = 0.0 + 3.0*tan(0.49)          | 1.6002
#  89   | 0.51         | X = 0.0 + 4.0*sec(0.51)        | 4.5832       | Y = 0.0 + 3.0*tan(0.51)          | 1.6781
#  90   | 0.53         | X = 0.0 + 4.0*sec(0.53)        | 4.6360       | Y = 0.0 + 3.0*tan(0.53)          | 1.7578
#  91   | 0.55         | X = 0.0 + 4.0*sec(0.55)        | 4.6919       | Y = 0.0 + 3.0*tan(0.55)          | 1.8393
#  92   | 0.57         | X = 0.0 + 4.0*sec(0.57)        | 4.7512       | Y = 0.0 + 3.0*tan(0.57)          | 1.9229
#  93   | 0.59         | X = 0.0 + 4.0*sec(0.59)        | 4.8138       | Y = 0.0 + 3.0*tan(0.59)          | 2.0087
#  94   | 0.61         | X = 0.0 + 4.0*sec(0.61)        | 4.8801       | Y = 0.0 + 3.0*tan(0.61)          | 2.0968
#  95   | 0.63         | X = 0.0 + 4.0*sec(0.63)        | 4.9503       | Y = 0.0 + 3.0*tan(0.63)          | 2.1873
#  96   | 0.65         | X = 0.0 + 4.0*sec(0.65)        | 5.0246       | Y = 0.0 + 3.0*tan(0.65)          | 2.2806
#  97   | 0.67         | X = 0.0 + 4.0*sec(0.67)        | 5.1032       | Y = 0.0 + 3.0*tan(0.67)          | 2.3768
#  98   | 0.69         | X = 0.0 + 4.0*sec(0.69)        | 5.1864       | Y = 0.0 + 3.0*tan(0.69)          | 2.4760
#  99   | 0.71         | X = 0.0 + 4.0*sec(0.71)        | 5.2745       | Y = 0.0 + 3.0*tan(0.71)          | 2.5786
#  100  | 0.73         | X = 0.0 + 4.0*sec(0.73)        | 5.3679       | Y = 0.0 + 3.0*tan(0.73)          | 2.6848
#  101  | 0.75         | X = 0.0 + 4.0*sec(0.75)        | 5.4668       | Y = 0.0 + 3.0*tan(0.75)          | 2.7948
#  102  | 0.77         | X = 0.0 + 4.0*sec(0.77)        | 5.5717       | Y = 0.0 + 3.0*tan(0.77)          | 2.9090
#  103  | 0.79         | X = 0.0 + 4.0*sec(0.79)        | 5.6831       | Y = 0.0 + 3.0*tan(0.79)          | 3.0277
#  104  | 0.81         | X = 0.0 + 4.0*sec(0.81)        | 5.8013       | Y = 0.0 + 3.0*tan(0.81)          | 3.1514
#  105  | 0.83         | X = 0.0 + 4.0*sec(0.83)        | 5.9270       | Y = 0.0 + 3.0*tan(0.83)          | 3.2803
#  106  | 0.85         | X = 0.0 + 4.0*sec(0.85)        | 6.0608       | Y = 0.0 + 3.0*tan(0.85)          | 3.4150
#  107  | 0.87         | X = 0.0 + 4.0*sec(0.87)        | 6.2032       | Y = 0.0 + 3.0*tan(0.87)          | 3.5560
#  108  | 0.89         | X = 0.0 + 4.0*sec(0.89)        | 6.3551       | Y = 0.0 + 3.0*tan(0.89)          | 3.7038
#  109  | 0.91         | X = 0.0 + 4.0*sec(0.91)        | 6.5174       | Y = 0.0 + 3.0*tan(0.91)          | 3.8591
#  110  | 0.93         | X = 0.0 + 4.0*sec(0.93)        | 6.6908       | Y = 0.0 + 3.0*tan(0.93)          | 4.0226
#  111  | 0.95         | X = 0.0 + 4.0*sec(0.95)        | 6.8766       | Y = 0.0 + 3.0*tan(0.95)          | 4.1951
#  112  | 0.97         | X = 0.0 + 4.0*sec(0.97)        | 7.0759       | Y = 0.0 + 3.0*tan(0.97)          | 4.3776
#  113  | 0.99         | X = 0.0 + 4.0*sec(0.99)        | 7.2901       | Y = 0.0 + 3.0*tan(0.99)          | 4.5710
#  114  | 1.01         | X = 0.0 + 4.0*sec(1.01)        | 7.5208       | Y = 0.0 + 3.0*tan(1.01)          | 4.7766
#  115  | 1.03         | X = 0.0 + 4.0*sec(1.03)        | 7.7697       | Y = 0.0 + 3.0*tan(1.03)          | 4.9957
#  116  | 1.05         | X = 0.0 + 4.0*sec(1.05)        | 8.0391       | Y = 0.0 + 3.0*tan(1.05)          | 5.2299
#  117  | 1.07         | X = 0.0 + 4.0*sec(1.07)        | 8.3312       | Y = 0.0 + 3.0*tan(1.07)          | 5.4811
#  118  | 1.09         | X = 0.0 + 4.0*sec(1.09)        | 8.6489       | Y = 0.0 + 3.0*tan(1.09)          | 5.7513
#  119  | 1.11         | X = 0.0 + 4.0*sec(1.11)        | 8.9956       | Y = 0.0 + 3.0*tan(1.11)          | 6.0430
#  120  | 1.13         | X = 0.0 + 4.0*sec(1.13)        | 9.3752       | Y = 0.0 + 3.0*tan(1.13)          | 6.3593
#  121  | 1.15         | X = 0.0 + 4.0*sec(1.15)        | 9.7922       | Y = 0.0 + 3.0*tan(1.15)          | 6.7035
#  122  | 1.17         | X = 0.0 + 4.0*sec(1.17)        | 10.2524      | Y = 0.0 + 3.0*tan(1.17)          | 7.0799
#  123  | 1.19         | X = 0.0 + 4.0*sec(1.19)        | 10.7625      | Y = 0.0 + 3.0*tan(1.19)          | 7.4937
#  124  | 1.21         | X = 0.0 + 4.0*sec(1.21)        | 11.3308      | Y = 0.0 + 3.0*tan(1.21)          | 7.9510
#  125  | 1.23         | X = 0.0 + 4.0*sec(1.23)        | 11.9675      | Y = 0.0 + 3.0*tan(1.23)          | 8.4594
#  126  | 1.25         | X = 0.0 + 4.0*sec(1.25)        | 12.6854      | Y = 0.0 + 3.0*tan(1.25)          | 9.0287
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA HIPERBOLA PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA HIPERBOLA (CABANG KANAN) - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Sesuai PPT Dosen):
#    x(θ) = xc + a * sec(θ)  |  y(θ) = yc + b * tan(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 7.0 * sec(θ)  |  y(θ) = 0.0 + 3.0 * tan(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA CABANG KANAN X         | HASIL X      | FORMULA CABANG KANAN Y           | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -1.25        | X = 0.0 + 7.0*sec(-1.25)       | 22.1995      | Y = 0.0 + 3.0*tan(-1.25)         | -9.0287
#  2    | -0.95        | X = 0.0 + 7.0*sec(-0.95)       | 12.0340      | Y = 0.0 + 3.0*tan(-0.95)         | -4.1951
#  3    | -0.65        | X = 0.0 + 7.0*sec(-0.65)       | 8.7930       | Y = 0.0 + 3.0*tan(-0.65)         | -2.2806
#  4    | -0.35        | X = 0.0 + 7.0*sec(-0.35)       | 7.4518       | Y = 0.0 + 3.0*tan(-0.35)         | -1.0951
#  5    | -0.05        | X = 0.0 + 7.0*sec(-0.05)       | 7.0088       | Y = 0.0 + 3.0*tan(-0.05)         | -0.1501
#  6    | 0.25         | X = 0.0 + 7.0*sec(0.25)        | 7.2246       | Y = 0.0 + 3.0*tan(0.25)          | 0.7660
#  7    | 0.55         | X = 0.0 + 7.0*sec(0.55)        | 8.2109       | Y = 0.0 + 3.0*tan(0.55)          | 1.8393
#  8    | 0.85         | X = 0.0 + 7.0*sec(0.85)        | 10.6063      | Y = 0.0 + 3.0*tan(0.85)          | 3.4150
#  9    | 1.15         | X = 0.0 + 7.0*sec(1.15)        | 17.1364      | Y = 0.0 + 3.0*tan(1.15)          | 6.7035
#  10   | 1.25         | X = 0.0 + 7.0*sec(1.25)        | 22.1995      | Y = 0.0 + 3.0*tan(1.25)          | 9.0287
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA HIPERBOLA (CABANG KANAN) - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Sesuai PPT Dosen):
#    x(θ) = xc + a * sec(θ)  |  y(θ) = yc + b * tan(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 7.0 * sec(θ)  |  y(θ) = 0.0 + 3.0 * tan(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA CABANG KANAN X         | HASIL X      | FORMULA CABANG KANAN Y           | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -1.25        | X = 0.0 + 7.0*sec(-1.25)       | 22.1995      | Y = 0.0 + 3.0*tan(-1.25)         | -9.0287
#  2    | -1.22        | X = 0.0 + 7.0*sec(-1.22)       | 20.3698      | Y = 0.0 + 3.0*tan(-1.22)         | -8.1983
#  3    | -1.19        | X = 0.0 + 7.0*sec(-1.19)       | 18.8344      | Y = 0.0 + 3.0*tan(-1.19)         | -7.4937
#  4    | -1.16        | X = 0.0 + 7.0*sec(-1.16)       | 17.5289      | Y = 0.0 + 3.0*tan(-1.16)         | -6.8874
#  5    | -1.13        | X = 0.0 + 7.0*sec(-1.13)       | 16.4065      | Y = 0.0 + 3.0*tan(-1.13)         | -6.3593
#  6    | -1.10        | X = 0.0 + 7.0*sec(-1.10)       | 15.4322      | Y = 0.0 + 3.0*tan(-1.10)         | -5.8943
#  7    | -1.07        | X = 0.0 + 7.0*sec(-1.07)       | 14.5796      | Y = 0.0 + 3.0*tan(-1.07)         | -5.4811
#  8    | -1.04        | X = 0.0 + 7.0*sec(-1.04)       | 13.8280      | Y = 0.0 + 3.0*tan(-1.04)         | -5.1108
#  9    | -1.01        | X = 0.0 + 7.0*sec(-1.01)       | 13.1613      | Y = 0.0 + 3.0*tan(-1.01)         | -4.7766
#  10   | -0.98        | X = 0.0 + 7.0*sec(-0.98)       | 12.5668      | Y = 0.0 + 3.0*tan(-0.98)         | -4.4729
#  11   | -0.95        | X = 0.0 + 7.0*sec(-0.95)       | 12.0340      | Y = 0.0 + 3.0*tan(-0.95)         | -4.1951
#  12   | -0.92        | X = 0.0 + 7.0*sec(-0.92)       | 11.5546      | Y = 0.0 + 3.0*tan(-0.92)         | -3.9398
#  13   | -0.89        | X = 0.0 + 7.0*sec(-0.89)       | 11.1215      | Y = 0.0 + 3.0*tan(-0.89)         | -3.7038
#  14   | -0.86        | X = 0.0 + 7.0*sec(-0.86)       | 10.7290      | Y = 0.0 + 3.0*tan(-0.86)         | -3.4847
#  15   | -0.83        | X = 0.0 + 7.0*sec(-0.83)       | 10.3723      | Y = 0.0 + 3.0*tan(-0.83)         | -3.2803
#  16   | -0.80        | X = 0.0 + 7.0*sec(-0.80)       | 10.0473      | Y = 0.0 + 3.0*tan(-0.80)         | -3.0889
#  17   | -0.77        | X = 0.0 + 7.0*sec(-0.77)       | 9.7505       | Y = 0.0 + 3.0*tan(-0.77)         | -2.9090
#  18   | -0.74        | X = 0.0 + 7.0*sec(-0.74)       | 9.4791       | Y = 0.0 + 3.0*tan(-0.74)         | -2.7393
#  19   | -0.71        | X = 0.0 + 7.0*sec(-0.71)       | 9.2304       | Y = 0.0 + 3.0*tan(-0.71)         | -2.5786
#  20   | -0.68        | X = 0.0 + 7.0*sec(-0.68)       | 9.0024       | Y = 0.0 + 3.0*tan(-0.68)         | -2.4260
#  21   | -0.65        | X = 0.0 + 7.0*sec(-0.65)       | 8.7930       | Y = 0.0 + 3.0*tan(-0.65)         | -2.2806
#  22   | -0.62        | X = 0.0 + 7.0*sec(-0.62)       | 8.6008       | Y = 0.0 + 3.0*tan(-0.62)         | -2.1417
#  23   | -0.59        | X = 0.0 + 7.0*sec(-0.59)       | 8.4242       | Y = 0.0 + 3.0*tan(-0.59)         | -2.0087
#  24   | -0.56        | X = 0.0 + 7.0*sec(-0.56)       | 8.2620       | Y = 0.0 + 3.0*tan(-0.56)         | -1.8808
#  25   | -0.53        | X = 0.0 + 7.0*sec(-0.53)       | 8.1131       | Y = 0.0 + 3.0*tan(-0.53)         | -1.7578
#  26   | -0.50        | X = 0.0 + 7.0*sec(-0.50)       | 7.9765       | Y = 0.0 + 3.0*tan(-0.50)         | -1.6389
#  27   | -0.47        | X = 0.0 + 7.0*sec(-0.47)       | 7.8513       | Y = 0.0 + 3.0*tan(-0.47)         | -1.5239
#  28   | -0.44        | X = 0.0 + 7.0*sec(-0.44)       | 7.7369       | Y = 0.0 + 3.0*tan(-0.44)         | -1.4123
#  29   | -0.41        | X = 0.0 + 7.0*sec(-0.41)       | 7.6326       | Y = 0.0 + 3.0*tan(-0.41)         | -1.3039
#  30   | -0.38        | X = 0.0 + 7.0*sec(-0.38)       | 7.5377       | Y = 0.0 + 3.0*tan(-0.38)         | -1.1982
#  31   | -0.35        | X = 0.0 + 7.0*sec(-0.35)       | 7.4518       | Y = 0.0 + 3.0*tan(-0.35)         | -1.0951
#  32   | -0.32        | X = 0.0 + 7.0*sec(-0.32)       | 7.3744       | Y = 0.0 + 3.0*tan(-0.32)         | -0.9942
#  33   | -0.29        | X = 0.0 + 7.0*sec(-0.29)       | 7.3050       | Y = 0.0 + 3.0*tan(-0.29)         | -0.8952
#  34   | -0.26        | X = 0.0 + 7.0*sec(-0.26)       | 7.2435       | Y = 0.0 + 3.0*tan(-0.26)         | -0.7981
#  35   | -0.23        | X = 0.0 + 7.0*sec(-0.23)       | 7.1893       | Y = 0.0 + 3.0*tan(-0.23)         | -0.7024
#  36   | -0.20        | X = 0.0 + 7.0*sec(-0.20)       | 7.1424       | Y = 0.0 + 3.0*tan(-0.20)         | -0.6081
#  37   | -0.17        | X = 0.0 + 7.0*sec(-0.17)       | 7.1024       | Y = 0.0 + 3.0*tan(-0.17)         | -0.5150
#  38   | -0.14        | X = 0.0 + 7.0*sec(-0.14)       | 7.0692       | Y = 0.0 + 3.0*tan(-0.14)         | -0.4228
#  39   | -0.11        | X = 0.0 + 7.0*sec(-0.11)       | 7.0426       | Y = 0.0 + 3.0*tan(-0.11)         | -0.3313
#  40   | -0.08        | X = 0.0 + 7.0*sec(-0.08)       | 7.0225       | Y = 0.0 + 3.0*tan(-0.08)         | -0.2405
#  41   | -0.05        | X = 0.0 + 7.0*sec(-0.05)       | 7.0088       | Y = 0.0 + 3.0*tan(-0.05)         | -0.1501
#  42   | -0.02        | X = 0.0 + 7.0*sec(-0.02)       | 7.0014       | Y = 0.0 + 3.0*tan(-0.02)         | -0.0600
#  43   | 0.01         | X = 0.0 + 7.0*sec(0.01)        | 7.0004       | Y = 0.0 + 3.0*tan(0.01)          | 0.0300
#  44   | 0.04         | X = 0.0 + 7.0*sec(0.04)        | 7.0056       | Y = 0.0 + 3.0*tan(0.04)          | 0.1201
#  45   | 0.07         | X = 0.0 + 7.0*sec(0.07)        | 7.0172       | Y = 0.0 + 3.0*tan(0.07)          | 0.2103
#  46   | 0.10         | X = 0.0 + 7.0*sec(0.10)        | 7.0351       | Y = 0.0 + 3.0*tan(0.10)          | 0.3010
#  47   | 0.13         | X = 0.0 + 7.0*sec(0.13)        | 7.0596       | Y = 0.0 + 3.0*tan(0.13)          | 0.3922
#  48   | 0.16         | X = 0.0 + 7.0*sec(0.16)        | 7.0906       | Y = 0.0 + 3.0*tan(0.16)          | 0.4841
#  49   | 0.19         | X = 0.0 + 7.0*sec(0.19)        | 7.1283       | Y = 0.0 + 3.0*tan(0.19)          | 0.5770
#  50   | 0.22         | X = 0.0 + 7.0*sec(0.22)        | 7.1729       | Y = 0.0 + 3.0*tan(0.22)          | 0.6709
#  51   | 0.25         | X = 0.0 + 7.0*sec(0.25)        | 7.2246       | Y = 0.0 + 3.0*tan(0.25)          | 0.7660
#  52   | 0.28         | X = 0.0 + 7.0*sec(0.28)        | 7.2837       | Y = 0.0 + 3.0*tan(0.28)          | 0.8627
#  53   | 0.31         | X = 0.0 + 7.0*sec(0.31)        | 7.3504       | Y = 0.0 + 3.0*tan(0.31)          | 0.9610
#  54   | 0.34         | X = 0.0 + 7.0*sec(0.34)        | 7.4250       | Y = 0.0 + 3.0*tan(0.34)          | 1.0612
#  55   | 0.37         | X = 0.0 + 7.0*sec(0.37)        | 7.5081       | Y = 0.0 + 3.0*tan(0.37)          | 1.1636
#  56   | 0.40         | X = 0.0 + 7.0*sec(0.40)        | 7.5999       | Y = 0.0 + 3.0*tan(0.40)          | 1.2684
#  57   | 0.43         | X = 0.0 + 7.0*sec(0.43)        | 7.7011       | Y = 0.0 + 3.0*tan(0.43)          | 1.3759
#  58   | 0.46         | X = 0.0 + 7.0*sec(0.46)        | 7.8120       | Y = 0.0 + 3.0*tan(0.46)          | 1.4863
#  59   | 0.49         | X = 0.0 + 7.0*sec(0.49)        | 7.9335       | Y = 0.0 + 3.0*tan(0.49)          | 1.6002
#  60   | 0.52         | X = 0.0 + 7.0*sec(0.52)        | 8.0662       | Y = 0.0 + 3.0*tan(0.52)          | 1.7177
#  61   | 0.55         | X = 0.0 + 7.0*sec(0.55)        | 8.2109       | Y = 0.0 + 3.0*tan(0.55)          | 1.8393
#  62   | 0.58         | X = 0.0 + 7.0*sec(0.58)        | 8.3686       | Y = 0.0 + 3.0*tan(0.58)          | 1.9655
#  63   | 0.61         | X = 0.0 + 7.0*sec(0.61)        | 8.5403       | Y = 0.0 + 3.0*tan(0.61)          | 2.0968
#  64   | 0.64         | X = 0.0 + 7.0*sec(0.64)        | 8.7271       | Y = 0.0 + 3.0*tan(0.64)          | 2.2336
#  65   | 0.67         | X = 0.0 + 7.0*sec(0.67)        | 8.9306       | Y = 0.0 + 3.0*tan(0.67)          | 2.3768
#  66   | 0.70         | X = 0.0 + 7.0*sec(0.70)        | 9.1522       | Y = 0.0 + 3.0*tan(0.70)          | 2.5269
#  67   | 0.73         | X = 0.0 + 7.0*sec(0.73)        | 9.3938       | Y = 0.0 + 3.0*tan(0.73)          | 2.6848
#  68   | 0.76         | X = 0.0 + 7.0*sec(0.76)        | 9.6574       | Y = 0.0 + 3.0*tan(0.76)          | 2.8514
#  69   | 0.79         | X = 0.0 + 7.0*sec(0.79)        | 9.9454       | Y = 0.0 + 3.0*tan(0.79)          | 3.0277
#  70   | 0.82         | X = 0.0 + 7.0*sec(0.82)        | 10.2606      | Y = 0.0 + 3.0*tan(0.82)          | 3.2151
#  71   | 0.85         | X = 0.0 + 7.0*sec(0.85)        | 10.6063      | Y = 0.0 + 3.0*tan(0.85)          | 3.4150
#  72   | 0.88         | X = 0.0 + 7.0*sec(0.88)        | 10.9864      | Y = 0.0 + 3.0*tan(0.88)          | 3.6290
#  73   | 0.91         | X = 0.0 + 7.0*sec(0.91)        | 11.4054      | Y = 0.0 + 3.0*tan(0.91)          | 3.8591
#  74   | 0.94         | X = 0.0 + 7.0*sec(0.94)        | 11.8687      | Y = 0.0 + 3.0*tan(0.94)          | 4.1077
#  75   | 0.97         | X = 0.0 + 7.0*sec(0.97)        | 12.3828      | Y = 0.0 + 3.0*tan(0.97)          | 4.3776
#  76   | 1.00         | X = 0.0 + 7.0*sec(1.00)        | 12.9557      | Y = 0.0 + 3.0*tan(1.00)          | 4.6722
#  77   | 1.03         | X = 0.0 + 7.0*sec(1.03)        | 13.5970      | Y = 0.0 + 3.0*tan(1.03)          | 4.9957
#  78   | 1.06         | X = 0.0 + 7.0*sec(1.06)        | 14.3187      | Y = 0.0 + 3.0*tan(1.06)          | 5.3533
#  79   | 1.09         | X = 0.0 + 7.0*sec(1.09)        | 15.1356      | Y = 0.0 + 3.0*tan(1.09)          | 5.7513
#  80   | 1.12         | X = 0.0 + 7.0*sec(1.12)        | 16.0667      | Y = 0.0 + 3.0*tan(1.12)          | 6.1979
#  81   | 1.15         | X = 0.0 + 7.0*sec(1.15)        | 17.1364      | Y = 0.0 + 3.0*tan(1.15)          | 6.7035
#  82   | 1.18         | X = 0.0 + 7.0*sec(1.18)        | 18.3763      | Y = 0.0 + 3.0*tan(1.18)          | 7.2818
#  83   | 1.21         | X = 0.0 + 7.0*sec(1.21)        | 19.8289      | Y = 0.0 + 3.0*tan(1.21)          | 7.9510
#  84   | 1.24         | X = 0.0 + 7.0*sec(1.24)        | 21.5520      | Y = 0.0 + 3.0*tan(1.24)          | 8.7358
#  85   | 1.25         | X = 0.0 + 7.0*sec(1.25)        | 22.1995      | Y = 0.0 + 3.0*tan(1.25)          | 9.0287
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA HIPERBOLA PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA HIPERBOLA (CABANG KANAN) - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Sesuai PPT Dosen):
#    x(θ) = xc + a * sec(θ)  |  y(θ) = yc + b * tan(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 8.0 * sec(θ)  |  y(θ) = 0.0 + 5.0 * tan(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA CABANG KANAN X         | HASIL X      | FORMULA CABANG KANAN Y           | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -1.25        | X = 0.0 + 8.0*sec(-1.25)       | 25.3709      | Y = 0.0 + 5.0*tan(-1.25)         | -15.0478
#  2    | -1.15        | X = 0.0 + 8.0*sec(-1.15)       | 19.5844      | Y = 0.0 + 5.0*tan(-1.15)         | -11.1725
#  3    | -1.05        | X = 0.0 + 8.0*sec(-1.05)       | 16.0781      | Y = 0.0 + 5.0*tan(-1.05)         | -8.7166
#  4    | -0.95        | X = 0.0 + 8.0*sec(-0.95)       | 13.7532      | Y = 0.0 + 5.0*tan(-0.95)         | -6.9919
#  5    | -0.85        | X = 0.0 + 8.0*sec(-0.85)       | 12.1215      | Y = 0.0 + 5.0*tan(-0.85)         | -5.6917
#  6    | -0.75        | X = 0.0 + 8.0*sec(-0.75)       | 10.9336      | Y = 0.0 + 5.0*tan(-0.75)         | -4.6580
#  7    | -0.65        | X = 0.0 + 8.0*sec(-0.65)       | 10.0492      | Y = 0.0 + 5.0*tan(-0.65)         | -3.8010
#  8    | -0.55        | X = 0.0 + 8.0*sec(-0.55)       | 9.3839       | Y = 0.0 + 5.0*tan(-0.55)         | -3.0655
#  9    | -0.45        | X = 0.0 + 8.0*sec(-0.45)       | 8.8845       | Y = 0.0 + 5.0*tan(-0.45)         | -2.4153
#  10   | -0.35        | X = 0.0 + 8.0*sec(-0.35)       | 8.5163       | Y = 0.0 + 5.0*tan(-0.35)         | -1.8251
#  11   | -0.25        | X = 0.0 + 8.0*sec(-0.25)       | 8.2567       | Y = 0.0 + 5.0*tan(-0.25)         | -1.2767
#  12   | -0.15        | X = 0.0 + 8.0*sec(-0.15)       | 8.0909       | Y = 0.0 + 5.0*tan(-0.15)         | -0.7557
#  13   | -0.05        | X = 0.0 + 8.0*sec(-0.05)       | 8.0100       | Y = 0.0 + 5.0*tan(-0.05)         | -0.2502
#  14   | 0.05         | X = 0.0 + 8.0*sec(0.05)        | 8.0100       | Y = 0.0 + 5.0*tan(0.05)          | 0.2502
#  15   | 0.15         | X = 0.0 + 8.0*sec(0.15)        | 8.0909       | Y = 0.0 + 5.0*tan(0.15)          | 0.7557
#  16   | 0.25         | X = 0.0 + 8.0*sec(0.25)        | 8.2567       | Y = 0.0 + 5.0*tan(0.25)          | 1.2767
#  17   | 0.35         | X = 0.0 + 8.0*sec(0.35)        | 8.5163       | Y = 0.0 + 5.0*tan(0.35)          | 1.8251
#  18   | 0.45         | X = 0.0 + 8.0*sec(0.45)        | 8.8845       | Y = 0.0 + 5.0*tan(0.45)          | 2.4153
#  19   | 0.55         | X = 0.0 + 8.0*sec(0.55)        | 9.3839       | Y = 0.0 + 5.0*tan(0.55)          | 3.0655
#  20   | 0.65         | X = 0.0 + 8.0*sec(0.65)        | 10.0492      | Y = 0.0 + 5.0*tan(0.65)          | 3.8010
#  21   | 0.75         | X = 0.0 + 8.0*sec(0.75)        | 10.9336      | Y = 0.0 + 5.0*tan(0.75)          | 4.6580
#  22   | 0.85         | X = 0.0 + 8.0*sec(0.85)        | 12.1215      | Y = 0.0 + 5.0*tan(0.85)          | 5.6917
#  23   | 0.95         | X = 0.0 + 8.0*sec(0.95)        | 13.7532      | Y = 0.0 + 5.0*tan(0.95)          | 6.9919
#  24   | 1.05         | X = 0.0 + 8.0*sec(1.05)        | 16.0781      | Y = 0.0 + 5.0*tan(1.05)          | 8.7166
#  25   | 1.15         | X = 0.0 + 8.0*sec(1.15)        | 19.5844      | Y = 0.0 + 5.0*tan(1.15)          | 11.1725
#  26   | 1.25         | X = 0.0 + 8.0*sec(1.25)        | 25.3709      | Y = 0.0 + 5.0*tan(1.25)          | 15.0478
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA HIPERBOLA (CABANG KANAN) - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Sesuai PPT Dosen):
#    x(θ) = xc + a * sec(θ)  |  y(θ) = yc + b * tan(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 8.0 * sec(θ)  |  y(θ) = 0.0 + 5.0 * tan(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA CABANG KANAN X         | HASIL X      | FORMULA CABANG KANAN Y           | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | -1.25        | X = 0.0 + 8.0*sec(-1.25)       | 25.3709      | Y = 0.0 + 5.0*tan(-1.25)         | -15.0478
#  2    | -1.24        | X = 0.0 + 8.0*sec(-1.24)       | 24.6308      | Y = 0.0 + 5.0*tan(-1.24)         | -14.5596
#  3    | -1.23        | X = 0.0 + 8.0*sec(-1.23)       | 23.9351      | Y = 0.0 + 5.0*tan(-1.23)         | -14.0991
#  4    | -1.22        | X = 0.0 + 8.0*sec(-1.22)       | 23.2798      | Y = 0.0 + 5.0*tan(-1.22)         | -13.6638
#  5    | -1.21        | X = 0.0 + 8.0*sec(-1.21)       | 22.6616      | Y = 0.0 + 5.0*tan(-1.21)         | -13.2516
#  6    | -1.20        | X = 0.0 + 8.0*sec(-1.20)       | 22.0776      | Y = 0.0 + 5.0*tan(-1.20)         | -12.8608
#  7    | -1.19        | X = 0.0 + 8.0*sec(-1.19)       | 21.5251      | Y = 0.0 + 5.0*tan(-1.19)         | -12.4895
#  8    | -1.18        | X = 0.0 + 8.0*sec(-1.18)       | 21.0015      | Y = 0.0 + 5.0*tan(-1.18)         | -12.1363
#  9    | -1.17        | X = 0.0 + 8.0*sec(-1.17)       | 20.5048      | Y = 0.0 + 5.0*tan(-1.17)         | -11.7999
#  10   | -1.16        | X = 0.0 + 8.0*sec(-1.16)       | 20.0331      | Y = 0.0 + 5.0*tan(-1.16)         | -11.4790
#  11   | -1.15        | X = 0.0 + 8.0*sec(-1.15)       | 19.5844      | Y = 0.0 + 5.0*tan(-1.15)         | -11.1725
#  12   | -1.14        | X = 0.0 + 8.0*sec(-1.14)       | 19.1573      | Y = 0.0 + 5.0*tan(-1.14)         | -10.8794
#  13   | -1.13        | X = 0.0 + 8.0*sec(-1.13)       | 18.7503      | Y = 0.0 + 5.0*tan(-1.13)         | -10.5988
#  14   | -1.12        | X = 0.0 + 8.0*sec(-1.12)       | 18.3620      | Y = 0.0 + 5.0*tan(-1.12)         | -10.3298
#  15   | -1.11        | X = 0.0 + 8.0*sec(-1.11)       | 17.9912      | Y = 0.0 + 5.0*tan(-1.11)         | -10.0717
#  16   | -1.10        | X = 0.0 + 8.0*sec(-1.10)       | 17.6368      | Y = 0.0 + 5.0*tan(-1.10)         | -9.8238
#  17   | -1.09        | X = 0.0 + 8.0*sec(-1.09)       | 17.2978      | Y = 0.0 + 5.0*tan(-1.09)         | -9.5855
#  18   | -1.08        | X = 0.0 + 8.0*sec(-1.08)       | 16.9733      | Y = 0.0 + 5.0*tan(-1.08)         | -9.3561
#  19   | -1.07        | X = 0.0 + 8.0*sec(-1.07)       | 16.6624      | Y = 0.0 + 5.0*tan(-1.07)         | -9.1351
#  20   | -1.06        | X = 0.0 + 8.0*sec(-1.06)       | 16.3642      | Y = 0.0 + 5.0*tan(-1.06)         | -8.9221
#  21   | -1.05        | X = 0.0 + 8.0*sec(-1.05)       | 16.0781      | Y = 0.0 + 5.0*tan(-1.05)         | -8.7166
#  22   | -1.04        | X = 0.0 + 8.0*sec(-1.04)       | 15.8034      | Y = 0.0 + 5.0*tan(-1.04)         | -8.5181
#  23   | -1.03        | X = 0.0 + 8.0*sec(-1.03)       | 15.5394      | Y = 0.0 + 5.0*tan(-1.03)         | -8.3262
#  24   | -1.02        | X = 0.0 + 8.0*sec(-1.02)       | 15.2857      | Y = 0.0 + 5.0*tan(-1.02)         | -8.1407
#  25   | -1.01        | X = 0.0 + 8.0*sec(-1.01)       | 15.0415      | Y = 0.0 + 5.0*tan(-1.01)         | -7.9610
#  26   | -1.00        | X = 0.0 + 8.0*sec(-1.00)       | 14.8065      | Y = 0.0 + 5.0*tan(-1.00)         | -7.7870
#  27   | -0.99        | X = 0.0 + 8.0*sec(-0.99)       | 14.5802      | Y = 0.0 + 5.0*tan(-0.99)         | -7.6184
#  28   | -0.98        | X = 0.0 + 8.0*sec(-0.98)       | 14.3621      | Y = 0.0 + 5.0*tan(-0.98)         | -7.4548
#  29   | -0.97        | X = 0.0 + 8.0*sec(-0.97)       | 14.1518      | Y = 0.0 + 5.0*tan(-0.97)         | -7.2960
#  30   | -0.96        | X = 0.0 + 8.0*sec(-0.96)       | 13.9489      | Y = 0.0 + 5.0*tan(-0.96)         | -7.1418
#  31   | -0.95        | X = 0.0 + 8.0*sec(-0.95)       | 13.7532      | Y = 0.0 + 5.0*tan(-0.95)         | -6.9919
#  32   | -0.94        | X = 0.0 + 8.0*sec(-0.94)       | 13.5642      | Y = 0.0 + 5.0*tan(-0.94)         | -6.8462
#  33   | -0.93        | X = 0.0 + 8.0*sec(-0.93)       | 13.3816      | Y = 0.0 + 5.0*tan(-0.93)         | -6.7044
#  34   | -0.92        | X = 0.0 + 8.0*sec(-0.92)       | 13.2052      | Y = 0.0 + 5.0*tan(-0.92)         | -6.5663
#  35   | -0.91        | X = 0.0 + 8.0*sec(-0.91)       | 13.0347      | Y = 0.0 + 5.0*tan(-0.91)         | -6.4318
#  36   | -0.90        | X = 0.0 + 8.0*sec(-0.90)       | 12.8698      | Y = 0.0 + 5.0*tan(-0.90)         | -6.3008
#  37   | -0.89        | X = 0.0 + 8.0*sec(-0.89)       | 12.7103      | Y = 0.0 + 5.0*tan(-0.89)         | -6.1730
#  38   | -0.88        | X = 0.0 + 8.0*sec(-0.88)       | 12.5559      | Y = 0.0 + 5.0*tan(-0.88)         | -6.0483
#  39   | -0.87        | X = 0.0 + 8.0*sec(-0.87)       | 12.4064      | Y = 0.0 + 5.0*tan(-0.87)         | -5.9266
#  40   | -0.86        | X = 0.0 + 8.0*sec(-0.86)       | 12.2617      | Y = 0.0 + 5.0*tan(-0.86)         | -5.8078
#  41   | -0.85        | X = 0.0 + 8.0*sec(-0.85)       | 12.1215      | Y = 0.0 + 5.0*tan(-0.85)         | -5.6917
#  42   | -0.84        | X = 0.0 + 8.0*sec(-0.84)       | 11.9857      | Y = 0.0 + 5.0*tan(-0.84)         | -5.5782
#  43   | -0.83        | X = 0.0 + 8.0*sec(-0.83)       | 11.8540      | Y = 0.0 + 5.0*tan(-0.83)         | -5.4672
#  44   | -0.82        | X = 0.0 + 8.0*sec(-0.82)       | 11.7264      | Y = 0.0 + 5.0*tan(-0.82)         | -5.3586
#  45   | -0.81        | X = 0.0 + 8.0*sec(-0.81)       | 11.6026      | Y = 0.0 + 5.0*tan(-0.81)         | -5.2523
#  46   | -0.80        | X = 0.0 + 8.0*sec(-0.80)       | 11.4826      | Y = 0.0 + 5.0*tan(-0.80)         | -5.1482
#  47   | -0.79        | X = 0.0 + 8.0*sec(-0.79)       | 11.3661      | Y = 0.0 + 5.0*tan(-0.79)         | -5.0462
#  48   | -0.78        | X = 0.0 + 8.0*sec(-0.78)       | 11.2531      | Y = 0.0 + 5.0*tan(-0.78)         | -4.9463
#  49   | -0.77        | X = 0.0 + 8.0*sec(-0.77)       | 11.1434      | Y = 0.0 + 5.0*tan(-0.77)         | -4.8483
#  50   | -0.76        | X = 0.0 + 8.0*sec(-0.76)       | 11.0370      | Y = 0.0 + 5.0*tan(-0.76)         | -4.7523
#  51   | -0.75        | X = 0.0 + 8.0*sec(-0.75)       | 10.9336      | Y = 0.0 + 5.0*tan(-0.75)         | -4.6580
#  52   | -0.74        | X = 0.0 + 8.0*sec(-0.74)       | 10.8332      | Y = 0.0 + 5.0*tan(-0.74)         | -4.5654
#  53   | -0.73        | X = 0.0 + 8.0*sec(-0.73)       | 10.7357      | Y = 0.0 + 5.0*tan(-0.73)         | -4.4746
#  54   | -0.72        | X = 0.0 + 8.0*sec(-0.72)       | 10.6410      | Y = 0.0 + 5.0*tan(-0.72)         | -4.3853
#  55   | -0.71        | X = 0.0 + 8.0*sec(-0.71)       | 10.5491      | Y = 0.0 + 5.0*tan(-0.71)         | -4.2976
#  56   | -0.70        | X = 0.0 + 8.0*sec(-0.70)       | 10.4597      | Y = 0.0 + 5.0*tan(-0.70)         | -4.2114
#  57   | -0.69        | X = 0.0 + 8.0*sec(-0.69)       | 10.3728      | Y = 0.0 + 5.0*tan(-0.69)         | -4.1267
#  58   | -0.68        | X = 0.0 + 8.0*sec(-0.68)       | 10.2884      | Y = 0.0 + 5.0*tan(-0.68)         | -4.0433
#  59   | -0.67        | X = 0.0 + 8.0*sec(-0.67)       | 10.2064      | Y = 0.0 + 5.0*tan(-0.67)         | -3.9613
#  60   | -0.66        | X = 0.0 + 8.0*sec(-0.66)       | 10.1267      | Y = 0.0 + 5.0*tan(-0.66)         | -3.8805
#  61   | -0.65        | X = 0.0 + 8.0*sec(-0.65)       | 10.0492      | Y = 0.0 + 5.0*tan(-0.65)         | -3.8010
#  62   | -0.64        | X = 0.0 + 8.0*sec(-0.64)       | 9.9739       | Y = 0.0 + 5.0*tan(-0.64)         | -3.7227
#  63   | -0.63        | X = 0.0 + 8.0*sec(-0.63)       | 9.9007       | Y = 0.0 + 5.0*tan(-0.63)         | -3.6456
#  64   | -0.62        | X = 0.0 + 8.0*sec(-0.62)       | 9.8295       | Y = 0.0 + 5.0*tan(-0.62)         | -3.5695
#  65   | -0.61        | X = 0.0 + 8.0*sec(-0.61)       | 9.7603       | Y = 0.0 + 5.0*tan(-0.61)         | -3.4946
#  66   | -0.60        | X = 0.0 + 8.0*sec(-0.60)       | 9.6930       | Y = 0.0 + 5.0*tan(-0.60)         | -3.4207
#  67   | -0.59        | X = 0.0 + 8.0*sec(-0.59)       | 9.6276       | Y = 0.0 + 5.0*tan(-0.59)         | -3.3478
#  68   | -0.58        | X = 0.0 + 8.0*sec(-0.58)       | 9.5641       | Y = 0.0 + 5.0*tan(-0.58)         | -3.2758
#  69   | -0.57        | X = 0.0 + 8.0*sec(-0.57)       | 9.5023       | Y = 0.0 + 5.0*tan(-0.57)         | -3.2048
#  70   | -0.56        | X = 0.0 + 8.0*sec(-0.56)       | 9.4423       | Y = 0.0 + 5.0*tan(-0.56)         | -3.1347
#  71   | -0.55        | X = 0.0 + 8.0*sec(-0.55)       | 9.3839       | Y = 0.0 + 5.0*tan(-0.55)         | -3.0655
#  72   | -0.54        | X = 0.0 + 8.0*sec(-0.54)       | 9.3272       | Y = 0.0 + 5.0*tan(-0.54)         | -2.9971
#  73   | -0.53        | X = 0.0 + 8.0*sec(-0.53)       | 9.2721       | Y = 0.0 + 5.0*tan(-0.53)         | -2.9296
#  74   | -0.52        | X = 0.0 + 8.0*sec(-0.52)       | 9.2185       | Y = 0.0 + 5.0*tan(-0.52)         | -2.8628
#  75   | -0.51        | X = 0.0 + 8.0*sec(-0.51)       | 9.1665       | Y = 0.0 + 5.0*tan(-0.51)         | -2.7968
#  76   | -0.50        | X = 0.0 + 8.0*sec(-0.50)       | 9.1160       | Y = 0.0 + 5.0*tan(-0.50)         | -2.7315
#  77   | -0.49        | X = 0.0 + 8.0*sec(-0.49)       | 9.0669       | Y = 0.0 + 5.0*tan(-0.49)         | -2.6669
#  78   | -0.48        | X = 0.0 + 8.0*sec(-0.48)       | 9.0192       | Y = 0.0 + 5.0*tan(-0.48)         | -2.6031
#  79   | -0.47        | X = 0.0 + 8.0*sec(-0.47)       | 8.9730       | Y = 0.0 + 5.0*tan(-0.47)         | -2.5398
#  80   | -0.46        | X = 0.0 + 8.0*sec(-0.46)       | 8.9280       | Y = 0.0 + 5.0*tan(-0.46)         | -2.4772
#  81   | -0.45        | X = 0.0 + 8.0*sec(-0.45)       | 8.8845       | Y = 0.0 + 5.0*tan(-0.45)         | -2.4153
# ...
#  122  | -0.04        | X = 0.0 + 8.0*sec(-0.04)       | 8.0064       | Y = 0.0 + 5.0*tan(-0.04)         | -0.2001
#  123  | -0.03        | X = 0.0 + 8.0*sec(-0.03)       | 8.0036       | Y = 0.0 + 5.0*tan(-0.03)         | -0.1500
#  124  | -0.02        | X = 0.0 + 8.0*sec(-0.02)       | 8.0016       | Y = 0.0 + 5.0*tan(-0.02)         | -0.1000
#  125  | -0.01        | X = 0.0 + 8.0*sec(-0.01)       | 8.0004       | Y = 0.0 + 5.0*tan(-0.01)         | -0.0500
#  126  | 0.00         | X = 0.0 + 8.0*sec(0.00)        | 8.0000       | Y = 0.0 + 5.0*tan(0.00)          | 0.0000
#  127  | 0.01         | X = 0.0 + 8.0*sec(0.01)        | 8.0004       | Y = 0.0 + 5.0*tan(0.01)          | 0.0500
#  128  | 0.02         | X = 0.0 + 8.0*sec(0.02)        | 8.0016       | Y = 0.0 + 5.0*tan(0.02)          | 0.1000
#  129  | 0.03         | X = 0.0 + 8.0*sec(0.03)        | 8.0036       | Y = 0.0 + 5.0*tan(0.03)          | 0.1500
#  130  | 0.04         | X = 0.0 + 8.0*sec(0.04)        | 8.0064       | Y = 0.0 + 5.0*tan(0.04)          | 0.2001
#  131  | 0.05         | X = 0.0 + 8.0*sec(0.05)        | 8.0100       | Y = 0.0 + 5.0*tan(0.05)          | 0.2502
#  132  | 0.06         | X = 0.0 + 8.0*sec(0.06)        | 8.0144       | Y = 0.0 + 5.0*tan(0.06)          | 0.3004
#  133  | 0.07         | X = 0.0 + 8.0*sec(0.07)        | 8.0196       | Y = 0.0 + 5.0*tan(0.07)          | 0.3506
#  134  | 0.08         | X = 0.0 + 8.0*sec(0.08)        | 8.0257       | Y = 0.0 + 5.0*tan(0.08)          | 0.4009
#  135  | 0.09         | X = 0.0 + 8.0*sec(0.09)        | 8.0325       | Y = 0.0 + 5.0*tan(0.09)          | 0.4512
#  136  | 0.10         | X = 0.0 + 8.0*sec(0.10)        | 8.0402       | Y = 0.0 + 5.0*tan(0.10)          | 0.5017
#  137  | 0.11         | X = 0.0 + 8.0*sec(0.11)        | 8.0486       | Y = 0.0 + 5.0*tan(0.11)          | 0.5522
#  138  | 0.12         | X = 0.0 + 8.0*sec(0.12)        | 8.0579       | Y = 0.0 + 5.0*tan(0.12)          | 0.6029
#  139  | 0.13         | X = 0.0 + 8.0*sec(0.13)        | 8.0681       | Y = 0.0 + 5.0*tan(0.13)          | 0.6537
#  140  | 0.14         | X = 0.0 + 8.0*sec(0.14)        | 8.0790       | Y = 0.0 + 5.0*tan(0.14)          | 0.7046
#  141  | 0.15         | X = 0.0 + 8.0*sec(0.15)        | 8.0909       | Y = 0.0 + 5.0*tan(0.15)          | 0.7557
#  142  | 0.16         | X = 0.0 + 8.0*sec(0.16)        | 8.1035       | Y = 0.0 + 5.0*tan(0.16)          | 0.8069
#  143  | 0.17         | X = 0.0 + 8.0*sec(0.17)        | 8.1170       | Y = 0.0 + 5.0*tan(0.17)          | 0.8583
#  144  | 0.18         | X = 0.0 + 8.0*sec(0.18)        | 8.1314       | Y = 0.0 + 5.0*tan(0.18)          | 0.9098
#  145  | 0.19         | X = 0.0 + 8.0*sec(0.19)        | 8.1466       | Y = 0.0 + 5.0*tan(0.19)          | 0.9616
#  146  | 0.20         | X = 0.0 + 8.0*sec(0.20)        | 8.1627       | Y = 0.0 + 5.0*tan(0.20)          | 1.0136
#  147  | 0.21         | X = 0.0 + 8.0*sec(0.21)        | 8.1797       | Y = 0.0 + 5.0*tan(0.21)          | 1.0657
#  148  | 0.22         | X = 0.0 + 8.0*sec(0.22)        | 8.1976       | Y = 0.0 + 5.0*tan(0.22)          | 1.1181
#  149  | 0.23         | X = 0.0 + 8.0*sec(0.23)        | 8.2164       | Y = 0.0 + 5.0*tan(0.23)          | 1.1707
#  150  | 0.24         | X = 0.0 + 8.0*sec(0.24)        | 8.2361       | Y = 0.0 + 5.0*tan(0.24)          | 1.2236
#  151  | 0.25         | X = 0.0 + 8.0*sec(0.25)        | 8.2567       | Y = 0.0 + 5.0*tan(0.25)          | 1.2767
#  152  | 0.26         | X = 0.0 + 8.0*sec(0.26)        | 8.2782       | Y = 0.0 + 5.0*tan(0.26)          | 1.3301
#  153  | 0.27         | X = 0.0 + 8.0*sec(0.27)        | 8.3007       | Y = 0.0 + 5.0*tan(0.27)          | 1.3838
#  154  | 0.28         | X = 0.0 + 8.0*sec(0.28)        | 8.3242       | Y = 0.0 + 5.0*tan(0.28)          | 1.4378
#  155  | 0.29         | X = 0.0 + 8.0*sec(0.29)        | 8.3486       | Y = 0.0 + 5.0*tan(0.29)          | 1.4921
#  156  | 0.30         | X = 0.0 + 8.0*sec(0.30)        | 8.3740       | Y = 0.0 + 5.0*tan(0.30)          | 1.5467
#  157  | 0.31         | X = 0.0 + 8.0*sec(0.31)        | 8.4004       | Y = 0.0 + 5.0*tan(0.31)          | 1.6016
#  158  | 0.32         | X = 0.0 + 8.0*sec(0.32)        | 8.4278       | Y = 0.0 + 5.0*tan(0.32)          | 1.6569
#  159  | 0.33         | X = 0.0 + 8.0*sec(0.33)        | 8.4563       | Y = 0.0 + 5.0*tan(0.33)          | 1.7126
#  160  | 0.34         | X = 0.0 + 8.0*sec(0.34)        | 8.4858       | Y = 0.0 + 5.0*tan(0.34)          | 1.7687
#  161  | 0.35         | X = 0.0 + 8.0*sec(0.35)        | 8.5163       | Y = 0.0 + 5.0*tan(0.35)          | 1.8251
#  162  | 0.36         | X = 0.0 + 8.0*sec(0.36)        | 8.5480       | Y = 0.0 + 5.0*tan(0.36)          | 1.8820
#  163  | 0.37         | X = 0.0 + 8.0*sec(0.37)        | 8.5807       | Y = 0.0 + 5.0*tan(0.37)          | 1.9393
#  164  | 0.38         | X = 0.0 + 8.0*sec(0.38)        | 8.6145       | Y = 0.0 + 5.0*tan(0.38)          | 1.9971
#  165  | 0.39         | X = 0.0 + 8.0*sec(0.39)        | 8.6495       | Y = 0.0 + 5.0*tan(0.39)          | 2.0553
#  166  | 0.40         | X = 0.0 + 8.0*sec(0.40)        | 8.6856       | Y = 0.0 + 5.0*tan(0.40)          | 2.1140
#  167  | 0.41         | X = 0.0 + 8.0*sec(0.41)        | 8.7230       | Y = 0.0 + 5.0*tan(0.41)          | 2.1732
#  168  | 0.42         | X = 0.0 + 8.0*sec(0.42)        | 8.7615       | Y = 0.0 + 5.0*tan(0.42)          | 2.2329
#  169  | 0.43         | X = 0.0 + 8.0*sec(0.43)        | 8.8012       | Y = 0.0 + 5.0*tan(0.43)          | 2.2931
#  170  | 0.44         | X = 0.0 + 8.0*sec(0.44)        | 8.8422       | Y = 0.0 + 5.0*tan(0.44)          | 2.3539
#  171  | 0.45         | X = 0.0 + 8.0*sec(0.45)        | 8.8845       | Y = 0.0 + 5.0*tan(0.45)          | 2.4153
#  172  | 0.46         | X = 0.0 + 8.0*sec(0.46)        | 8.9280       | Y = 0.0 + 5.0*tan(0.46)          | 2.4772
#  173  | 0.47         | X = 0.0 + 8.0*sec(0.47)        | 8.9730       | Y = 0.0 + 5.0*tan(0.47)          | 2.5398
#  174  | 0.48         | X = 0.0 + 8.0*sec(0.48)        | 9.0192       | Y = 0.0 + 5.0*tan(0.48)          | 2.6031
#  175  | 0.49         | X = 0.0 + 8.0*sec(0.49)        | 9.0669       | Y = 0.0 + 5.0*tan(0.49)          | 2.6669
#  176  | 0.50         | X = 0.0 + 8.0*sec(0.50)        | 9.1160       | Y = 0.0 + 5.0*tan(0.50)          | 2.7315
#  177  | 0.51         | X = 0.0 + 8.0*sec(0.51)        | 9.1665       | Y = 0.0 + 5.0*tan(0.51)          | 2.7968
#  178  | 0.52         | X = 0.0 + 8.0*sec(0.52)        | 9.2185       | Y = 0.0 + 5.0*tan(0.52)          | 2.8628
#  179  | 0.53         | X = 0.0 + 8.0*sec(0.53)        | 9.2721       | Y = 0.0 + 5.0*tan(0.53)          | 2.9296
#  180  | 0.54         | X = 0.0 + 8.0*sec(0.54)        | 9.3272       | Y = 0.0 + 5.0*tan(0.54)          | 2.9971
#  181  | 0.55         | X = 0.0 + 8.0*sec(0.55)        | 9.3839       | Y = 0.0 + 5.0*tan(0.55)          | 3.0655
#  182  | 0.56         | X = 0.0 + 8.0*sec(0.56)        | 9.4423       | Y = 0.0 + 5.0*tan(0.56)          | 3.1347
#  183  | 0.57         | X = 0.0 + 8.0*sec(0.57)        | 9.5023       | Y = 0.0 + 5.0*tan(0.57)          | 3.2048
#  184  | 0.58         | X = 0.0 + 8.0*sec(0.58)        | 9.5641       | Y = 0.0 + 5.0*tan(0.58)          | 3.2758
#  185  | 0.59         | X = 0.0 + 8.0*sec(0.59)        | 9.6276       | Y = 0.0 + 5.0*tan(0.59)          | 3.3478
#  186  | 0.60         | X = 0.0 + 8.0*sec(0.60)        | 9.6930       | Y = 0.0 + 5.0*tan(0.60)          | 3.4207
#  187  | 0.61         | X = 0.0 + 8.0*sec(0.61)        | 9.7603       | Y = 0.0 + 5.0*tan(0.61)          | 3.4946
#  188  | 0.62         | X = 0.0 + 8.0*sec(0.62)        | 9.8295       | Y = 0.0 + 5.0*tan(0.62)          | 3.5695
#  189  | 0.63         | X = 0.0 + 8.0*sec(0.63)        | 9.9007       | Y = 0.0 + 5.0*tan(0.63)          | 3.6456
#  190  | 0.64         | X = 0.0 + 8.0*sec(0.64)        | 9.9739       | Y = 0.0 + 5.0*tan(0.64)          | 3.7227
#  191  | 0.65         | X = 0.0 + 8.0*sec(0.65)        | 10.0492      | Y = 0.0 + 5.0*tan(0.65)          | 3.8010
#  192  | 0.66         | X = 0.0 + 8.0*sec(0.66)        | 10.1267      | Y = 0.0 + 5.0*tan(0.66)          | 3.8805
#  193  | 0.67         | X = 0.0 + 8.0*sec(0.67)        | 10.2064      | Y = 0.0 + 5.0*tan(0.67)          | 3.9613
#  194  | 0.68         | X = 0.0 + 8.0*sec(0.68)        | 10.2884      | Y = 0.0 + 5.0*tan(0.68)          | 4.0433
#  195  | 0.69         | X = 0.0 + 8.0*sec(0.69)        | 10.3728      | Y = 0.0 + 5.0*tan(0.69)          | 4.1267
#  196  | 0.70         | X = 0.0 + 8.0*sec(0.70)        | 10.4597      | Y = 0.0 + 5.0*tan(0.70)          | 4.2114
#  197  | 0.71         | X = 0.0 + 8.0*sec(0.71)        | 10.5491      | Y = 0.0 + 5.0*tan(0.71)          | 4.2976
#  198  | 0.72         | X = 0.0 + 8.0*sec(0.72)        | 10.6410      | Y = 0.0 + 5.0*tan(0.72)          | 4.3853
#  199  | 0.73         | X = 0.0 + 8.0*sec(0.73)        | 10.7357      | Y = 0.0 + 5.0*tan(0.73)          | 4.4746
#  200  | 0.74         | X = 0.0 + 8.0*sec(0.74)        | 10.8332      | Y = 0.0 + 5.0*tan(0.74)          | 4.5654
#  201  | 0.75         | X = 0.0 + 8.0*sec(0.75)        | 10.9336      | Y = 0.0 + 5.0*tan(0.75)          | 4.6580
#  202  | 0.76         | X = 0.0 + 8.0*sec(0.76)        | 11.0370      | Y = 0.0 + 5.0*tan(0.76)          | 4.7523
#  203  | 0.77         | X = 0.0 + 8.0*sec(0.77)        | 11.1434      | Y = 0.0 + 5.0*tan(0.77)          | 4.8483
#  204  | 0.78         | X = 0.0 + 8.0*sec(0.78)        | 11.2531      | Y = 0.0 + 5.0*tan(0.78)          | 4.9463
#  205  | 0.79         | X = 0.0 + 8.0*sec(0.79)        | 11.3661      | Y = 0.0 + 5.0*tan(0.79)          | 5.0462
#  206  | 0.80         | X = 0.0 + 8.0*sec(0.80)        | 11.4826      | Y = 0.0 + 5.0*tan(0.80)          | 5.1482
#  207  | 0.81         | X = 0.0 + 8.0*sec(0.81)        | 11.6026      | Y = 0.0 + 5.0*tan(0.81)          | 5.2523
#  208  | 0.82         | X = 0.0 + 8.0*sec(0.82)        | 11.7264      | Y = 0.0 + 5.0*tan(0.82)          | 5.3586
#  209  | 0.83         | X = 0.0 + 8.0*sec(0.83)        | 11.8540      | Y = 0.0 + 5.0*tan(0.83)          | 5.4672
#  210  | 0.84         | X = 0.0 + 8.0*sec(0.84)        | 11.9857      | Y = 0.0 + 5.0*tan(0.84)          | 5.5782
#  211  | 0.85         | X = 0.0 + 8.0*sec(0.85)        | 12.1215      | Y = 0.0 + 5.0*tan(0.85)          | 5.6917
#  212  | 0.86         | X = 0.0 + 8.0*sec(0.86)        | 12.2617      | Y = 0.0 + 5.0*tan(0.86)          | 5.8078
#  213  | 0.87         | X = 0.0 + 8.0*sec(0.87)        | 12.4064      | Y = 0.0 + 5.0*tan(0.87)          | 5.9266
#  214  | 0.88         | X = 0.0 + 8.0*sec(0.88)        | 12.5559      | Y = 0.0 + 5.0*tan(0.88)          | 6.0483
#  215  | 0.89         | X = 0.0 + 8.0*sec(0.89)        | 12.7103      | Y = 0.0 + 5.0*tan(0.89)          | 6.1730
#  216  | 0.90         | X = 0.0 + 8.0*sec(0.90)        | 12.8698      | Y = 0.0 + 5.0*tan(0.90)          | 6.3008
#  217  | 0.91         | X = 0.0 + 8.0*sec(0.91)        | 13.0347      | Y = 0.0 + 5.0*tan(0.91)          | 6.4318
#  218  | 0.92         | X = 0.0 + 8.0*sec(0.92)        | 13.2052      | Y = 0.0 + 5.0*tan(0.92)          | 6.5663
#  219  | 0.93         | X = 0.0 + 8.0*sec(0.93)        | 13.3816      | Y = 0.0 + 5.0*tan(0.93)          | 6.7044
#  220  | 0.94         | X = 0.0 + 8.0*sec(0.94)        | 13.5642      | Y = 0.0 + 5.0*tan(0.94)          | 6.8462
#  221  | 0.95         | X = 0.0 + 8.0*sec(0.95)        | 13.7532      | Y = 0.0 + 5.0*tan(0.95)          | 6.9919
#  222  | 0.96         | X = 0.0 + 8.0*sec(0.96)        | 13.9489      | Y = 0.0 + 5.0*tan(0.96)          | 7.1418
#  223  | 0.97         | X = 0.0 + 8.0*sec(0.97)        | 14.1518      | Y = 0.0 + 5.0*tan(0.97)          | 7.2960
#  224  | 0.98         | X = 0.0 + 8.0*sec(0.98)        | 14.3621      | Y = 0.0 + 5.0*tan(0.98)          | 7.4548
#  225  | 0.99         | X = 0.0 + 8.0*sec(0.99)        | 14.5802      | Y = 0.0 + 5.0*tan(0.99)          | 7.6184
#  226  | 1.00         | X = 0.0 + 8.0*sec(1.00)        | 14.8065      | Y = 0.0 + 5.0*tan(1.00)          | 7.7870
#  227  | 1.01         | X = 0.0 + 8.0*sec(1.01)        | 15.0415      | Y = 0.0 + 5.0*tan(1.01)          | 7.9610
#  228  | 1.02         | X = 0.0 + 8.0*sec(1.02)        | 15.2857      | Y = 0.0 + 5.0*tan(1.02)          | 8.1407
#  229  | 1.03         | X = 0.0 + 8.0*sec(1.03)        | 15.5394      | Y = 0.0 + 5.0*tan(1.03)          | 8.3262
#  230  | 1.04         | X = 0.0 + 8.0*sec(1.04)        | 15.8034      | Y = 0.0 + 5.0*tan(1.04)          | 8.5181
#  231  | 1.05         | X = 0.0 + 8.0*sec(1.05)        | 16.0781      | Y = 0.0 + 5.0*tan(1.05)          | 8.7166
#  232  | 1.06         | X = 0.0 + 8.0*sec(1.06)        | 16.3642      | Y = 0.0 + 5.0*tan(1.06)          | 8.9221
#  233  | 1.07         | X = 0.0 + 8.0*sec(1.07)        | 16.6624      | Y = 0.0 + 5.0*tan(1.07)          | 9.1351
#  234  | 1.08         | X = 0.0 + 8.0*sec(1.08)        | 16.9733      | Y = 0.0 + 5.0*tan(1.08)          | 9.3561
#  235  | 1.09         | X = 0.0 + 8.0*sec(1.09)        | 17.2978      | Y = 0.0 + 5.0*tan(1.09)          | 9.5855
#  236  | 1.10         | X = 0.0 + 8.0*sec(1.10)        | 17.6368      | Y = 0.0 + 5.0*tan(1.10)          | 9.8238
#  237  | 1.11         | X = 0.0 + 8.0*sec(1.11)        | 17.9912      | Y = 0.0 + 5.0*tan(1.11)          | 10.0717
#  238  | 1.12         | X = 0.0 + 8.0*sec(1.12)        | 18.3620      | Y = 0.0 + 5.0*tan(1.12)          | 10.3298
#  239  | 1.13         | X = 0.0 + 8.0*sec(1.13)        | 18.7503      | Y = 0.0 + 5.0*tan(1.13)          | 10.5988
#  240  | 1.14         | X = 0.0 + 8.0*sec(1.14)        | 19.1573      | Y = 0.0 + 5.0*tan(1.14)          | 10.8794
#  241  | 1.15         | X = 0.0 + 8.0*sec(1.15)        | 19.5844      | Y = 0.0 + 5.0*tan(1.15)          | 11.1725
#  242  | 1.16         | X = 0.0 + 8.0*sec(1.16)        | 20.0331      | Y = 0.0 + 5.0*tan(1.16)          | 11.4790
#  243  | 1.17         | X = 0.0 + 8.0*sec(1.17)        | 20.5048      | Y = 0.0 + 5.0*tan(1.17)          | 11.7999
#  244  | 1.18         | X = 0.0 + 8.0*sec(1.18)        | 21.0015      | Y = 0.0 + 5.0*tan(1.18)          | 12.1363
#  245  | 1.19         | X = 0.0 + 8.0*sec(1.19)        | 21.5251      | Y = 0.0 + 5.0*tan(1.19)          | 12.4895
#  246  | 1.20         | X = 0.0 + 8.0*sec(1.20)        | 22.0776      | Y = 0.0 + 5.0*tan(1.20)          | 12.8608
#  247  | 1.21         | X = 0.0 + 8.0*sec(1.21)        | 22.6616      | Y = 0.0 + 5.0*tan(1.21)          | 13.2516
#  248  | 1.22         | X = 0.0 + 8.0*sec(1.22)        | 23.2798      | Y = 0.0 + 5.0*tan(1.22)          | 13.6638
#  249  | 1.23         | X = 0.0 + 8.0*sec(1.23)        | 23.9351      | Y = 0.0 + 5.0*tan(1.23)          | 14.0991
#  250  | 1.24         | X = 0.0 + 8.0*sec(1.24)        | 24.6308      | Y = 0.0 + 5.0*tan(1.24)          | 14.5596
#  251  | 1.25         | X = 0.0 + 8.0*sec(1.25)        | 25.3709      | Y = 0.0 + 5.0*tan(1.25)          | 15.0478
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
#
#  Eksekusi dihentikan. Program selesai dengan sukses!
