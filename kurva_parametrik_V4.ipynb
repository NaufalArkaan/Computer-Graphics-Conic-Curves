# %%
import numpy as np
import matplotlib.pyplot as plt

# Mengatur tema gelap bawaan matplotlib
plt.style.use('dark_background')


# =====================================================
# VISUALISASI UTAMA (GAYA DASHBOARD CLEAN & BINGKAI LUAR)
# =====================================================

def tampilkan_gaya_pro(param_array, x1, y1, xc, yc, a, b, title, n_pts, step, teks_panel, tipe_kurva="ELIPS", x2=None, y2=None):
    
    warna_kurva = '#00FFCC'   # Cyan-Neon
    warna_kurva2 = '#FF007F'  # Magenta-Neon (Khusus Hiperbola)
    warna_titik = '#FFFFFF'   # Putih
    warna_teks  = '#E0E0E0'
    
    fig, ax = plt.subplots(figsize=(11, 6.5))
    fig.subplots_adjust(left=0.08, right=0.70, top=0.88, bottom=0.10)

    # Judul Utama Gambar (SEKARANG MENGGUNAKAN NILAI STEP ASLI DARI INPUT)
    fig.suptitle(
        f"✦ VISUALISASI {tipe_kurva} PARAMETRIK ✦\nResolusi: {title} | Delta = {step:.4f}",
        fontsize=13, fontweight='bold', color=warna_kurva, y=0.96
    )

    # Plot Jalur Kurva dan Titik Sampel
    if x2 is not None and y2 is not None:
        ax.plot(x1, y1, color=warna_kurva, linewidth=2.5, zorder=2, label='Cabang Kanan')
        ax.plot(x2, y2, color=warna_kurva2, linewidth=2.5, zorder=2, label='Cabang Kiri')
        ax.scatter(x1, y1, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5)
        ax.scatter(x2, y2, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5)
    else:
        ax.plot(x1, y1, color=warna_kurva, linewidth=2.5, zorder=2, label=f'Kurva {tipe_kurva.title()}')
        ax.scatter(x1, y1, color=warna_titik, s=25, zorder=3, edgecolors='black', lw=0.5, label=f'Koordinat ({n_pts} titik)')

    # Titik Pusat / Vertex
    ax.scatter(xc, yc, color='#FFFF00', s=100, marker='P', zorder=5)
    ax.annotate(f"PUSAT ({xc:.1f}, {yc:.1f})", xy=(xc, yc), xytext=(5, 5),
                textcoords="offset points", color='#FFFF00', fontsize=8.5, fontweight='bold')

    # --- PENANDA TITIK AWAL & AKHIR ---
    if len(x1) > 0:
        ax.scatter(x1[0], y1[0], color='#00FF00', marker='s', s=80, zorder=6, label='Titik Awal')
        ax.annotate(f"► START ({x1[0]:.1f}, {y1[0]:.1f})", xy=(x1[0], y1[0]), 
                    xytext=(x1[0] + max(a, 1) * 0.15, y1[0] + max(b, 1) * 0.15),
                    color='#00FF00', fontsize=8.5, fontweight='bold',
                    arrowprops=dict(arrowstyle='->', color='#00FF00', lw=1.2))

        ax.scatter(x1[-1], y1[-1], color='#FF9900', marker='x', s=90, zorder=7, label='Titik Akhir')
        ax.annotate(f"■ END ({x1[-1]:.1f}, {y1[-1]:.1f})", xy=(x1[-1], y1[-1]), 
                    xytext=(x1[-1] + max(a, 1) * 0.15, y1[-1] - max(b, 1) * 0.15),
                    color='#FF9900', fontsize=8.5, fontweight='bold',
                    arrowprops=dict(arrowstyle='->', color='#FF9900', lw=1.2))

    # Teks Koordinat Tipis
    step_lbl = max(1, len(x1) // 6)
    for i in range(1, len(x1) - 1, step_lbl):
        ax.annotate(f"({x1[i]:.1f}, {y1[i]:.1f})", (x1[i], y1[i]),
                    textcoords="offset points", xytext=(5, 5), fontsize=7, color='#888888')
        if x2 is not None and y2 is not None:
            ax.annotate(f"({x2[i]:.1f}, {y2[i]:.1f})", (x2[i], y2[i]),
                        textcoords="offset points", xytext=(5, 5), fontsize=7, color='#888888')

    # --- KOTAK INFO PANEL TUNGGAL ---
    bbox_style = dict(boxstyle="square,pad=0.7", fc="#0B1320", ec=warna_kurva, lw=1.2, alpha=0.95)
    
    fig.text(0.73, 0.5, teks_panel, fontsize=9.5, color=warna_teks, family='monospace', bbox=bbox_style, va='center')

    # Konfigurasi Batas Grafik
    if tipe_kurva in ("ELIPS", "LINGKARAN"):
        ax.set_aspect('equal', adjustable='box')
        ax.set_xlim(xc - a * 1.6, xc + a * 1.6)
        ax.set_ylim(yc - b * 1.6, yc + b * 1.6)
    else:
        all_x = x1 if x2 is None else np.concatenate([x1, x2])
        all_y = y1 if y2 is None else np.concatenate([y1, y2])
        if len(all_x) > 0 and len(all_y) > 0:
            ax.set_xlim(np.min(all_x) - 2, np.max(all_x) + 2)
            ax.set_ylim(np.min(all_y) - 2, np.max(all_y) + 2)

    # Style Background Grid
    ax.grid(True, linestyle='--', alpha=0.3, color='gray')
    ax.tick_params(colors=warna_teks, labelsize=9)
    for spine in ax.spines.values():
        spine.set_color('white')
        spine.set_linewidth(1)

    ax.axvline(xc, color='gray', linestyle=':', linewidth=0.8, alpha=0.4, zorder=1)
    ax.axhline(yc, color='gray', linestyle=':', linewidth=0.8, alpha=0.4, zorder=1)
    ax.legend(loc='lower left', facecolor='#0B1320', edgecolor='none', labelcolor='white', fontsize=8)
    plt.show()


# =====================================================
# INPUT HELPER UTALITAS
# =====================================================

def input_float(prompt):
    while True:
        try:
            return float(input(prompt))
        except ValueError:
            print("  ⚠  Masukkan angka koordinat yang valid!")

def input_step(prompt):
    while True:
        val = input_float(prompt)
        if val > 0:
            return val
        print("  ⚠  Nilai step pembagi harus lebih besar dari 0!")


# =====================================================
# BANGUN 1: LINGKARAN
# =====================================================

def lingkaran():
    print("================================================================================")
    print(" COMPILER KURVA LINGKARAN PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat X (xc) [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Y (yc) [contoh: 0.0] : ")
    r  = input_float("Ukuran Radius  (r) [contoh: 5.0] : ")
    if r <= 0:
        print("  ⚠  Radius wajib bernilai positif!")
        return

    step_besar = input_step("Jarak Interval Step Besar θ (rad) [contoh: 0.5]  : ")
    step_kecil = input_step("Jarak Interval Step Kecil θ (rad) [contoh: 0.05] : ")

    configs = [
        ("Resolusi Rendah", step_besar),
        ("Resolusi Tinggi", step_kecil),
    ]

    keliling = 2 * np.pi * r
    luas = np.pi * r**2

    for title, step_val in configs:
        theta = np.append(np.arange(0, 2 * np.pi, step_val), 2 * np.pi)
        n_pts = len(theta)

        x = xc + r * np.cos(theta)
        y = yc + r * np.sin(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA LINGKARAN - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {r} * cos(θ)  |  y(θ) = {yc} + {r} * sin(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {r}*cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {r}*sin({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI LINGKARAN\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Radius (r)   : {r}\n"
            f" Luas Area    : {luas:.4f}\n"
            f" Keliling     : {keliling:.4f}\n"
            f" Total Titik  : {n_pts}\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})² + (y-{yc})² = {r}²"
        )
        tampilkan_gaya_pro(theta, x, y, xc, yc, r, r, title, n_pts, step_val, teks_panel, "LINGKARAN")


# =====================================================
# BANGUN 2: ELIPS
# =====================================================

def elips():
    print("================================================================================")
    print(" COMPILER KURVA ELIPS PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat X (xc)         [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Y (yc)         [contoh: 0.0] : ")
    a  = input_float("Panjang Sumbu Horizontal a [contoh: 8.0] : ")
    b  = input_float("Panjang Sumbu Vertikal b   [contoh: 5.0] : ")
    if a <= 0 or b <= 0:
        print("  ⚠  Nilai sumbu komponen harus di atas 0!")
        return

    step_besar = input_step("Jarak Interval Step Besar θ (rad) [contoh: 0.5]  : ")
    step_kecil = input_step("Jarak Interval Step Kecil θ (rad) [contoh: 0.05] : ")

    c = np.sqrt(abs(a**2 - b**2))
    e = c / max(a, b)
    luas = np.pi * a * b
    keliling = np.pi * (3*(a+b) - np.sqrt((3*a+b)*(a+3*b))) # Ramanujan approx

    configs = [
        ("Resolusi Rendah", step_besar),
        ("Resolusi Tinggi", step_kecil),
    ]

    for title, step_val in configs:
        theta = np.append(np.arange(0, 2 * np.pi, step_val), 2 * np.pi)
        n_pts = len(theta)

        x = xc + a * np.cos(theta)
        y = yc + b * np.sin(theta)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA ELIPS - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Rumus Asli):")
        print(f"   x(θ) = xc + a * cos(θ)  |  y(θ) = yc + b * sin(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {a} * cos(θ)  |  y(θ) = {yc} + {b} * sin(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            calc_x = f"X = {xc} + {a}*cos({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {b}*sin({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI ELIPS\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Sumbu hor (a): {a}\n"
            f" Sumbu ver (b): {b}\n"
            f" Jarak Fokus c: {c:.4f}\n"
            f" Eksentrisitas: {e:.4f}\n"
            f" Luas Area    : {luas:.4f}\n"
            f" Keliling     : {keliling:.4f}\n"
            f" Total Titik  : {n_pts}\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})²/{a}² + (y-{yc})²/{b}² = 1"
        )
        tampilkan_gaya_pro(theta, x, y, xc, yc, a, b, title, n_pts, step_val, teks_panel, "ELIPS")


# =====================================================
# BANGUN 3: PARABOLA (FIX 100% SESUAI PPT DOSEN)
# =====================================================

def parabola():
    print("================================================================================")
    print(" COMPILER KURVA PARABOLA PARAMETRIK")
    print("================================================================================\n")
    
    xp = input_float("Titik Vertex X (xp)  [contoh: 0.0] : ")
    yp = input_float("Titik Vertex Y (yp)  [contoh: 0.0] : ")
    a  = input_float("Jarak Fokus a        [contoh: 1.0] : ")

    step_besar = input_step("Interval Step Batas Besar parameter t [contoh: 1.0] : ")
    step_kecil = input_step("Interval Step Batas Kecil parameter t [contoh: 0.1] : ")

    configs = [("Resolusi Rendah", step_besar), ("Resolusi Tinggi", step_kecil)]

    for title, step_val in configs:
        t = np.arange(-5, 5 + step_val, step_val)
        n_pts = len(t)
        
        # PERUBAHAN RUMUS KALKULASI MENGIKUTI PPT DOSEN
        x = xp + a * t**2
        y = yp + 2 * a * t
        
        # Persamaan kartesian yang setara dengan paramaterisasi PPT Dosen
        rumus_std = f"(y-{yp})² = {4*a} * (x-{xp})"

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA PARABOLA - {title.upper()}")
        print("=" * 115)
        print(f" Persamaan Parametrik (Sesuai PPT Dosen):")
        print(f"   x(t) = xp + a * t²  |  y(t) = yp + 2 * a * t\n")
            
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(t) = {xp} + {a} * t²  |  y(t) = {yp} + 2 * {a} * t\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'NILAI t':<12} | {'FORMULA SUMBU X':<30} | {'HASIL X':<12} | {'FORMULA SUMBU Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        
        for i in range(len(t)):
            calc_x = f"X = {xp} + {a}*({t[i]:.2f})²"
            calc_y = f"Y = {yp} + 2*{a}*({t[i]:.2f})"
            print(f" {i+1:<4} | {t[i]:<12.2f} | {calc_x:<30} | {x[i]:<12.4f} | {calc_y:<32} | {y[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI PARABOLA\n"
            f" ════════════════════════════\n"
            f" Vertex (xp,yp): ({xp:.2f}, {yp:.2f})\n"
            f" Orientasi     : Horizontal\n"
            f" Jarak Fokus a : {a}\n"
            f" Total Titik   : {n_pts}\n"
            f" Skema         : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" {rumus_std}"
        )
        tampilkan_gaya_pro(t, x, y, xp, yp, a, a, title, n_pts, step_val, teks_panel, "PARABOLA")


# =====================================================
# BANGUN 4: HIPERBOLA (FIX KAKI SIMETRIS & TEKS SEC(THETA))
# =====================================================

def hiperbola():
    print("================================================================================")
    print(" COMPILER KURVA HIPERBOLA PARAMETRIK")
    print("================================================================================\n")
    xc = input_float("Titik Pusat Domain X (xc)      [contoh: 0.0] : ")
    yc = input_float("Titik Pusat Domain Y (yc)      [contoh: 0.0] : ")
    a  = input_float("Semi-Sumbu Transversal Nilai a [contoh: 4.0] : ")
    b  = input_float("Semi-Sumbu Konjugasi Nilai b   [contoh: 3.0] : ")
    if a <= 0 or b <= 0: return

    step_besar = input_step("Interval Pembagi Step Besar θ (rad) [contoh: 0.2]  : ")
    step_kecil = input_step("Interval Pembagi Step Kecil θ (rad) [contoh: 0.02] : ")

    # Batas 1.25 mendekati pi/2 (1.57) untuk menghindari error infinity (tak terhingga)
    batas = 1.25  
    configs = [("Resolusi Rendah", step_besar), ("Resolusi Tinggi", step_kecil)]

    c = np.sqrt(a**2 + b**2)
    e = c / a

    for title, step_val in configs:
        
        # PERBAIKAN: Mengunci array agar titik akhir selalu simetris tepat di batas (1.25)
        # Menghindari kaki panjang sebelah pada resolusi rendah
        theta = np.append(np.arange(-batas, batas, step_val), batas)
        n_pts = len(theta)

        # KALKULASI ASLI DENGAN 2 CABANG (Agar gambar visualnya utuh)
        # 1 / np.cos(theta) adalah ekuivalen matematis dari sec(theta)
        x1 = xc + a / np.cos(theta); y1 = yc + b * np.tan(theta) # Cabang Kanan
        x2 = xc - a / np.cos(theta); y2 = yc + b * np.tan(theta) # Cabang Kiri (Pencerminan)

        print("\n" + "=" * 115)
        print(f" METADATA & FORMULA HIPERBOLA (CABANG KANAN) - {title.upper()}")
        print("=" * 115)
        
        # TEKS KOSMETIK: Menggunakan kata 'sec(θ)' agar persis PPT Dosen
        print(f" Persamaan Parametrik (Sesuai PPT Dosen):")
        print(f"   x(θ) = xc + a * sec(θ)  |  y(θ) = yc + b * tan(θ)\n")
        print(f" Persamaan Parametrik (Substitusi):")
        print(f"   x(θ) = {xc} + {a} * sec(θ)  |  y(θ) = {yc} + {b} * tan(θ)\n")

        print("╌" * 115)
        print(f"{'IDX':<5} | {'SUDUT (rad)':<12} | {'FORMULA CABANG KANAN X':<30} | {'HASIL X':<12} | {'FORMULA CABANG KANAN Y':<32} | {'HASIL Y':<12}")
        print("╌" * 115)
        for i in range(len(theta)):
            # Mencetak tabel dengan teks 'sec'
            calc_x = f"X = {xc} + {a}*sec({theta[i]:.2f})"
            calc_y = f"Y = {yc} + {b}*tan({theta[i]:.2f})"
            print(f" {i+1:<4} | {theta[i]:<12.2f} | {calc_x:<30} | {x1[i]:<12.4f} | {calc_y:<32} | {y1[i]:<12.4f}")
        print("╌" * 115)

        teks_panel = (
            f" ⚙ DATA SPESIFIKASI HIPERBOLA\n"
            f" ════════════════════════════\n"
            f" Pusat (xc,yc): ({xc:.2f}, {yc:.2f})\n"
            f" Transversal a: {a}\n"
            f" Konjugasi b  : {b}\n"
            f" Jarak Fokus c: {c:.4f}\n"
            f" Eksentrisitas: {e:.4f}\n"
            f" Total Titik  : {n_pts} per cb\n"
            f" Skema        : {title}\n"
            f" ════════════════════════════\n"
            f" PERSAMAAN MATEMATIKA:\n"
            f" (x-{xc})²/{a}² - (y-{yc})²/{b}² = 1"
        )
        
        # Memanggil x1 dan x2 agar kedua lengkungan digambar seimbang di layar
        tampilkan_gaya_pro(theta, x1, y1, xc, yc, a, b, title, n_pts, step_val, teks_panel, "HIPERBOLA", x2, y2)


# =====================================================
# HUB KONTROL MENU UTAMA
# =====================================================

def menu():
    while True:
        print("\n" + "═" * 42)
        print("   SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF   ")
        print("═" * 42)
        print("  [1]  Kurva Lingkaran Parametrik")
        print("  [2]  Kurva Elips Parametrik")
        print("  [3]  Kurva Parabola Parametrik")
        print("  [4]  Kurva Hiperbola Parametrik")
        print("  [0]  Hentikan & Keluar Program")
        print("─" * 42)

        pilih = input(" Tentukan Opsi Operasi Menu : ").strip()

        if pilih == "1": lingkaran()
        elif pilih == "2": elips()
        elif pilih == "3": parabola()
        elif pilih == "4": hiperbola()
        elif pilih == "0":
            print("\n Eksekusi dihentikan. Program selesai dengan sukses!\n")
            break
        else: print("  ⚠  Pilihan tidak tersedia!")


if __name__ == "__main__":
    menu()
# Out:
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA LINGKARAN PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA LINGKARAN - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 5.0 * cos(θ)  |  y(θ) = 0.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 5.0*cos(0.00)        | 5.0000       | Y = 0.0 + 5.0*sin(0.00)          | 0.0000
#  2    | 0.50         | X = 0.0 + 5.0*cos(0.50)        | 4.3879       | Y = 0.0 + 5.0*sin(0.50)          | 2.3971
#  3    | 1.00         | X = 0.0 + 5.0*cos(1.00)        | 2.7015       | Y = 0.0 + 5.0*sin(1.00)          | 4.2074
#  4    | 1.50         | X = 0.0 + 5.0*cos(1.50)        | 0.3537       | Y = 0.0 + 5.0*sin(1.50)          | 4.9875
#  5    | 2.00         | X = 0.0 + 5.0*cos(2.00)        | -2.0807      | Y = 0.0 + 5.0*sin(2.00)          | 4.5465
#  6    | 2.50         | X = 0.0 + 5.0*cos(2.50)        | -4.0057      | Y = 0.0 + 5.0*sin(2.50)          | 2.9924
#  7    | 3.00         | X = 0.0 + 5.0*cos(3.00)        | -4.9500      | Y = 0.0 + 5.0*sin(3.00)          | 0.7056
#  8    | 3.50         | X = 0.0 + 5.0*cos(3.50)        | -4.6823      | Y = 0.0 + 5.0*sin(3.50)          | -1.7539
#  9    | 4.00         | X = 0.0 + 5.0*cos(4.00)        | -3.2682      | Y = 0.0 + 5.0*sin(4.00)          | -3.7840
#  10   | 4.50         | X = 0.0 + 5.0*cos(4.50)        | -1.0540      | Y = 0.0 + 5.0*sin(4.50)          | -4.8877
#  11   | 5.00         | X = 0.0 + 5.0*cos(5.00)        | 1.4183       | Y = 0.0 + 5.0*sin(5.00)          | -4.7946
#  12   | 5.50         | X = 0.0 + 5.0*cos(5.50)        | 3.5433       | Y = 0.0 + 5.0*sin(5.50)          | -3.5277
#  13   | 6.00         | X = 0.0 + 5.0*cos(6.00)        | 4.8009       | Y = 0.0 + 5.0*sin(6.00)          | -1.3971
#  14   | 6.28         | X = 0.0 + 5.0*cos(6.28)        | 5.0000       | Y = 0.0 + 5.0*sin(6.28)          | -0.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA LINGKARAN - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 5.0 * cos(θ)  |  y(θ) = 0.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 5.0*cos(0.00)        | 5.0000       | Y = 0.0 + 5.0*sin(0.00)          | 0.0000
#  2    | 0.05         | X = 0.0 + 5.0*cos(0.05)        | 4.9938       | Y = 0.0 + 5.0*sin(0.05)          | 0.2499
#  3    | 0.10         | X = 0.0 + 5.0*cos(0.10)        | 4.9750       | Y = 0.0 + 5.0*sin(0.10)          | 0.4992
#  4    | 0.15         | X = 0.0 + 5.0*cos(0.15)        | 4.9439       | Y = 0.0 + 5.0*sin(0.15)          | 0.7472
#  5    | 0.20         | X = 0.0 + 5.0*cos(0.20)        | 4.9003       | Y = 0.0 + 5.0*sin(0.20)          | 0.9933
#  6    | 0.25         | X = 0.0 + 5.0*cos(0.25)        | 4.8446       | Y = 0.0 + 5.0*sin(0.25)          | 1.2370
#  7    | 0.30         | X = 0.0 + 5.0*cos(0.30)        | 4.7767       | Y = 0.0 + 5.0*sin(0.30)          | 1.4776
#  8    | 0.35         | X = 0.0 + 5.0*cos(0.35)        | 4.6969       | Y = 0.0 + 5.0*sin(0.35)          | 1.7145
#  9    | 0.40         | X = 0.0 + 5.0*cos(0.40)        | 4.6053       | Y = 0.0 + 5.0*sin(0.40)          | 1.9471
#  10   | 0.45         | X = 0.0 + 5.0*cos(0.45)        | 4.5022       | Y = 0.0 + 5.0*sin(0.45)          | 2.1748
#  11   | 0.50         | X = 0.0 + 5.0*cos(0.50)        | 4.3879       | Y = 0.0 + 5.0*sin(0.50)          | 2.3971
#  12   | 0.55         | X = 0.0 + 5.0*cos(0.55)        | 4.2626       | Y = 0.0 + 5.0*sin(0.55)          | 2.6134
#  13   | 0.60         | X = 0.0 + 5.0*cos(0.60)        | 4.1267       | Y = 0.0 + 5.0*sin(0.60)          | 2.8232
#  14   | 0.65         | X = 0.0 + 5.0*cos(0.65)        | 3.9804       | Y = 0.0 + 5.0*sin(0.65)          | 3.0259
#  15   | 0.70         | X = 0.0 + 5.0*cos(0.70)        | 3.8242       | Y = 0.0 + 5.0*sin(0.70)          | 3.2211
#  16   | 0.75         | X = 0.0 + 5.0*cos(0.75)        | 3.6584       | Y = 0.0 + 5.0*sin(0.75)          | 3.4082
#  17   | 0.80         | X = 0.0 + 5.0*cos(0.80)        | 3.4835       | Y = 0.0 + 5.0*sin(0.80)          | 3.5868
#  18   | 0.85         | X = 0.0 + 5.0*cos(0.85)        | 3.2999       | Y = 0.0 + 5.0*sin(0.85)          | 3.7564
#  19   | 0.90         | X = 0.0 + 5.0*cos(0.90)        | 3.1080       | Y = 0.0 + 5.0*sin(0.90)          | 3.9166
#  20   | 0.95         | X = 0.0 + 5.0*cos(0.95)        | 2.9084       | Y = 0.0 + 5.0*sin(0.95)          | 4.0671
#  21   | 1.00         | X = 0.0 + 5.0*cos(1.00)        | 2.7015       | Y = 0.0 + 5.0*sin(1.00)          | 4.2074
#  22   | 1.05         | X = 0.0 + 5.0*cos(1.05)        | 2.4879       | Y = 0.0 + 5.0*sin(1.05)          | 4.3371
#  23   | 1.10         | X = 0.0 + 5.0*cos(1.10)        | 2.2680       | Y = 0.0 + 5.0*sin(1.10)          | 4.4560
#  24   | 1.15         | X = 0.0 + 5.0*cos(1.15)        | 2.0424       | Y = 0.0 + 5.0*sin(1.15)          | 4.5638
#  25   | 1.20         | X = 0.0 + 5.0*cos(1.20)        | 1.8118       | Y = 0.0 + 5.0*sin(1.20)          | 4.6602
#  26   | 1.25         | X = 0.0 + 5.0*cos(1.25)        | 1.5766       | Y = 0.0 + 5.0*sin(1.25)          | 4.7449
#  27   | 1.30         | X = 0.0 + 5.0*cos(1.30)        | 1.3375       | Y = 0.0 + 5.0*sin(1.30)          | 4.8178
#  28   | 1.35         | X = 0.0 + 5.0*cos(1.35)        | 1.0950       | Y = 0.0 + 5.0*sin(1.35)          | 4.8786
#  29   | 1.40         | X = 0.0 + 5.0*cos(1.40)        | 0.8498       | Y = 0.0 + 5.0*sin(1.40)          | 4.9272
#  30   | 1.45         | X = 0.0 + 5.0*cos(1.45)        | 0.6025       | Y = 0.0 + 5.0*sin(1.45)          | 4.9636
#  31   | 1.50         | X = 0.0 + 5.0*cos(1.50)        | 0.3537       | Y = 0.0 + 5.0*sin(1.50)          | 4.9875
#  32   | 1.55         | X = 0.0 + 5.0*cos(1.55)        | 0.1040       | Y = 0.0 + 5.0*sin(1.55)          | 4.9989
#  33   | 1.60         | X = 0.0 + 5.0*cos(1.60)        | -0.1460      | Y = 0.0 + 5.0*sin(1.60)          | 4.9979
#  34   | 1.65         | X = 0.0 + 5.0*cos(1.65)        | -0.3956      | Y = 0.0 + 5.0*sin(1.65)          | 4.9843
#  35   | 1.70         | X = 0.0 + 5.0*cos(1.70)        | -0.6442      | Y = 0.0 + 5.0*sin(1.70)          | 4.9583
#  36   | 1.75         | X = 0.0 + 5.0*cos(1.75)        | -0.8912      | Y = 0.0 + 5.0*sin(1.75)          | 4.9199
#  37   | 1.80         | X = 0.0 + 5.0*cos(1.80)        | -1.1360      | Y = 0.0 + 5.0*sin(1.80)          | 4.8692
#  38   | 1.85         | X = 0.0 + 5.0*cos(1.85)        | -1.3780      | Y = 0.0 + 5.0*sin(1.85)          | 4.8064
#  39   | 1.90         | X = 0.0 + 5.0*cos(1.90)        | -1.6164      | Y = 0.0 + 5.0*sin(1.90)          | 4.7315
#  40   | 1.95         | X = 0.0 + 5.0*cos(1.95)        | -1.8509      | Y = 0.0 + 5.0*sin(1.95)          | 4.6448
#  41   | 2.00         | X = 0.0 + 5.0*cos(2.00)        | -2.0807      | Y = 0.0 + 5.0*sin(2.00)          | 4.5465
#  42   | 2.05         | X = 0.0 + 5.0*cos(2.05)        | -2.3054      | Y = 0.0 + 5.0*sin(2.05)          | 4.4368
#  43   | 2.10         | X = 0.0 + 5.0*cos(2.10)        | -2.5242      | Y = 0.0 + 5.0*sin(2.10)          | 4.3160
#  44   | 2.15         | X = 0.0 + 5.0*cos(2.15)        | -2.7368      | Y = 0.0 + 5.0*sin(2.15)          | 4.1845
#  45   | 2.20         | X = 0.0 + 5.0*cos(2.20)        | -2.9425      | Y = 0.0 + 5.0*sin(2.20)          | 4.0425
#  46   | 2.25         | X = 0.0 + 5.0*cos(2.25)        | -3.1409      | Y = 0.0 + 5.0*sin(2.25)          | 3.8904
#  47   | 2.30         | X = 0.0 + 5.0*cos(2.30)        | -3.3314      | Y = 0.0 + 5.0*sin(2.30)          | 3.7285
#  48   | 2.35         | X = 0.0 + 5.0*cos(2.35)        | -3.5136      | Y = 0.0 + 5.0*sin(2.35)          | 3.5574
#  49   | 2.40         | X = 0.0 + 5.0*cos(2.40)        | -3.6870      | Y = 0.0 + 5.0*sin(2.40)          | 3.3773
#  50   | 2.45         | X = 0.0 + 5.0*cos(2.45)        | -3.8512      | Y = 0.0 + 5.0*sin(2.45)          | 3.1888
#  51   | 2.50         | X = 0.0 + 5.0*cos(2.50)        | -4.0057      | Y = 0.0 + 5.0*sin(2.50)          | 2.9924
#  52   | 2.55         | X = 0.0 + 5.0*cos(2.55)        | -4.1503      | Y = 0.0 + 5.0*sin(2.55)          | 2.7884
#  53   | 2.60         | X = 0.0 + 5.0*cos(2.60)        | -4.2844      | Y = 0.0 + 5.0*sin(2.60)          | 2.5775
#  54   | 2.65         | X = 0.0 + 5.0*cos(2.65)        | -4.4079      | Y = 0.0 + 5.0*sin(2.65)          | 2.3602
#  55   | 2.70         | X = 0.0 + 5.0*cos(2.70)        | -4.5204      | Y = 0.0 + 5.0*sin(2.70)          | 2.1369
#  56   | 2.75         | X = 0.0 + 5.0*cos(2.75)        | -4.6215      | Y = 0.0 + 5.0*sin(2.75)          | 1.9083
#  57   | 2.80         | X = 0.0 + 5.0*cos(2.80)        | -4.7111      | Y = 0.0 + 5.0*sin(2.80)          | 1.6749
#  58   | 2.85         | X = 0.0 + 5.0*cos(2.85)        | -4.7889      | Y = 0.0 + 5.0*sin(2.85)          | 1.4374
#  59   | 2.90         | X = 0.0 + 5.0*cos(2.90)        | -4.8548      | Y = 0.0 + 5.0*sin(2.90)          | 1.1962
#  60   | 2.95         | X = 0.0 + 5.0*cos(2.95)        | -4.9085      | Y = 0.0 + 5.0*sin(2.95)          | 0.9521
#  61   | 3.00         | X = 0.0 + 5.0*cos(3.00)        | -4.9500      | Y = 0.0 + 5.0*sin(3.00)          | 0.7056
#  62   | 3.05         | X = 0.0 + 5.0*cos(3.05)        | -4.9790      | Y = 0.0 + 5.0*sin(3.05)          | 0.4573
#  63   | 3.10         | X = 0.0 + 5.0*cos(3.10)        | -4.9957      | Y = 0.0 + 5.0*sin(3.10)          | 0.2079
#  64   | 3.15         | X = 0.0 + 5.0*cos(3.15)        | -4.9998      | Y = 0.0 + 5.0*sin(3.15)          | -0.0420
#  65   | 3.20         | X = 0.0 + 5.0*cos(3.20)        | -4.9915      | Y = 0.0 + 5.0*sin(3.20)          | -0.2919
#  66   | 3.25         | X = 0.0 + 5.0*cos(3.25)        | -4.9706      | Y = 0.0 + 5.0*sin(3.25)          | -0.5410
#  67   | 3.30         | X = 0.0 + 5.0*cos(3.30)        | -4.9374      | Y = 0.0 + 5.0*sin(3.30)          | -0.7887
#  68   | 3.35         | X = 0.0 + 5.0*cos(3.35)        | -4.8918      | Y = 0.0 + 5.0*sin(3.35)          | -1.0345
#  69   | 3.40         | X = 0.0 + 5.0*cos(3.40)        | -4.8340      | Y = 0.0 + 5.0*sin(3.40)          | -1.2777
#  70   | 3.45         | X = 0.0 + 5.0*cos(3.45)        | -4.7641      | Y = 0.0 + 5.0*sin(3.45)          | -1.5177
#  71   | 3.50         | X = 0.0 + 5.0*cos(3.50)        | -4.6823      | Y = 0.0 + 5.0*sin(3.50)          | -1.7539
#  72   | 3.55         | X = 0.0 + 5.0*cos(3.55)        | -4.5888      | Y = 0.0 + 5.0*sin(3.55)          | -1.9857
#  73   | 3.60         | X = 0.0 + 5.0*cos(3.60)        | -4.4838      | Y = 0.0 + 5.0*sin(3.60)          | -2.2126
#  74   | 3.65         | X = 0.0 + 5.0*cos(3.65)        | -4.3676      | Y = 0.0 + 5.0*sin(3.65)          | -2.4339
#  75   | 3.70         | X = 0.0 + 5.0*cos(3.70)        | -4.2405      | Y = 0.0 + 5.0*sin(3.70)          | -2.6492
#  76   | 3.75         | X = 0.0 + 5.0*cos(3.75)        | -4.1028      | Y = 0.0 + 5.0*sin(3.75)          | -2.8578
#  77   | 3.80         | X = 0.0 + 5.0*cos(3.80)        | -3.9548      | Y = 0.0 + 5.0*sin(3.80)          | -3.0593
#  78   | 3.85         | X = 0.0 + 5.0*cos(3.85)        | -3.7970      | Y = 0.0 + 5.0*sin(3.85)          | -3.2531
#  79   | 3.90         | X = 0.0 + 5.0*cos(3.90)        | -3.6297      | Y = 0.0 + 5.0*sin(3.90)          | -3.4388
#  80   | 3.95         | X = 0.0 + 5.0*cos(3.95)        | -3.4533      | Y = 0.0 + 5.0*sin(3.95)          | -3.6159
#  81   | 4.00         | X = 0.0 + 5.0*cos(4.00)        | -3.2682      | Y = 0.0 + 5.0*sin(4.00)          | -3.7840
#  82   | 4.05         | X = 0.0 + 5.0*cos(4.05)        | -3.0750      | Y = 0.0 + 5.0*sin(4.05)          | -3.9426
#  83   | 4.10         | X = 0.0 + 5.0*cos(4.10)        | -2.8741      | Y = 0.0 + 5.0*sin(4.10)          | -4.0914
#  84   | 4.15         | X = 0.0 + 5.0*cos(4.15)        | -2.6660      | Y = 0.0 + 5.0*sin(4.15)          | -4.2299
#  85   | 4.20         | X = 0.0 + 5.0*cos(4.20)        | -2.4513      | Y = 0.0 + 5.0*sin(4.20)          | -4.3579
#  86   | 4.25         | X = 0.0 + 5.0*cos(4.25)        | -2.2304      | Y = 0.0 + 5.0*sin(4.25)          | -4.4749
#  87   | 4.30         | X = 0.0 + 5.0*cos(4.30)        | -2.0040      | Y = 0.0 + 5.0*sin(4.30)          | -4.5808
#  88   | 4.35         | X = 0.0 + 5.0*cos(4.35)        | -1.7725      | Y = 0.0 + 5.0*sin(4.35)          | -4.6753
#  89   | 4.40         | X = 0.0 + 5.0*cos(4.40)        | -1.5367      | Y = 0.0 + 5.0*sin(4.40)          | -4.7580
#  90   | 4.45         | X = 0.0 + 5.0*cos(4.45)        | -1.2969      | Y = 0.0 + 5.0*sin(4.45)          | -4.8289
#  91   | 4.50         | X = 0.0 + 5.0*cos(4.50)        | -1.0540      | Y = 0.0 + 5.0*sin(4.50)          | -4.8877
#  92   | 4.55         | X = 0.0 + 5.0*cos(4.55)        | -0.8084      | Y = 0.0 + 5.0*sin(4.55)          | -4.9342
#  93   | 4.60         | X = 0.0 + 5.0*cos(4.60)        | -0.5608      | Y = 0.0 + 5.0*sin(4.60)          | -4.9685
#  94   | 4.65         | X = 0.0 + 5.0*cos(4.65)        | -0.3117      | Y = 0.0 + 5.0*sin(4.65)          | -4.9903
#  95   | 4.70         | X = 0.0 + 5.0*cos(4.70)        | -0.0619      | Y = 0.0 + 5.0*sin(4.70)          | -4.9996
#  96   | 4.75         | X = 0.0 + 5.0*cos(4.75)        | 0.1880       | Y = 0.0 + 5.0*sin(4.75)          | -4.9965
#  97   | 4.80         | X = 0.0 + 5.0*cos(4.80)        | 0.4375       | Y = 0.0 + 5.0*sin(4.80)          | -4.9808
#  98   | 4.85         | X = 0.0 + 5.0*cos(4.85)        | 0.6859       | Y = 0.0 + 5.0*sin(4.85)          | -4.9527
#  99   | 4.90         | X = 0.0 + 5.0*cos(4.90)        | 0.9326       | Y = 0.0 + 5.0*sin(4.90)          | -4.9123
#  100  | 4.95         | X = 0.0 + 5.0*cos(4.95)        | 1.1769       | Y = 0.0 + 5.0*sin(4.95)          | -4.8595
#  101  | 5.00         | X = 0.0 + 5.0*cos(5.00)        | 1.4183       | Y = 0.0 + 5.0*sin(5.00)          | -4.7946
#  102  | 5.05         | X = 0.0 + 5.0*cos(5.05)        | 1.6562       | Y = 0.0 + 5.0*sin(5.05)          | -4.7177
#  103  | 5.10         | X = 0.0 + 5.0*cos(5.10)        | 1.8899       | Y = 0.0 + 5.0*sin(5.10)          | -4.6291
#  104  | 5.15         | X = 0.0 + 5.0*cos(5.15)        | 2.1189       | Y = 0.0 + 5.0*sin(5.15)          | -4.5288
#  105  | 5.20         | X = 0.0 + 5.0*cos(5.20)        | 2.3426       | Y = 0.0 + 5.0*sin(5.20)          | -4.4173
#  106  | 5.25         | X = 0.0 + 5.0*cos(5.25)        | 2.5604       | Y = 0.0 + 5.0*sin(5.25)          | -4.2947
#  107  | 5.30         | X = 0.0 + 5.0*cos(5.30)        | 2.7719       | Y = 0.0 + 5.0*sin(5.30)          | -4.1613
#  108  | 5.35         | X = 0.0 + 5.0*cos(5.35)        | 2.9764       | Y = 0.0 + 5.0*sin(5.35)          | -4.0176
#  109  | 5.40         | X = 0.0 + 5.0*cos(5.40)        | 3.1735       | Y = 0.0 + 5.0*sin(5.40)          | -3.8638
#  110  | 5.45         | X = 0.0 + 5.0*cos(5.45)        | 3.3626       | Y = 0.0 + 5.0*sin(5.45)          | -3.7004
#  111  | 5.50         | X = 0.0 + 5.0*cos(5.50)        | 3.5433       | Y = 0.0 + 5.0*sin(5.50)          | -3.5277
#  112  | 5.55         | X = 0.0 + 5.0*cos(5.55)        | 3.7152       | Y = 0.0 + 5.0*sin(5.55)          | -3.3462
#  113  | 5.60         | X = 0.0 + 5.0*cos(5.60)        | 3.8778       | Y = 0.0 + 5.0*sin(5.60)          | -3.1563
#  114  | 5.65         | X = 0.0 + 5.0*cos(5.65)        | 4.0307       | Y = 0.0 + 5.0*sin(5.65)          | -2.9586
#  115  | 5.70         | X = 0.0 + 5.0*cos(5.70)        | 4.1736       | Y = 0.0 + 5.0*sin(5.70)          | -2.7534
#  116  | 5.75         | X = 0.0 + 5.0*cos(5.75)        | 4.3060       | Y = 0.0 + 5.0*sin(5.75)          | -2.5414
#  117  | 5.80         | X = 0.0 + 5.0*cos(5.80)        | 4.4276       | Y = 0.0 + 5.0*sin(5.80)          | -2.3230
#  118  | 5.85         | X = 0.0 + 5.0*cos(5.85)        | 4.5382       | Y = 0.0 + 5.0*sin(5.85)          | -2.0988
#  119  | 5.90         | X = 0.0 + 5.0*cos(5.90)        | 4.6374       | Y = 0.0 + 5.0*sin(5.90)          | -1.8694
#  120  | 5.95         | X = 0.0 + 5.0*cos(5.95)        | 4.7250       | Y = 0.0 + 5.0*sin(5.95)          | -1.6353
#  121  | 6.00         | X = 0.0 + 5.0*cos(6.00)        | 4.8009       | Y = 0.0 + 5.0*sin(6.00)          | -1.3971
#  122  | 6.05         | X = 0.0 + 5.0*cos(6.05)        | 4.8647       | Y = 0.0 + 5.0*sin(6.05)          | -1.1554
#  123  | 6.10         | X = 0.0 + 5.0*cos(6.10)        | 4.9163       | Y = 0.0 + 5.0*sin(6.10)          | -0.9108
#  124  | 6.15         | X = 0.0 + 5.0*cos(6.15)        | 4.9557       | Y = 0.0 + 5.0*sin(6.15)          | -0.6640
#  125  | 6.20         | X = 0.0 + 5.0*cos(6.20)        | 4.9827       | Y = 0.0 + 5.0*sin(6.20)          | -0.4154
#  126  | 6.25         | X = 0.0 + 5.0*cos(6.25)        | 4.9972       | Y = 0.0 + 5.0*sin(6.25)          | -0.1659
#  127  | 6.28         | X = 0.0 + 5.0*cos(6.28)        | 5.0000       | Y = 0.0 + 5.0*sin(6.28)          | -0.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
# ================================================================================
#  COMPILER KURVA LINGKARAN PARAMETRIK
# ================================================================================
#
#
# ===================================================================================================================
#  METADATA & FORMULA LINGKARAN - RESOLUSI RENDAH
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 5.0 * cos(θ)  |  y(θ) = 0.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 5.0*cos(0.00)        | 5.0000       | Y = 0.0 + 5.0*sin(0.00)          | 0.0000
#  2    | 0.70         | X = 0.0 + 5.0*cos(0.70)        | 3.8242       | Y = 0.0 + 5.0*sin(0.70)          | 3.2211
#  3    | 1.40         | X = 0.0 + 5.0*cos(1.40)        | 0.8498       | Y = 0.0 + 5.0*sin(1.40)          | 4.9272
#  4    | 2.10         | X = 0.0 + 5.0*cos(2.10)        | -2.5242      | Y = 0.0 + 5.0*sin(2.10)          | 4.3160
#  5    | 2.80         | X = 0.0 + 5.0*cos(2.80)        | -4.7111      | Y = 0.0 + 5.0*sin(2.80)          | 1.6749
#  6    | 3.50         | X = 0.0 + 5.0*cos(3.50)        | -4.6823      | Y = 0.0 + 5.0*sin(3.50)          | -1.7539
#  7    | 4.20         | X = 0.0 + 5.0*cos(4.20)        | -2.4513      | Y = 0.0 + 5.0*sin(4.20)          | -4.3579
#  8    | 4.90         | X = 0.0 + 5.0*cos(4.90)        | 0.9326       | Y = 0.0 + 5.0*sin(4.90)          | -4.9123
#  9    | 5.60         | X = 0.0 + 5.0*cos(5.60)        | 3.8778       | Y = 0.0 + 5.0*sin(5.60)          | -3.1563
#  10   | 6.28         | X = 0.0 + 5.0*cos(6.28)        | 5.0000       | Y = 0.0 + 5.0*sin(6.28)          | -0.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ===================================================================================================================
#  METADATA & FORMULA LINGKARAN - RESOLUSI TINGGI
# ===================================================================================================================
#  Persamaan Parametrik (Rumus Asli):
#    x(θ) = xc + r * cos(θ)  |  y(θ) = yc + r * sin(θ)
#
#  Persamaan Parametrik (Substitusi):
#    x(θ) = 0.0 + 5.0 * cos(θ)  |  y(θ) = 0.0 + 5.0 * sin(θ)
#
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# IDX   | SUDUT (rad)  | FORMULA SUMBU X                | HASIL X      | FORMULA SUMBU Y                  | HASIL Y
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
#  1    | 0.00         | X = 0.0 + 5.0*cos(0.00)        | 5.0000       | Y = 0.0 + 5.0*sin(0.00)          | 0.0000
#  2    | 0.09         | X = 0.0 + 5.0*cos(0.09)        | 4.9798       | Y = 0.0 + 5.0*sin(0.09)          | 0.4494
#  3    | 0.18         | X = 0.0 + 5.0*cos(0.18)        | 4.9192       | Y = 0.0 + 5.0*sin(0.18)          | 0.8951
#  4    | 0.27         | X = 0.0 + 5.0*cos(0.27)        | 4.8189       | Y = 0.0 + 5.0*sin(0.27)          | 1.3337
#  5    | 0.36         | X = 0.0 + 5.0*cos(0.36)        | 4.6795       | Y = 0.0 + 5.0*sin(0.36)          | 1.7614
#  6    | 0.45         | X = 0.0 + 5.0*cos(0.45)        | 4.5022       | Y = 0.0 + 5.0*sin(0.45)          | 2.1748
#  7    | 0.54         | X = 0.0 + 5.0*cos(0.54)        | 4.2885       | Y = 0.0 + 5.0*sin(0.54)          | 2.5707
#  8    | 0.63         | X = 0.0 + 5.0*cos(0.63)        | 4.0401       | Y = 0.0 + 5.0*sin(0.63)          | 2.9457
#  9    | 0.72         | X = 0.0 + 5.0*cos(0.72)        | 3.7590       | Y = 0.0 + 5.0*sin(0.72)          | 3.2969
#  10   | 0.81         | X = 0.0 + 5.0*cos(0.81)        | 3.4475       | Y = 0.0 + 5.0*sin(0.81)          | 3.6214
#  11   | 0.90         | X = 0.0 + 5.0*cos(0.90)        | 3.1080       | Y = 0.0 + 5.0*sin(0.90)          | 3.9166
#  12   | 0.99         | X = 0.0 + 5.0*cos(0.99)        | 2.7434       | Y = 0.0 + 5.0*sin(0.99)          | 4.1801
#  13   | 1.08         | X = 0.0 + 5.0*cos(1.08)        | 2.3566       | Y = 0.0 + 5.0*sin(1.08)          | 4.4098
#  14   | 1.17         | X = 0.0 + 5.0*cos(1.17)        | 1.9508       | Y = 0.0 + 5.0*sin(1.17)          | 4.6038
#  15   | 1.26         | X = 0.0 + 5.0*cos(1.26)        | 1.5291       | Y = 0.0 + 5.0*sin(1.26)          | 4.7605
#  16   | 1.35         | X = 0.0 + 5.0*cos(1.35)        | 1.0950       | Y = 0.0 + 5.0*sin(1.35)          | 4.8786
#  17   | 1.44         | X = 0.0 + 5.0*cos(1.44)        | 0.6521       | Y = 0.0 + 5.0*sin(1.44)          | 4.9573
#  18   | 1.53         | X = 0.0 + 5.0*cos(1.53)        | 0.2039       | Y = 0.0 + 5.0*sin(1.53)          | 4.9958
#  19   | 1.62         | X = 0.0 + 5.0*cos(1.62)        | -0.2459      | Y = 0.0 + 5.0*sin(1.62)          | 4.9939
#  20   | 1.71         | X = 0.0 + 5.0*cos(1.71)        | -0.6938      | Y = 0.0 + 5.0*sin(1.71)          | 4.9516
#  21   | 1.80         | X = 0.0 + 5.0*cos(1.80)        | -1.1360      | Y = 0.0 + 5.0*sin(1.80)          | 4.8692
#  22   | 1.89         | X = 0.0 + 5.0*cos(1.89)        | -1.5691      | Y = 0.0 + 5.0*sin(1.89)          | 4.7474
#  23   | 1.98         | X = 0.0 + 5.0*cos(1.98)        | -1.9894      | Y = 0.0 + 5.0*sin(1.98)          | 4.5872
#  24   | 2.07         | X = 0.0 + 5.0*cos(2.07)        | -2.3936      | Y = 0.0 + 5.0*sin(2.07)          | 4.3898
#  25   | 2.16         | X = 0.0 + 5.0*cos(2.16)        | -2.7785      | Y = 0.0 + 5.0*sin(2.16)          | 4.1569
#  26   | 2.25         | X = 0.0 + 5.0*cos(2.25)        | -3.1409      | Y = 0.0 + 5.0*sin(2.25)          | 3.8904
#  27   | 2.34         | X = 0.0 + 5.0*cos(2.34)        | -3.4778      | Y = 0.0 + 5.0*sin(2.34)          | 3.5923
#  28   | 2.43         | X = 0.0 + 5.0*cos(2.43)        | -3.7866      | Y = 0.0 + 5.0*sin(2.43)          | 3.2652
#  29   | 2.52         | X = 0.0 + 5.0*cos(2.52)        | -4.0648      | Y = 0.0 + 5.0*sin(2.52)          | 2.9117
#  30   | 2.61         | X = 0.0 + 5.0*cos(2.61)        | -4.3100      | Y = 0.0 + 5.0*sin(2.61)          | 2.5345
#  31   | 2.70         | X = 0.0 + 5.0*cos(2.70)        | -4.5204      | Y = 0.0 + 5.0*sin(2.70)          | 2.1369
#  32   | 2.79         | X = 0.0 + 5.0*cos(2.79)        | -4.6941      | Y = 0.0 + 5.0*sin(2.79)          | 1.7220
#  33   | 2.88         | X = 0.0 + 5.0*cos(2.88)        | -4.8299      | Y = 0.0 + 5.0*sin(2.88)          | 1.2931
#  34   | 2.97         | X = 0.0 + 5.0*cos(2.97)        | -4.9266      | Y = 0.0 + 5.0*sin(2.97)          | 0.8538
#  35   | 3.06         | X = 0.0 + 5.0*cos(3.06)        | -4.9834      | Y = 0.0 + 5.0*sin(3.06)          | 0.4075
#  36   | 3.15         | X = 0.0 + 5.0*cos(3.15)        | -4.9998      | Y = 0.0 + 5.0*sin(3.15)          | -0.0420
#  37   | 3.24         | X = 0.0 + 5.0*cos(3.24)        | -4.9758      | Y = 0.0 + 5.0*sin(3.24)          | -0.4912
#  38   | 3.33         | X = 0.0 + 5.0*cos(3.33)        | -4.9115      | Y = 0.0 + 5.0*sin(3.33)          | -0.9365
#  39   | 3.42         | X = 0.0 + 5.0*cos(3.42)        | -4.8075      | Y = 0.0 + 5.0*sin(3.42)          | -1.3741
#  40   | 3.51         | X = 0.0 + 5.0*cos(3.51)        | -4.6645      | Y = 0.0 + 5.0*sin(3.51)          | -1.8007
#  41   | 3.60         | X = 0.0 + 5.0*cos(3.60)        | -4.4838      | Y = 0.0 + 5.0*sin(3.60)          | -2.2126
#  42   | 3.69         | X = 0.0 + 5.0*cos(3.69)        | -4.2668      | Y = 0.0 + 5.0*sin(3.69)          | -2.6066
#  43   | 3.78         | X = 0.0 + 5.0*cos(3.78)        | -4.0152      | Y = 0.0 + 5.0*sin(3.78)          | -2.9796
#  44   | 3.87         | X = 0.0 + 5.0*cos(3.87)        | -3.7312      | Y = 0.0 + 5.0*sin(3.87)          | -3.3284
#  45   | 3.96         | X = 0.0 + 5.0*cos(3.96)        | -3.4169      | Y = 0.0 + 5.0*sin(3.96)          | -3.6503
#  46   | 4.05         | X = 0.0 + 5.0*cos(4.05)        | -3.0750      | Y = 0.0 + 5.0*sin(4.05)          | -3.9426
#  47   | 4.14         | X = 0.0 + 5.0*cos(4.14)        | -2.7082      | Y = 0.0 + 5.0*sin(4.14)          | -4.2030
#  48   | 4.23         | X = 0.0 + 5.0*cos(4.23)        | -2.3195      | Y = 0.0 + 5.0*sin(4.23)          | -4.4294
#  49   | 4.32         | X = 0.0 + 5.0*cos(4.32)        | -1.9120      | Y = 0.0 + 5.0*sin(4.32)          | -4.6200
#  50   | 4.41         | X = 0.0 + 5.0*cos(4.41)        | -1.4890      | Y = 0.0 + 5.0*sin(4.41)          | -4.7731
#  51   | 4.50         | X = 0.0 + 5.0*cos(4.50)        | -1.0540      | Y = 0.0 + 5.0*sin(4.50)          | -4.8877
#  52   | 4.59         | X = 0.0 + 5.0*cos(4.59)        | -0.6104      | Y = 0.0 + 5.0*sin(4.59)          | -4.9626
#  53   | 4.68         | X = 0.0 + 5.0*cos(4.68)        | -0.1619      | Y = 0.0 + 5.0*sin(4.68)          | -4.9974
#  54   | 4.77         | X = 0.0 + 5.0*cos(4.77)        | 0.2879       | Y = 0.0 + 5.0*sin(4.77)          | -4.9917
#  55   | 4.86         | X = 0.0 + 5.0*cos(4.86)        | 0.7354       | Y = 0.0 + 5.0*sin(4.86)          | -4.9456
#  56   | 4.95         | X = 0.0 + 5.0*cos(4.95)        | 1.1769       | Y = 0.0 + 5.0*sin(4.95)          | -4.8595
#  57   | 5.04         | X = 0.0 + 5.0*cos(5.04)        | 1.6089       | Y = 0.0 + 5.0*sin(5.04)          | -4.7341
#  58   | 5.13         | X = 0.0 + 5.0*cos(5.13)        | 2.0279       | Y = 0.0 + 5.0*sin(5.13)          | -4.5703
#  59   | 5.22         | X = 0.0 + 5.0*cos(5.22)        | 2.4305       | Y = 0.0 + 5.0*sin(5.22)          | -4.3695
#  60   | 5.31         | X = 0.0 + 5.0*cos(5.31)        | 2.8133       | Y = 0.0 + 5.0*sin(5.31)          | -4.1334
#  61   | 5.40         | X = 0.0 + 5.0*cos(5.40)        | 3.1735       | Y = 0.0 + 5.0*sin(5.40)          | -3.8638
#  62   | 5.49         | X = 0.0 + 5.0*cos(5.49)        | 3.5079       | Y = 0.0 + 5.0*sin(5.49)          | -3.5630
#  63   | 5.58         | X = 0.0 + 5.0*cos(5.58)        | 3.8139       | Y = 0.0 + 5.0*sin(5.58)          | -3.2333
#  64   | 5.67         | X = 0.0 + 5.0*cos(5.67)        | 4.0891       | Y = 0.0 + 5.0*sin(5.67)          | -2.8774
#  65   | 5.76         | X = 0.0 + 5.0*cos(5.76)        | 4.3312       | Y = 0.0 + 5.0*sin(5.76)          | -2.4982
#  66   | 5.85         | X = 0.0 + 5.0*cos(5.85)        | 4.5382       | Y = 0.0 + 5.0*sin(5.85)          | -2.0988
#  67   | 5.94         | X = 0.0 + 5.0*cos(5.94)        | 4.7084       | Y = 0.0 + 5.0*sin(5.94)          | -1.6824
#  68   | 6.03         | X = 0.0 + 5.0*cos(6.03)        | 4.8406       | Y = 0.0 + 5.0*sin(6.03)          | -1.2524
#  69   | 6.12         | X = 0.0 + 5.0*cos(6.12)        | 4.9336       | Y = 0.0 + 5.0*sin(6.12)          | -0.8123
#  70   | 6.21         | X = 0.0 + 5.0*cos(6.21)        | 4.9866       | Y = 0.0 + 5.0*sin(6.21)          | -0.3656
#  71   | 6.28         | X = 0.0 + 5.0*cos(6.28)        | 5.0000       | Y = 0.0 + 5.0*sin(6.28)          | -0.0000
# ╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌
# ══════════════════════════════════════════
#    SYSTEM GENERATOR KURVA GRAFIKA INTERAKTIF
# ══════════════════════════════════════════
#   [1]  Kurva Lingkaran Parametrik
#   [2]  Kurva Elips Parametrik
#   [3]  Kurva Parabola Parametrik
#   [4]  Kurva Hiperbola Parametrik
#   [0]  Hentikan & Keluar Program
# ──────────────────────────────────────────
#
#  Eksekusi dihentikan. Program selesai dengan sukses!
